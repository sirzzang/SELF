# %% [markdown]
# # Keep in Mind
#
# **1. 사이트 페이지 몇 개를 살펴 보며 패턴을 찾는다.**
#
# **2. 유연한 사고방식을 가진다. 웹사이트마다 레이아웃이 완전히 다르다.**
#
#     - 각 웹사이트에서 어떤 정보를 찾을지,
#     - 어떻게 찾을지 유연하게 생각하자.
#
# **3. 링크를 따라가다 보면 인터넷 어디든지 갈 수 있음을 유념하자. 항상 법, 규정, 보안 등에 주의하자.**
#
# **4. 링크를 따라가는 크롤러를 만들기 전에, 다음과 같은 사항을 생각하자.**
#
#     - 내가 수집하려는 데이터는 어떤 것인가?
#         * 정해진 사이트 몇 개만 수집하면 되는가?
#         * 내가 몰랐던 사이트에도 방문하는 크롤러가 필요한가?
#
#     - 크롤러가 특정 웹사이트에 도달했을 때 어떻게 동작해야 할까?
#         * 즉시 새 웹사이트 링크로 들어가야 하나?
#         * 한 동안 현재 웹사이트에 머물면서 파고들고, 정보를 저장해야 하나?
#
#     - 특정 사이트를 스크랩에서 제외할 필요가 있을까?(*ex. 비영어권 사이트, 성인용 사이트 등*)
#
#     - 웹사이트가 내 방문을 알아차렸다면, 나 자신을 법적으로 보호할 수 있을까?(_18장_)
#
# **5. 반드시, 실제 코드를 작성하기 전에 코드가 무슨 일을 하는지 다이어그램을 그리거나, 메모하는 습관을 갖는다. 크롤러가 복잡해질수록 시간이 절약되고, 좌절 경험이 적어질 것이다!**

# %% [markdown]
# # 크롤러 만들기
#
# > 아래 단계로 갈수록, 크롤러의 동작이 많아진다.
#
# **1.** 단일 도메인 내에서 페이지를 옮겨 다니며 각 링크를 방문하는 크롤러.
#
# **2.** 단일 도메인 내에서, 페이지에 머무르는 동안 특정 정보를 수집하는 스크레이퍼를 추가한 크롤러.
#
# **3.** 외부 링크를 따라 가면서, 여러 도메인 내에서 페이지에 대해 특정 정보를 수집하는 스크레이퍼를 추가한 크롤러.

# %% [markdown]
# ## 1. 단일 도메인 내에서 페이지 이동
# * 위키피디아에서 항목 페이지 간 이동하는 크롤러 제작
# > BTS 페이지에서 TXT 페이지로 넘어가는 데 몇 번의 링크 이동이 필요할까?

# %%
# bts 위키피디아 페이지 읽어 오기
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError

def getTitle(url):
    try:
        html = urlopen(url)
    except HTTPError as e:
        print("접속에 실패하였습니다. {}".format(e))
    try:
        bs = BeautifulSoup(html, 'html5lib')
        print("{} 페이지를 읽어 왔습니다.".format(bs.h1.get_text()))
    except AttributeError as e:
        print("error! no such tag!")
    return bs

bts_page = getTitle("https://en.wikipedia.org/wiki/BTS") # 성공
type(bts_page)
# Out:
# BTS 페이지를 읽어 왔습니다.
# bs4.BeautifulSoup

# %%
# BTS 페이지에서 모든 링크 확인하기
for link in bts_page.findAll('a'):
    if 'href' in link.attrs: # a 태그에 href 속성이 있나 확인.
        print(link['href'])
        
# 결과 확인 : 원하지 않는 링크들도 있다.
# https://foundation.wikimedia.org/wiki/Privacy_policy
# https://wikimediafoundation.org/
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/BTS_(disambiguation)
# /wiki/File:%E2%80%98LG_Q7_BTS_%EC%97%90%EB%94%94%EC%85%98%E2%80%99_%EC%98%88%EC%95%BD_%ED%8C%90%EB%A7%A4_%EC%8B%9C%EC%9E%91_(42773472410)_(cropped).jpg
# /wiki/LG_Electronics
# /wiki/V_(singer)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Kim_Seok-jin
# /wiki/Jimin_(singer,_born_1995)
# /wiki/Jungkook
# /wiki/Suga_(rapper)
# /wiki/Seoul
# /wiki/K-pop
# /wiki/Hip_hop_music
# /wiki/Contemporary_R%26B
# /wiki/Electronic_dance_music
# /wiki/Big_Hit_Entertainment
# /wiki/Pony_Canyon
# /wiki/Def_Jam_Recordings
# #cite_note-1
# /wiki/Columbia_Records
# #cite_note-2
# http://bts.ibighit.com
# /wiki/Kim_Seok-jin
# /wiki/Suga_(rapper)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Jimin_(singer,_born_1995)
# /wiki/V_(singer)
# /wiki/Jungkook
# /wiki/Hangul
# https://en.wiktionary.org/wiki/%EB%B0%A9%ED%83%84
# https://en.wiktionary.org/wiki/%EC%86%8C%EB%85%84
# https://en.wiktionary.org/wiki/%EB%8B%A8
# /wiki/Hanja
# https://en.wiktionary.org/wiki/%E9%98%B2%E5%BD%88
# https://en.wiktionary.org/wiki/%E5%B0%91%E5%B9%B4
# https://en.wiktionary.org/wiki/%E5%9C%98
# /wiki/Revised_Romanization_of_Korean
# /wiki/McCune%E2%80%93Reischauer
# /wiki/Kanji
# /wiki/Hiragana
# /wiki/Hepburn_romanization
# /wiki/Kunrei-shiki_romanization
# /wiki/Korean_language
# /wiki/Revised_Romanization_of_Korean
# /wiki/Boy_band
# /wiki/Seoul
# #cite_note-3
# /wiki/Hip_hop_music
# /wiki/Parallel_universes_in_fiction
# /wiki/Big_Hit_Entertainment
# /wiki/2_Cool_4_Skool
# /wiki/Billboard_200
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_2
# /wiki/The_Most_Beautiful_Moment_in_Life:_Young_Forever
# /wiki/Wings_(BTS_album)
# /wiki/Korean_Wave
# /wiki/Recording_Industry_Association_of_America
# /wiki/Mic_Drop_(song)
# /wiki/Love_Yourself:_Tear
# /wiki/Love_Yourself:_Answer
# /wiki/Map_of_the_Soul:_Persona
# /wiki/Map_of_the_Soul:_7
# /wiki/The_Beatles
# /wiki/Gaon_Album_Chart
# /wiki/Gaon_Music_Chart
# #cite_note-4
# /wiki/List_of_best-selling_albums_in_South_Korea
# /wiki/IFPI
# /wiki/Billboard_Music_Award_for_Top_Social_Artist
# /wiki/Billboard_Music_Award_for_Top_Duo/Group
# /wiki/2019_Billboard_Music_Awards
# /wiki/Time_(magazine)
# /wiki/Time_100
# /wiki/Honorific_nicknames_in_popular_music
# /wiki/Forbes_Korea_Power_Celebrity
# /wiki/Forbes_Celebrity_100
# /wiki/Billboard_(magazine)
# /wiki/Love_Yourself_World_Tour
# /wiki/Wembley_Stadium
# /wiki/Rose_Bowl_(stadium)
# /wiki/Love_Myself_(campaign)
# /wiki/UNICEF
# /wiki/United_Nations
# /wiki/United_Nations_General_Assembly
# /wiki/Order_of_Cultural_Merit_(Korea)
# /wiki/President_of_South_Korea
# #Name
# #Career
# #2010–2014:_Formation_and_early_years
# #2014–2015:_Moderate_success_and_first_concert_tour
# #2015–2016:_Mainstream_breakthrough_and_commercial_success
# #2017:_International_expansion_and_collaborations
# #2018:_Worldwide_recognition
# #2019:_Map_of_the_Soul:_Persona,_stadium_world_tour_and_BTS_World
# #2020:_Map_of_the_Soul:_7_and_second_stadium_world_tour
# #Artistry
# #Influences
# #Music
# #Lyrics_and_themes
# #Impact_and_influence
# #Awards_and_achievements
# #Other_ventures
# #Endorsements
# #Philanthropy
# #BTS_Universe
# #Connect,_BTS
# #Members
# #Discography
# #Tours_and_concerts
# #Filmography
# #Exhibitions
# #Film
# #Television
# #Online_shows
# #References
# #External_links
# /wiki/Korean_language
# /wiki/Hanja
# https://en.wiktionary.org/wiki/%E9%98%B2%E5%BD%88
# https://en.wiktionary.org/wiki/%E5%B0%91%E5%B9%B4
# https://en.wiktionary.org/wiki/%E5%9C%98
# /wiki/J-Hope
# #cite_note-5
# #cite_note-6
# #cite_note-7
# #cite_note-newname-8
# #cite_note-:9-9
# /wiki/File:Bangtan_Boys_at_the_Incheon_Music_Center_in_September_2013_02.jpg
# /wiki/File:Bangtan_Boys_at_the_Incheon_Music_Center_in_September_2013_02.jpg
# /wiki/Incheon
# /wiki/Bang_Si-hyuk
# /wiki/RM_(rapper)
# #cite_note-10
# /wiki/Hip-hop
# /wiki/1TYM
# #cite_note-:0-11
# #cite_note-12
# /wiki/2AM_(band)
# /wiki/Lee_Seung-gi
# #cite_note-13
# /wiki/Kim_Seok-jin
# /wiki/Suga_(rapper)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Jimin_(singer,_born_1995)
# /wiki/V_(singer)
# /wiki/Jungkook_(singer)
# /wiki/YouTube
# /wiki/SoundCloud
# #cite_note-14
# #cite_note-15
# /wiki/Suga_(rapper)
# #cite_note-16
# /wiki/Single_(music)#In_South_Korea
# /wiki/2_Cool_4_Skool
# #cite_note-17
# #cite_note-18
# #cite_note-19
# #cite_note-20
# #cite_note-BTSReview-21
# #cite_note-:3-22
# #cite_note-BTSReview-21
# #cite_note-:3-22
# #cite_note-:4-23
# #cite_note-24
# #cite_note-:4-23
# #cite_note-Japan_Debut-25
# /wiki/Extended_play
# /wiki/O!RUL8,2%3F
# #cite_note-26
# #cite_note-27
# #cite_note-28
# #cite_note-29
# /wiki/SBS_MTV
# /wiki/MasterChef_Korea
# #cite_note-30
# /wiki/Melon_Music_Awards
# /wiki/Golden_Disc_Awards
# /wiki/Seoul_Music_Awards
# #cite_note-31
# /wiki/File:Troubadour_02.jpg
# /wiki/File:Troubadour_02.jpg
# /wiki/Troubadour_(West_Hollywood,_California)
# /wiki/United_States
# /wiki/Skool_Luv_Affair
# #cite_note-sla-32
# /wiki/Gaon_Album_Chart
# #cite_note-33
# /wiki/Billboard_(magazine)
# #cite_note-sla-32
# #cite_note-World_chart-34
# #cite_note-35
# #cite_note-36
# /wiki/Seoul
# #cite_note-37
# #cite_note-38
# /wiki/West_Hollywood,_California
# #cite_note-39
# /wiki/KCON_(music_festival)
# /wiki/Los_Angeles
# #cite_note-40
# /wiki/Dark_%26_Wild
# #cite_note-41
# #cite_note-42
# /wiki/Rock_music
# /wiki/Rhythm_and_blues
# #cite_note-:15-43
# #cite_note-44
# #cite_note-45
# /wiki/Concert_tour
# /wiki/The_Red_Bullet_Tour
# /wiki/Kobe
# /wiki/Tokyo
# /wiki/Manila
# /wiki/Singapore
# /wiki/Bangkok
# #cite_note-TRB_II-46
# /wiki/Wake_Up_(BTS_album)
# /wiki/Oricon_Albums_Chart
# #cite_note-oricon-47
# #cite_note-48
# /wiki/Wake_Up_(BTS_album)#Promotion
# #cite_note-49
# #cite_note-BTS_Begin-50
# #cite_note-Review6-51
# #cite_note-:5-52
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_1
# #cite_note-Review6-51
# /wiki/Fuse_(TV_channel)
# #cite_note-53
# #cite_note-54
# /wiki/I_Need_U_(BTS_song)
# #cite_note-55
# /wiki/SBS_MTV
# /wiki/The_Show_(South_Korean_TV_series)
# #cite_note-INU_Wins-56
# #cite_note-57
# #cite_note-58
# /wiki/YouTube
# #cite_note-Dope_100mil-59
# /wiki/2015_BTS_Live_Trilogy_Episode_II:_The_Red_Bullet
# #cite_note-TRB_II-46
# /wiki/Oricon_Albums_Chart
# #cite_note-For_You_Oricon-60
# /wiki/Summer_Sonic_Festival
# #cite_note-61
# #cite_note-62
# /wiki/The_Most_Beautiful_Moment_in_Life_On_Stage_Tour
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_2
# #cite_note-63
# #cite_note-:16-64
# /wiki/Billboard_(magazine)
# /wiki/World_Albums
# #cite_note-65
# #cite_note-66
# /wiki/Billboard_200_chart
# #cite_note-67
# /wiki/Mnet_Asian_Music_Awards_in_the_Special_Awards_Category
# /wiki/2015_Mnet_Asian_Music_Awards
# /wiki/File:Bangtan_Boys_at_KCON_France_2016.jpg
# /wiki/File:Bangtan_Boys_at_KCON_France_2016.jpg
# /wiki/KCON_(music_festival)
# /wiki/The_Most_Beautiful_Moment_in_Life:_Young_Forever
# /wiki/Fire_(BTS_song)
# /wiki/Save_Me_(BTS_song)
# #cite_note-68
# #cite_note-69
# /wiki/List_of_Gaon_Album_Chart_number_ones_of_2016#Weekly_charts
# /wiki/Billboard_200
# #cite_note-70
# #cite_note-71
# #cite_note-72
# /wiki/Melon_Music_Awards
# #cite_note-73
# /wiki/The_Most_Beautiful_Moment_in_Life_On_Stage_Tour#Epilogue_extension
# #cite_note-74
# /wiki/Olympic_Gymnastics_Arena
# /wiki/Seoul
# #cite_note-May_2016_Comeback-75
# /wiki/KCON_(music_festival)
# /wiki/Newark,_New_Jersey
# #cite_note-76
# #cite_note-Kcon_2016-77
# #cite_note-78
# /wiki/File:BTS_win_first_Daesang_(Grand_Prize)_at_Melon_Music_Awards,_19_November_2016.jpg
# /wiki/File:BTS_win_first_Daesang_(Grand_Prize)_at_Melon_Music_Awards,_19_November_2016.jpg
# /wiki/Youth_(BTS_album)
# #cite_note-INU_Japanese-79
# /wiki/Japan
# #cite_note-80
# /wiki/Wings_(BTS_album)
# #cite_note-500k_presale-81
# #cite_note-Review10-82
# /wiki/Rolling_Stone
# #cite_note-83
# /wiki/Fuse_(TV_channel)
# #cite_note-84
# #cite_note-85
# #cite_note-86
# #cite_note-BST_Youtube_Records-87
# #cite_note-88
# /wiki/List_of_Billboard_Social_50_number-one_artists
# #cite_note-89
# #cite_note-90
# /wiki/Gaon_Album_Chart
# #cite_note-91
# /wiki/S.M._Entertainment
# /wiki/YG_Entertainment
# /wiki/JYP_Entertainment
# /wiki/Mnet_Asian_Music_Awards
# #cite_note-92
# #cite_note-93
# /wiki/Wings_(BTS_album)#You_Never_Walk_Alone
# #cite_note-94
# #cite_note-95
# #cite_note-:03-96
# /wiki/Spring_Day_(song)
# /wiki/Dazed_Digital
# #cite_note-97
# #cite_note-Review10-82
# #cite_note-98
# #cite_note-99
# /wiki/Melon_(online_music_service)
# #cite_note-100
# /wiki/Bubbling_Under_Hot_100
# #cite_note-101
# #cite_note-102
# /wiki/Melon_Music_Awards#Song_of_the_Year
# #cite_note-103
# #cite_note-104
# /wiki/File:170529_BTS_at_a_press_conference_for_the_BBMAs_(3).png
# /wiki/File:170529_BTS_at_a_press_conference_for_the_BBMAs_(3).png
# /wiki/2017_BTS_Live_Trilogy_Episode_III:_The_Wings_Tour
# #cite_note-TotalNumbers2-105
# #cite_note-106
# #cite_note-107
# /wiki/Billboard_Music_Award
# /wiki/Billboard_Music_Award_for_Top_Social_Artist
# #cite_note-108
# /wiki/Seo_Taiji
# /wiki/Come_Back_Home_(Seo_Taiji_and_Boys_song)
# #cite_note-109
# /wiki/Seoul_Olympic_Stadium
# #cite_note-110
# #cite_note-111
# /wiki/Kish%C5%8Dtenketsu
# #cite_note-:6-112
# /wiki/Love_Yourself:_Her
# #cite_note-113
# /wiki/The_Chainsmokers
# #cite_note-114
# /wiki/DNA_(BTS_song)
# /wiki/Steve_Aoki
# /wiki/Mic_Drop_(song)
# /wiki/Desiigner
# #cite_note-115
# #cite_note-:6-112
# #cite_note-116
# /wiki/File:BTS_at_2017_American_Music_Awards_in_Los_Angeles,_19_November_2017_02.jpg
# /wiki/File:BTS_at_2017_American_Music_Awards_in_Los_Angeles,_19_November_2017_02.jpg
# #cite_note-117
# /wiki/G.o.d
# /wiki/Chapter_4_(g.o.d_album)
# #cite_note-118
# /wiki/YouTube
# #cite_note-119
# /wiki/Billboard_Hot_100
# #cite_note-120
# /wiki/Wonder_Girls
# #cite_note-121
# /wiki/Mic_Drop_(song)
# #cite_note-122
# #cite_note-123
# #cite_note-124
# /wiki/Recording_Industry_Association_of_America
# #cite_note-125
# #cite_note-126
# #cite_note-:7-127
# #cite_note-128
# #cite_note-129
# #cite_note-130
# #cite_note-131
# #cite_note-132
# #cite_note-133
# #cite_note-134
# #cite_note-135
# /wiki/American_Music_Awards
# #cite_note-136
# #cite_note-137
# #cite_note-138
# #cite_note-139
# /wiki/Guinness_World_Records
# #cite_note-:14-140
# /wiki/Dick_Clark%27s_New_Year%27s_Rockin%27_Eve
# #cite_note-141
# /wiki/TV_Asahi
# /wiki/Music_Station#Super_Live
# #cite_note-142
# /wiki/Mnet_Asian_Music_Award_for_Artist_of_the_Year
# /wiki/2017_Mnet_Asian_Music_Awards
# #cite_note-143
# #cite_note-144
# #cite_note-145
# /wiki/Golden_Disc_Awards
# #cite_note-146
# /wiki/Seoul_Music_Awards
# #cite_note-147
# /wiki/YouTube_Premium
# #cite_note-148
# #cite_note-149
# /wiki/Face_Yourself
# #cite_note-150
# /wiki/Billboard_200
# #cite_note-151
# #cite_note-:8-152
# /wiki/File:180524_BTS_at_a_press_conference_for_Love_Yourself_Tear_(3).png
# /wiki/File:180524_BTS_at_a_press_conference_for_Love_Yourself_Tear_(3).png
# /wiki/Love_Yourself:_Tear
# /wiki/2018_Billboard_Music_Awards
# #cite_note-153
# /wiki/Fake_Love_(BTS_song)
# #cite_note-154
# /wiki/Billboard_Music_Award_for_Top_Social_Artist
# #cite_note-155
# #cite_note-156
# #cite_note-157
# /wiki/Billboard_(magazine)
# #cite_note-158
# /wiki/Pitchfork_(website)
# #cite_note-159
# /wiki/Album-equivalent_unit
# #cite_note-160
# #cite_note-161
# /wiki/United_Kingdom
# /wiki/UK_Albums_Chart
# #cite_note-162
# #cite_note-163
# #cite_note-164
# #cite_note-165
# #cite_note-166
# /wiki/Compilation_album
# /wiki/Love_Yourself:_Answer
# #cite_note-167
# #cite_note-168
# /wiki/Idol_(BTS_song)
# /wiki/Nicki_Minaj
# #cite_note-169
# #cite_note-170
# #cite_note-:10-171
# /wiki/Magnum_opus
# #cite_note-172
# /wiki/Gaon_Album_Chart
# #cite_note-173
# #cite_note-BB200-174
# /wiki/Pop_music
# /wiki/One_Direction
# /wiki/Midnight_Memories
# /wiki/Four_(One_Direction_album)
# #cite_note-BB200-174
# #cite_note-:7-127
# /wiki/Canadian_Albums_Chart
# /wiki/Billboard_Hot_100
# #cite_note-175
# /wiki/Canadian_Singles_Chart
# #cite_note-176
# /wiki/Taylor_Swift
# /wiki/Look_What_You_Made_Me_Do
# #cite_note-177
# #cite_note-178
# /wiki/File:Le_Citi_Field.jpg
# /wiki/File:Le_Citi_Field.jpg
# /wiki/Citi_Field
# /wiki/Love_Yourself:_Answer
# /wiki/BTS_World_Tour:_Love_Yourself
# /wiki/Seoul_Olympic_Stadium
# #cite_note-179
# /wiki/Steve_Aoki
# /wiki/Waste_It_On_Me
# #cite_note-180
# #cite_note-181
# /wiki/Citi_Field
# /wiki/Koreatown,_Long_Island
# #cite_note-182
# #cite_note-183
# /wiki/StubHub
# /wiki/Ed_Sheeran
# #cite_note-184
# /wiki/Vivid_Seats
# #cite_note-185
# /wiki/Uproxx
# /wiki/Staples_Center
# #cite_note-:02-186
# /wiki/MTV
# #cite_note-CF1-187
# #cite_note-188
# #cite_note-189
# /wiki/Simon_Wiesenthal_Center
# #cite_note-190
# /wiki/Nazism
# #cite_note-191
# #cite_note-192
# #cite_note-193
# /wiki/Burn_the_Stage:_The_Movie
# #cite_note-194
# /wiki/2018_Mnet_Asian_Music_Awards
# /wiki/Drake_(musician)
# /wiki/Taylor_Swift
# /wiki/Imagine_Dragons
# #cite_note-195
# #cite_note-196
# /wiki/50_Most_Influential_(Bloomberg_Markets_ranking)
# #cite_note-:18-197
# #cite_note-198
# /wiki/61st_Grammy_Awards
# #cite_note-199
# #cite_note-200
# /wiki/Grammy_Museum_at_L.A._Live
# #cite_note-201
# #cite_note-202
# /wiki/Spotify
# #cite_note-203
# /wiki/Time_(magazine)
# /wiki/Time_100
# #cite_note-204
# /wiki/Map_of_the_Soul:_Persona
# /wiki/Boy_With_Luv
# /wiki/Halsey_(singer)
# #cite_note-205
# /wiki/Saturday_Night_Live
# #cite_note-206
# #cite_note-207
# #cite_note-208
# #cite_note-209
# /wiki/The_Beatles
# /wiki/The_Monkees
# #cite_note-210
# #cite_note-211
# /wiki/List_of_best-selling_albums_in_South_Korea
# #cite_note-212
# #cite_note-213
# https://en.wikipedia.org/w/index.php?title=BTS&action=edit
# #cite_note-214
# /wiki/Australia
# #cite_note-215
# /wiki/Recording_Industry_Association_of_America
# #cite_note-216
# /wiki/British_Phonographic_Industry
# #cite_note-217
# #cite_note-218
# #cite_note-219
# /wiki/File:BTS_Love_Yourself_-_Speak_Yourself_tour_at_Rose_Bowl,_Pasadena_(California),_4_May_2019_04.jpg
# /wiki/File:BTS_Love_Yourself_-_Speak_Yourself_tour_at_Rose_Bowl,_Pasadena_(California),_4_May_2019_04.jpg
# /wiki/Pasadena,_California
# /wiki/Rose_Bowl_(stadium)
# /wiki/2019_Billboard_Music_Awards
# /wiki/Billboard_Music_Award_for_Top_Duo/Group
# /wiki/BTS_World_Tour_Love_Yourself:_Speak_Yourself
# /wiki/Wembley_Stadium
# /wiki/Stade_de_France
# /wiki/MetLife_Stadium
# /wiki/Rose_Bowl_(stadium)
# /wiki/Soldier_Field
# #cite_note-SYextension-220
# #cite_note-221
# #cite_note-222
# /wiki/Taylor_Swift
# /wiki/U2
# #cite_note-223
# #cite_note-224
# /wiki/The_Late_Show_with_Stephen_Colbert
# #cite_note-225
# /wiki/Good_Morning_America
# /wiki/Central_Park
# /wiki/Koreatown,_Manhattan
# #cite_note-226
# /wiki/The_Voice_(U.S._TV_series)
# #cite_note-227
# /wiki/Britain%27s_Got_Talent
# #cite_note-228
# /wiki/BTS_World
# /wiki/Dream_Glow
# /wiki/Charli_XCX
# #cite_note-229
# /wiki/A_Brand_New_Day_(BTS_and_Zara_Larsson_song)
# /wiki/Zara_Larsson
# #cite_note-230
# /wiki/All_Night_(BTS_and_Juice_Wrld_song)
# /wiki/Juice_Wrld
# #cite_note-231
# /wiki/Heartbeat_(BTS_song)
# /wiki/BTS_World:_Original_Soundtrack
# #cite_note-232
# /wiki/Gaon_Music_Chart
# #cite_note-233
# /wiki/Netmarble
# /wiki/IOS
# /wiki/Android_(operating_system)
# #cite_note-234
# /wiki/Lights_(BTS_song)
# #cite_note-235
# /wiki/Celine_Dion
# /wiki/To_Love_You_More
# #cite_note-236
# #cite_note-237
# /wiki/RIAJ
# #cite_note-238
# /wiki/Love_Yourself:_Her
# /wiki/Love_Yourself:_Tear
# #cite_note-239
# /wiki/Love_Yourself:_Answer
# #cite_note-240
# #cite_note-241
# #cite_note-242
# /wiki/King_Fahd_International_Stadium
# #cite_note-243
# /wiki/Love_Yourself_World_Tour
# #cite_note-244
# /wiki/Ed_Sheeran
# /wiki/Pink_(singer)
# #cite_note-245
# /wiki/Rolling_Stones
# /wiki/Metallica
# /wiki/Kiss_(band)
# /wiki/Backstreet_Boys
# #cite_note-246
# /wiki/Make_It_Right_(BTS_song)
# /wiki/Lauv
# #cite_note-247
# /wiki/American_Music_Awards_of_2019
# #cite_note-248
# /wiki/2019_Melon_Music_Awards
# /wiki/2019_Mnet_Asian_Music_Awards
# #cite_note-MMA2019sweep-249
# #cite_note-250
# #cite_note-251
# /wiki/Jonas_Brothers
# #cite_note-252
# #cite_note-253
# /wiki/Variety_(magazine)
# #cite_note-254
# #cite_note-255
# /wiki/New_York_City
# /wiki/Times_Square
# /wiki/American_Broadcasting_Company
# /wiki/Dick_Clark%27s_New_Year%27s_Rockin%27_Eve
# #cite_note-256
# /wiki/34th_Golden_Disc_Awards
# #cite_note-257
# /wiki/Nielsen_SoundScan
# /wiki/Taylor_Swift
# /wiki/Lover_(album)
# #cite_note-258
# /wiki/Billboard_(magazine)
# /wiki/Queen_(band)
# /wiki/Imagine_Dragons
# /wiki/The_Beatles
# #cite_note-259
# /wiki/International_Federation_of_the_Phonographic_Industry
# #cite_note-260
# #cite_note-261
# #cite_note-262
# /wiki/Arashi
# /wiki/5x20_All_the_Best!!_1999%E2%80%932019
# #cite_note-263
# /wiki/International_Federation_of_the_Phonographic_Industry
# #cite_note-264
# #cite_note-265
# /wiki/Black_Swan_(BTS_song)
# /wiki/Map_of_the_Soul:_7
# #cite_note-266
# #cite_note-267
# /wiki/Iriver_Inc
# /wiki/Map_of_the_Soul:_Persona
# #cite_note-268
# #cite_note-269
# #cite_note-270
# /wiki/Lil_Nas_X
# /wiki/Billy_Ray_Cyrus
# /wiki/Diplo
# /wiki/62nd_Annual_Grammy_Awards
# #cite_note-271
# #cite_note-272
# #cite_note-273
# #cite_note-274
# #cite_note-275
# /wiki/On_(song)
# /wiki/Sia_(musician)
# #cite_note-276
# /wiki/Billboard_200
# /wiki/Album-equivalent_unit
# /wiki/The_Beatles
# #cite_note-277
# #cite_note-278
# #cite_note-279
# /wiki/Billboard_Hot_100
# #cite_note-280
# #cite_note-281
# #cite_note-282
# /wiki/List_of_best-selling_albums_in_South_Korea
# #cite_note-283
# #cite_note-284
# #cite_note-topfive-285
# /wiki/Map_of_the_Soul_Tour
# /wiki/2019%E2%80%9320_coronavirus_outbreak
# #cite_note-286
# #cite_note-287
# //upload.wikimedia.org/wikipedia/commons/7/72/190601_Jin_Wembley_Stadium_Day_1_Ay-Oh_Chant.webm
# /wiki/File:190601_Jin_Wembley_Stadium_Day_1_Ay-Oh_Chant.webm
# /wiki/Freddie_Mercury
# /wiki/Wembley_Stadium
# /wiki/Seo_Taiji_and_Boys
# #cite_note-288
# /wiki/Nas
# /wiki/Eminem
# /wiki/Kanye_West
# /wiki/Drake_(musician)
# /wiki/Post_Malone
# /wiki/Charlie_Puth
# /wiki/Danger_(musician)
# #cite_note-289
# /wiki/Queen_(band)
# /wiki/Live_Aid
# /wiki/Freddie_Mercury
# #cite_note-290
# #cite_note-291
# /wiki/Hermann_Hesse
# /wiki/Demian
# #cite_note-292
# /wiki/Blood_Sweat_%26_Tears_(song)
# /wiki/Friedrich_Nietzsche
# /wiki/Thus_Spoke_Zarathustra
# /wiki/Herbert_James_Draper
# /wiki/The_Lament_for_Icarus
# /wiki/Pieter_Bruegel_the_Elder
# /wiki/Landscape_with_the_Fall_of_Icarus
# /wiki/The_Fall_of_the_Rebel_Angels_(Bruegel)
# #cite_note-293
# /wiki/Ursula_K._Le_Guin
# /wiki/The_Ones_Who_Walk_Away_from_Omelas
# #cite_note-294
# /wiki/Erich_Fromm
# /wiki/The_Art_of_Loving
# #cite_note-295
# /wiki/James_Doty_(physician)
# #cite_note-296
# #cite_note-297
# #cite_note-298
# #cite_note-299
# /wiki/Hip_hop
# #cite_note-:17-300
# #cite_note-:0-11
# #cite_note-301
# #cite_note-:17-300
# /wiki/Old-school_hip_hop
# #cite_note-BTSReview-21
# /wiki/Rhythm_and_blues
# /wiki/Rock_music
# #cite_note-mtviggy.com-302
# #cite_note-:15-43
# /wiki/Electronic_dance_music
# #cite_note-:16-64
# /wiki/Moombahton
# /wiki/Neo_soul
# /wiki/Gospel_music
# #cite_note-Vapp-303
# #cite_note-Review10-82
# /wiki/Future_bass
# /wiki/Latin_pop
# /wiki/Jazz_rap
# #cite_note-:6-112
# /wiki/Emo_rap
# /wiki/Rap_rock
# /wiki/Afro_pop
# /wiki/Nu-disco
# /wiki/Funk
# /wiki/Trap_music
# /wiki/Pop_rap
# #cite_note-rollingstonerev-304
# #cite_note-stereogumrev-305
# #cite_note-independent-review-306
# /wiki/Social_commentary
# /wiki/No_More_Dream
# /wiki/N.O_(BTS_song)
# #cite_note-:11-307
# /wiki/Dope_(BTS_song)
# /wiki/Silver_Spoon_(BTS_song)
# /wiki/Millennials
# #cite_note-:11-307
# /wiki/Am_I_Wrong_(BTS_song)
# /wiki/Wings_(BTS_album)
# /wiki/Ministry_of_Education_(South_Korea)
# /wiki/Caste
# /wiki/2016_South_Korean_political_scandal
# /wiki/Park_Geun-hye
# #cite_note-:11-307
# /wiki/Skool_Luv_Affair
# /wiki/The_Most_Beautiful_Moment_in_Life,_Pt._1
# /wiki/Forever_Rain
# #cite_note-308
# #cite_note-309
# /wiki/Not_Today_(BTS_song)
# /wiki/Anti-establishment
# #cite_note-Not_Today-310
# /wiki/Spring_Day_(song)
# /wiki/Sinking_of_MV_Sewol
# #cite_note-311
# #cite_note-:9-9
# #cite_note-:2-312
# #cite_note-:2-312
# /wiki/Wings_(BTS_album)
# #cite_note-:1-313
# #cite_note-:10-171
# #cite_note-:3-22
# #cite_note-314
# /wiki/RM_(rapper)
# #cite_note-:12-315
# /wiki/Suga_(rapper)
# #cite_note-316
# /wiki/Fuse_(magazine)
# #cite_note-:03-96
# /wiki/Moon_Jae-in
# #cite_note-317
# /wiki/File:BTS_performing_at_the_Korea-France_Friendship_Concert,_Paris_Treasure_Art_Theater,_14_October_2018.jpg
# /wiki/File:BTS_performing_at_the_Korea-France_Friendship_Concert,_Paris_Treasure_Art_Theater,_14_October_2018.jpg
# #cite_note-318
# /wiki/Time_(magazine)
# #cite_note-319
# /wiki/Billboard_charts
# /wiki/The_Beatles
# /wiki/The_Monkees
# #cite_note-320
# /wiki/Nielsen_Holdings
# #cite_note-321
# /wiki/Global_Recording_Artist_of_the_Year
# /wiki/Drake_(musician)
# #cite_note-322
# #cite_note-GAC2-323
# #cite_note-324
# /wiki/International_Federation_of_the_Phonographic_Industry
# #cite_note-325
# #cite_note-326
# #cite_note-327
# #cite_note-328
# /wiki/Billboard_(magazine)
# #cite_note-329
# #cite_note-330
# /wiki/Honorific_nicknames_in_popular_music
# #cite_note-331
# #cite_note-332
# #cite_note-333
# /wiki/Time_(magazine)
# #cite_note-334
# #cite_note-335
# /wiki/Time_100
# #cite_note-:142-336
# /wiki/CNN
# #cite_note-337
# /wiki/Parasite_(2019_film)
# /wiki/Bong_Joon-ho
# #cite_note-338
# /wiki/Bloomberg_Markets
# /wiki/50_Most_Influential_(Bloomberg_Markets_ranking)
# #cite_note-:182-339
# /wiki/Forbes_Korea_Power_Celebrity
# #cite_note-340
# #cite_note-KForbes2-341
# /wiki/Forbes
# /wiki/Forbes_Celebrity_100
# #cite_note-342
# /wiki/SDG
# /wiki/United_Nations
# /wiki/Malala_Yousafzai
# /wiki/Bill_Gates
# #cite_note-343
# #cite_note-344
# /wiki/California
# #cite_note-345
# #cite_note-346
# /wiki/United_Nations
# /wiki/United_Nations_General_Assembly
# #cite_note-:132-347
# #cite_note-RSIUN2-348
# /wiki/Moon_Jae-in
# #cite_note-349
# /wiki/Moon_Hee-sang
# #cite_note-350
# /wiki/Moon_Jae-in
# #cite_note-351
# /wiki/Ministry_of_Culture,_Sports_and_Tourism
# #cite_note-352
# /wiki/Gallup_(company)
# #cite_note-353
# /wiki/Korean_Culture_and_Information_Service
# #cite_note-354
# /wiki/Order_of_Cultural_Merit_(Korea)
# /wiki/President_of_South_Korea
# #cite_note-herald2-355
# #cite_note-356
# #cite_note-357
# #cite_note-358
# /wiki/Korean_Wave
# /wiki/Korea_Customs_Service
# /wiki/Korea_Foundation
# #cite_note-359
# /wiki/China%E2%80%93South_Korea_relations#Deployment_of_THAAD_in_South_Korea
# #cite_note-360
# /wiki/Korea_Creative_Content_Agency
# #cite_note-361
# /wiki/KB_Financial_Group_Inc
# /wiki/Billboard_200
# #cite_note-362
# #cite_note-363
# #cite_note-364
# /wiki/Netmarble
# /wiki/Soribada
# /wiki/Mattel
# #cite_note-365
# #cite_note-Mattell-366
# /wiki/Mattel
# #cite_note-367
# /wiki/Hyundai_Motor_Company
# #cite_note-368
# /wiki/Balance_of_payments
# #cite_note-369
# /wiki/Seoul_Metropolitan_Government
# /wiki/China%E2%80%93South_Korea_relations#Deployment_of_THAAD_in_South_Korea
# #cite_note-370
# #cite_note-371
# #cite_note-372
# /wiki/Seoul
# /wiki/Busan
# /wiki/Gross_domestic_product
# #cite_note-373
# /wiki/Love_Yourself_World_Tour
# #cite_note-374
# https://en.wikipedia.org/w/index.php?title=BTS&action=edit
# #cite_note-375
# /wiki/Korean_Air
# #cite_note-376
# /wiki/Interpark
# /wiki/Seoul_Olympic_Stadium
# #cite_note-377
# #cite_note-378
# /wiki/Wembley_Stadium
# /wiki/London
# #cite_note-379
# /wiki/Malta_(island)
# #cite_note-380
# /wiki/Ariana_Grande
# /wiki/Drake_(musician)
# #cite_note-381
# /wiki/(G)I-dle
# #cite_note-382
# /wiki/D-Crunch
# #cite_note-383
# /wiki/The_Boyz_(South_Korean_band)
# #cite_note-384
# /wiki/SF9_(band)
# #cite_note-385
# /wiki/Euna_Kim
# #cite_note-386
# /wiki/Golden_Child_(band)
# #cite_note-387
# /wiki/Wanna_One
# #cite_note-388
# /wiki/In2It
# #cite_note-389
# /wiki/Park_Ji-hoon
# #cite_note-390
# /wiki/Kim_Dong-han
# #cite_note-391
# #cite_note-392
# /wiki/Seven_O%27Clock_(band)
# #cite_note-393
# /wiki/Hyeongseop_X_Euiwoong
# #cite_note-394
# /wiki/Noir_(band)
# #cite_note-395
# /wiki/Victon
# #cite_note-396
# /wiki/Loona_(group)
# #cite_note-397
# /wiki/Idol_(BTS_song)
# /wiki/National_Gugak_Center
# #cite_note-398
# /wiki/RM_(rapper)
# /wiki/United_Nations
# #cite_note-399
# #cite_note-400
# /wiki/List_of_awards_and_nominations_received_by_BTS
# /wiki/Mnet_Asian_Music_Awards
# /wiki/Melon_Music_Awards
# /wiki/Golden_Disc_Awards
# /wiki/Seoul_Music_Awards
# /wiki/Gaon_Chart_Music_Awards
# /wiki/Billboard_Music_Award
# /wiki/Korean_Music_Awards
# /wiki/American_Music_Awards
# /wiki/MTV_Video_Music_Awards
# /wiki/Gaon_Music_Chart#Certification
# /wiki/Gaon_Music_Chart#Certification
# #cite_note-401
# #cite_note-402
# /wiki/Recording_Industry_Association_of_America
# /wiki/Music_recording_certification
# /wiki/Platinum_Single
# /wiki/Gold_single
# /wiki/Gold_album
# #cite_note-403
# /wiki/Recording_Industry_Association_of_Japan
# /wiki/Recording_Industry_Association_of_Japan
# #cite_note-404
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# #cite_note-405
# /wiki/British_Phonographic_Industry
# /wiki/British_Phonographic_Industry
# /wiki/Love_Yourself:_Tear
# /wiki/Love_Yourself:_Answer
# /wiki/Map_of_the_Soul:_Persona
# #cite_note-406
# #cite_note-407
# https://en.wikipedia.org/w/index.php?title=BTS&action=edit
# /wiki/Guinness_World_Records
# #cite_note-:14-140
# #cite_note-408
# /wiki/Order_of_Cultural_Merit_(Korea)
# /wiki/President_of_South_Korea
# #cite_note-herald-409
# /wiki/Recording_Academy
# /wiki/Grammy_Award
# #cite_note-410
# #cite_note-411
# #cite_note-412
# #cite_note-413
# /wiki/Puma_(brand)
# #cite_note-414
# #cite_note-415
# #cite_note-416
# #cite_note-417
# /wiki/Dior
# /wiki/Kim_Jones_(designer)
# /wiki/Stade_de_France
# /wiki/Business_of_Fashion
# #cite_note-418
# /wiki/Fila_(company)
# #cite_note-:19-419
# /wiki/LG_Electronics
# /wiki/LG_G7_ThinQ
# #cite_note-420
# /wiki/Hyundai_Motor_Company
# /wiki/LA_Auto_Show
# /wiki/Hyundai_Palisade
# #cite_note-421
# #cite_note-422
# /wiki/Lotte_Corporation
# #cite_note-423
# /wiki/Seoul_Metropolitan_Government
# #cite_note-424
# /wiki/Line_(software)
# /wiki/Line_Friends
# /wiki/Line_Friends#BT21
# #cite_note-425
# #cite_note-426
# /wiki/File:Line_FriendsStore_BT21_04.jpg
# /wiki/File:Line_FriendsStore_BT21_04.jpg
# /wiki/Line_Friends#BT21
# /wiki/Line_Friends
# /wiki/Mapo_District
# /wiki/Seoul
# /wiki/Webtoon
# /wiki/Save_Me_(webtoon)
# /wiki/Line_Webtoon
# #cite_note-427
# #cite_note-428
# #cite_note-429
# /wiki/Mattel
# /wiki/Idol_(BTS_song)
# #cite_note-Mattell-366
# /wiki/Kubrick_(toy)
# #cite_note-430
# /wiki/Funko
# #cite_note-431
# /wiki/Nexon
# /wiki/Role-playing_game
# /wiki/Elsword
# #cite_note-432
# #cite_note-433
# /wiki/Netmarble_Games
# /wiki/BTS_World
# #cite_note-434
# /wiki/Casetify
# #cite_note-435
# /wiki/KB_Kookmin_Bank
# #cite_note-436
# #cite_note-437
# #cite_note-438
# /wiki/The_Coca-Cola_Company
# #cite_note-439
# /wiki/2018_FIFA_World_Cup
# #cite_note-440
# #cite_note-441
# #cite_note-442
# #cite_note-443
# #cite_note-444
# #cite_note-445
# #cite_note-446
# /wiki/Map_of_the_Soul:_Persona
# /wiki/Plum_Blossom
# #cite_note-447
# /wiki/Tokopedia
# #cite_note-448
# /wiki/Formula_E
# /wiki/Formula_E
# #cite_note-449
# /wiki/Hyundai_Motors
# /wiki/Hydrogen_vehicle
# /wiki/Fuel_cell_vehicle
# /wiki/Sport_utility_vehicle
# /wiki/Hyundai_Nexo
# #cite_note-450
# /wiki/Samsung_Electronics
# #cite_note-451
# /wiki/Love_Myself_(campaign)
# /wiki/Apgujeong-dong
# #cite_note-Rice_Donation-452
# #cite_note-Allet_Campaign-453
# #cite_note-454
# /wiki/File:BTS_Love_Myself_Logo.png
# /wiki/File:BTS_Love_Myself_Logo.png
# /wiki/Love_Myself_(campaign)
# /wiki/Sinking_of_MV_Sewol
# #cite_note-Sewol_Donation-455
# /wiki/Love_Myself_(campaign)
# /wiki/UNICEF
# #cite_note-456
# #cite_note-bbun-457
# #cite_note-458
# /wiki/Love_Yourself:_Her
# /wiki/Love_Yourself:_Tear
# /wiki/Love_Yourself:_Answer
# #cite_note-bbun-457
# #cite_note-459
# #cite_note-460
# #cite_note-461
# /wiki/Stevie_Wonder
# /wiki/Martin_Luther_King_Jr.
# #cite_note-462
# /wiki/Amyotrophic_lateral_sclerosis
# #cite_note-463
# /wiki/United_Nations
# /wiki/United_Nations_General_Assembly
# #cite_note-RSIUN-464
# #cite_note-CBSUN-465
# #cite_note-:13-466
# #cite_note-RSIUN-464
# #cite_note-467
# #cite_note-RSIUN-464
# #cite_note-CBSUN-465
# /wiki/Starbucks_Corporation
# #cite_note-468
# /wiki/Grammy_Award
# /wiki/Love_Yourself_World_Tour
# /wiki/MusiCares
# /wiki/Music_community
# #cite_note-469
# /wiki/File:BTS_Universe_logo.png
# /wiki/File:BTS_Universe_logo.png
# /wiki/Parallel_universes_in_fiction
# /wiki/Big_Hit_Entertainment
# /wiki/Webtoon
# /wiki/Save_Me_(webtoon)
# #cite_note-470
# #cite_note-471
# /wiki/I_Need_U_(BTS_song)
# #cite_note-472
# #cite_note-473
# #cite_note-474
# /wiki/Picture_book
# /wiki/Korean_drama
# /wiki/Chorokbaem_Media
# #cite_note-475
# #cite_note-476
# /wiki/Billboard_(magazine)
# #cite_note-477
# /wiki/The_Ones_Who_Walk_Away_from_Omelas
# #cite_note-478
# #cite_note-479
# #cite_note-480
# #cite_note-481
# /wiki/London
# /wiki/Berlin
# /wiki/Buenos_Aires
# /wiki/Seoul
# /wiki/New_York_City
# #cite_note-cnn-482
# #cite_note-billb-483
# /wiki/Serpentine_Galleries
# #cite_note-cnn-482
# /wiki/Brooklyn_Bridge
# /wiki/Antony_Gormley
# #cite_note-484
# /wiki/BBC
# /wiki/Tom%C3%A1s_Saraceno
# /wiki/Dongdaemun_Design_Plaza
# /wiki/Ann_Veronica_Janssens
# /wiki/Martin-Gropius-Bau
# #cite_note-bbc-485
# /wiki/Kim_Seok-jin
# #cite_note-486
# /wiki/Suga_(rapper)
# #cite_note-487
# /wiki/J-Hope
# #cite_note-488
# /wiki/RM_(rapper)
# #cite_note-489
# /wiki/Jimin_(singer,_born_1995)
# #cite_note-490
# /wiki/V_(singer)
# #cite_note-491
# /wiki/Jungkook
# #cite_note-492
# /wiki/BTS_albums_discography
# /wiki/BTS_singles_discography
# /wiki/Dark_%26_Wild
# /wiki/Wings_(BTS_album)
# /wiki/Love_Yourself:_Tear
# /wiki/Map_of_the_Soul:_7
# /wiki/Wake_Up_(BTS_album)
# /wiki/Youth_(BTS_album)
# /wiki/Face_Yourself
# /wiki/List_of_BTS_live_performances
# /wiki/The_Red_Bullet_Tour
# /wiki/Wake_Up_(BTS_album)#Promotion
# /wiki/The_Most_Beautiful_Moment_in_Life_On_Stage_Tour
# /wiki/The_Wings_Tour
# /wiki/Love_Yourself_World_Tour
# /wiki/Map_of_the_Soul_Tour
# /wiki/BTS_videography
# #cite_note-493
# #cite_note-494
# #cite_note-495
# #cite_note-496
# /wiki/Burn_the_Stage:_The_Movie
# #cite_note-497
# /wiki/Love_Yourself_in_Seoul
# #cite_note-498
# /wiki/Bring_the_Soul:_The_Movie
# #cite_note-499
# /wiki/SBS_MTV
# #cite_note-500
# /wiki/YinYueTai
# #cite_note-501
# /wiki/Mnet_(TV_channel)
# #cite_note-502
# #cite_note-503
# /wiki/Run_BTS!
# /wiki/Mnet_(TV_channel)
# #cite_note-KH1-504
# /wiki/JTBC
# #cite_note-505
# #cite_note-506
# /wiki/V_Live_(website)
# #cite_note-507
# #cite_note-508
# /wiki/Run_BTS!
# #cite_note-509
# #cite_note-510
# #cite_note-511
# /wiki/YouTube_Premium
# /wiki/2017_BTS_Live_Trilogy_Episode_III:_The_Wings_Tour
# #cite_note-512
# /wiki/Love_Yourself_World_Tour
# #cite_note-513
# #cite_ref-1
# http://www.universal-music.co.jp/bts/news/2017/03/23/
# /wiki/Universal_Music_Group
# https://web.archive.org/web/20170324175800/http://www.universal-music.co.jp/bts/news/2017/03/23/
# #cite_ref-2
# /wiki/Roger_Friedman
# http://www.showbiz411.com/2018/08/24/crazy-rich-asians-south-korean-boy-band-bts-first-us-release-explodes-gangnam-style-swamps-itunes-singles-album-charts
# /wiki/Showbiz411
# #cite_ref-3
# https://www.vulture.com/2018/10/bts-renews-contract-with-bighit-for-7-more-years.html
# #cite_ref-4
# http://www.gaonchart.co.kr/main/section/article/view.gaon?idx=15713&sgenre=opinion
# https://web.archive.org/web/20190829090631/http://www.gaonchart.co.kr/main/section/article/view.gaon?idx=15713&sgenre=opinion
# #cite_ref-5
# http://www.newsen.com/news_view.php?uid=201506221820303510
# #cite_ref-6
# https://web.archive.org/web/20190329161534/http://affinitymagazine.us/2016/05/29/its-about-time-you-know-why-bts-is-trending/
# http://affinitymagazine.us/2016/05/29/its-about-time-you-know-why-bts-is-trending/
# #cite_ref-7
# https://www.universal-music.co.jp/bts/
# #cite_ref-newname_8-0
# http://entertain.naver.com/read?oid=009&aid=0003973387
# https://web.archive.org/web/20170812172014/http://entertain.naver.com/read?oid=009&aid=0003973387
# #cite_ref-:9_9-0
# #cite_ref-:9_9-1
# https://web.archive.org/web/20171011234847/https://www.behance.net/gallery/55324473/BTS-Brand-eXperience-Design-Renewal
# /wiki/Behance
# https://www.behance.net/gallery/55324473/BTS-Brand-eXperience-Design-Renewal
# #cite_ref-10
# https://www.youtube.com/watch?v=p9AutAQ33ro
# #cite_ref-:0_11-0
# #cite_ref-:0_11-1
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9791186559116
# #cite_ref-12
# https://www.vox.com/culture/2018/6/13/17426350/bts-history-members-explained
# /wiki/Vox_(website)
# #cite_ref-13
# https://entertain.naver.com/read?oid=001&aid=0004699382
# #cite_ref-14
# http://star.mt.co.kr/stview.php?no=2010090211500915414
# https://web.archive.org/web/20170422124040/http://star.mt.co.kr/stview.php?no=2010090211500915414
# #cite_ref-15
# http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201107130906421116
# https://web.archive.org/web/20170422141636/http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201107130906421116
# #cite_ref-16
# http://time.com/collection-post/5414052/bts-next-generation-leaders/
# /wiki/Time_(magazine)
# #cite_ref-17
# http://bntnews.co.uk/app/news.php?nid=3882
# https://web.archive.org/web/20150518090435/http://bntnews.co.uk/app/news.php?nid=3882
# http://mwave.interest.me/enewsworld/en/article/38336/bts-releases-debut-video
# https://web.archive.org/web/20150205172617/http://mwave.interest.me/enewsworld/en/article/38336/bts-releases-debut-video
# #cite_ref-18
# https://web.archive.org/web/20160828194450/http://gaonchart.co.kr/main/section/chart/online.gaon?PageNo=2&nationGbn=T&serviceGbn=ALL&targetTime=25&hitYear=2013&termGbn=week
# http://gaonchart.co.kr/main/section/chart/online.gaon?PageNo=2&nationGbn=T&serviceGbn=ALL&targetTime=25&hitYear=2013&termGbn=week
# #cite_ref-19
# https://web.archive.org/web/20170707202306/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=K&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2016&hitYear=2016&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2017&hitYear=2017&termGbn=year
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month
# #cite_ref-20
# http://gaonchart.co.kr/main/section/chart/online.gaon?PageNo=2&nationGbn=T&serviceGbn=ALL&targetTime=25&hitYear=2013&termGbn=week
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=S1020&targetTime=25&hitYear=2013&termGbn=week
# #cite_ref-BTSReview_21-0
# #cite_ref-BTSReview_21-1
# #cite_ref-BTSReview_21-2
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9788925565828
# #cite_ref-:3_22-0
# #cite_ref-:3_22-1
# #cite_ref-:3_22-2
# http://www.ize.co.kr/articleView.html?no=2019040102057238751
# #cite_ref-:4_23-0
# #cite_ref-:4_23-1
# http://mosen.mt.co.kr/article/G1109617843
# #cite_ref-24
# http://mosen.mt.co.kr/article/G1109618986
# #cite_ref-Japan_Debut_25-0
# http://news.kstyle.com/article.ksn?articleNo=1990114
# #cite_ref-26
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=38&hitYear=2013&termGbn=week
# https://web.archive.org/web/20190116184957/http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=38&hitYear=2013&termGbn=week
# #cite_ref-27
# https://web.archive.org/web/20170707202306/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2013&hitYear=2013&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?termGbn=year&hitYear=2016&targetTime=2016&nationGbn=K
# http://gaonchart.co.kr/main/section/chart/album.gaon?termGbn=year&hitYear=2017&targetTime=2017&nationGbn=K
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month
# #cite_ref-28
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9788925565828
# #cite_ref-29
# http://www.kwnews.co.kr/nview.asp?s=801&aid=213091100183
# #cite_ref-30
# http://sports.chosun.com/news/ntype.htm?id=201308290100252680019119&servicedate=20130828
# #cite_ref-31
# http://www.melon.com/melonaward/yearlyaward.htm
# /wiki/Melon_(online_music_service)
# https://web.archive.org/web/20180224011714/http://isplus.live.joins.com/award/29goldendisc/en/last_winner.aspx?%23main_menu#main_menu
# http://isplus.live.joins.com/award/29goldendisc/en/last_winner.aspx?#main_menu
# http://seoulmusicawards.com/history/winner
# https://web.archive.org/web/20180223195443/http://seoulmusicawards.com/history/winner
# #cite_ref-sla_32-0
# #cite_ref-sla_32-1
# https://www.billboard.com/articles/columns/k-town/8455612/bts-takeover-timeline-bbmas
# /wiki/Billboard_(magazine)
# #cite_ref-33
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2016&hitYear=2016&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2017&hitYear=2017&termGbn=year
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month
# #cite_ref-World_chart_34-0
# https://www.billboard.com/music/bts/chart-history/world-albums
# /wiki/Billboard_(magazine)
# #cite_ref-35
# https://www.youtube.com/watch?v=m8MfJg68oCs
# https://web.archive.org/web/20150729070329/https://www.youtube.com/watch?v=m8MfJg68oCs
# http://mwave.interest.me/enewsworld/en/article/62983/bts-releases-mv
# https://web.archive.org/web/20151121133843/http://mwave.interest.me/enewsworld/en/article/62983/bts-releases-mv
# #cite_ref-36
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9788925565828
# #cite_ref-37
# http://www.tvreport.co.kr/?c=news&m=newsview&idx=463054
# #cite_ref-38
# http://m.star.naver.com/bts/news/end?id=2612217
# #cite_ref-39
# https://www.billboard.com/articles/news/6157532/bts-announces-free-surprise-los-angeles-concert
# #cite_ref-40
# http://www.latimes.com/entertainment/music/posts/la-et-ms-girls-generation-bangtan-boys-headline-kcon-2014-20140521-story.html
# https://web.archive.org/web/20141009221756/http://www.latimes.com/entertainment/music/posts/la-et-ms-girls-generation-bangtan-boys-headline-kcon-2014-20140521-story.html
# #cite_ref-41
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2014&hitYear=2014&termGbn=year
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=11&hitYear=2017&termGbn=month
# #cite_ref-42
# http://mwave.interest.me/enewsworld/en/article/78799/bts-releases-mv
# https://web.archive.org/web/20151208071048/http://mwave.interest.me/enewsworld/en/article/78799/bts-releases-mv
# #cite_ref-:15_43-0
# #cite_ref-:15_43-1
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9788925565828
# #cite_ref-44
# http://enter.etoday.co.kr/view/news_view.php?varAtcId=18836
# #cite_ref-45
# http://news1.kr/articles/?1824877
# #cite_ref-TRB_II_46-0
# #cite_ref-TRB_II_46-1
# http://news.sbs.co.kr/news/endPage.do?news_id=N1003147018&plink=SEARCH&cooper=SBSNEWSSEARCH
# https://web.archive.org/web/20170422141734/http://news.sbs.co.kr/news/endPage.do?news_id=N1003147018&plink=SEARCH&cooper=SBSNEWSSEARCH
# #cite_ref-oricon_47-0
# http://www.oricon.co.jp/prof/530375/rank/album/
# /wiki/Oricon
# https://www.oricon.co.jp/news/2078320/full/
# /wiki/Oricon
# #cite_ref-48
# https://itunes.apple.com/jp/album/wake-up-tong-chang-pan/id948185423?l=en
# /wiki/ITunes
# https://web.archive.org/web/20170422130845/https://itunes.apple.com/jp/album/wake-up-tong-chang-pan/id948185423?l=en
# #cite_ref-49
# http://mwave.interest.me/enewsworld/en/article/87818/bts-wraps-up-concert-tour-in-japan-gathering-25000-fans
# https://web.archive.org/web/20151222111014/http://mwave.interest.me/enewsworld/en/article/87818/bts-wraps-up-concert-tour-in-japan-gathering-25000-fans
# #cite_ref-BTS_Begin_50-0
# http://mwave.interest.me/en/kpop-news/article/87064/video-bts-to-hold-second-exclusive-concert-in-seoul
# https://web.archive.org/web/20170106122508/http://mwave.interest.me/en/kpop-news/article/87064/video-bts-to-hold-second-exclusive-concert-in-seoul
# #cite_ref-Review6_51-0
# #cite_ref-Review6_51-1
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9788925565828
# #cite_ref-:5_52-0
# http://tenasia.hankyung.com/archives/510280
# #cite_ref-53
# http://www.fuse.tv/2015/06/best-albums-2015-so-far#24
# /wiki/Fuse_(TV_channel)
# https://web.archive.org/web/20150625213652/http://www.fuse.tv/2015/06/best-albums-2015-so-far#24
# #cite_ref-54
# https://web.archive.org/web/20170707202644/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2015&hitYear=2015&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2016&hitYear=2016&termGbn=year
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=2017&hitYear=2017&termGbn=year
# http://www.gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=09&hitYear=2018&termGbn=month
# #cite_ref-55
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=19&hitYear=2015&termGbn=week
# #cite_ref-INU_Wins_56-0
# http://osen.mt.co.kr/article/G1110151107
# #cite_ref-57
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=28&hitYear=2015&termGbn=week
# #cite_ref-58
# http://www.billboard.com/biz/charts/2015-07-11/world-digital-songs
# /wiki/Billboard_(magazine)
# https://web.archive.org/web/20171103235802/http://www.billboard.com/biz/charts/2015-07-11/world-digital-songs
# #cite_ref-Dope_100mil_59-0
# http://english.yonhapnews.co.kr/news/2016/10/25/0200000000AEN20161025005300315.html
# https://web.archive.org/web/20161030095321/http://english.yonhapnews.co.kr/news/2016/10/25/0200000000AEN20161025005300315.html
# #cite_ref-For_You_Oricon_60-0
# https://web.archive.org/web/20150620105214/https://www.oricon.co.jp/rank/js/d/2015-06-18/
# /wiki/Oricon
# https://www.oricon.co.jp/rank/js/d/2015-06-18/
# #cite_ref-61
# http://www.summersonic.com/2015/lineup/
# https://web.archive.org/web/20150314181031/http://www.summersonic.com/2015/lineup/
# #cite_ref-62
# http://mwave.interest.me/enewsworld/en/article/96992/bts-fan-meeting-in-japan-a-roaring-success
# https://web.archive.org/web/20150824211118/http://mwave.interest.me/enewsworld/en/article/96992/bts-fan-meeting-in-japan-a-roaring-success
# #cite_ref-63
# http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201510280801961138&ext=na
# https://web.archive.org/web/20151031180434/http://www.mydaily.co.kr/new_yk/html/read.php?newsid=201510280801961138&ext=na
# #cite_ref-:16_64-0
# #cite_ref-:16_64-1
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9788925565828
# #cite_ref-65
# https://web.archive.org/web/20151211012235/http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=50&hitYear=2015&termGbn=week
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=&targetTime=50&hitYear=2015&termGbn=week
# #cite_ref-66
# http://www.billboard.com/articles/columns/k-town/6835246/bts-most-beautiful-moment-in-life-pt-2-returns-no-1-world-albums
# /wiki/Billboard_(magazine)
# https://web.archive.org/web/20160623000816/http://www.billboard.com/articles/columns/k-town/6835246/bts-most-beautiful-moment-in-life-pt-2-returns-no-1-world-albums
# #cite_ref-67
# https://www.billboard.com/articles/columns/k-town/6786050/bts-most-beautiful-moment-in-life-pt-2-billboard-200-charts
# #cite_ref-68
# https://itunes.apple.com/us/album/화양연화-the-most-beautiful-moment-in-life-young-forever/id1109292307
# #cite_ref-69
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=19&hitYear=2016&termGbn=week
# #cite_ref-70
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=ALL&targetTime=19&hitYear=2016&termGbn=week
# /wiki/Gaon_Chart
# #cite_ref-71
# http://gaonchart.co.kr/main/section/chart/album.gaon?nationGbn=T&serviceGbn=ALL&targetTime=20&hitYear=2016&termGbn=week
# /wiki/Gaon_Chart
# #cite_ref-72
# http://www.billboard.com/artist/5912948/bts/chart
# /wiki/Billboard_(magazine)
# https://web.archive.org/web/20160719224117/http://www.billboard.com/artist/5912948/bts/chart
# #cite_ref-73
# http://english.yonhapnews.co.kr/search1/2603000000.html?cid=AEN20161119003200315
# https://web.archive.org/web/20170422131453/http://english.yonhapnews.co.kr/search1/2603000000.html?cid=AEN20161119003200315
# #cite_ref-74
# https://www.inquisitr.com/3243751/bts-has-already-dominated-their-2016-asia-tour-all-144000-tickets-in-upcoming-shows-in-china-japan-thailand-and-philippines-sold-out/
# #cite_ref-May_2016_Comeback_75-0
# http://kpopherald.koreaherald.com/view.php?ud=201603211315030316684_2
# https://web.archive.org/web/20170422142624/http://kpopherald.koreaherald.com/view.php?ud=201603211315030316684_2
# #cite_ref-76
# https://www.billboard.com/articles/columns/k-town/7341599/bts-headline-kcon-ny-twice-added-kcon-la-lineup
# #cite_ref-Kcon_2016_77-0
# http://www.fuse.tv/2016/05/bts-kcon-2016-la-lineup-headliner
# https://web.archive.org/web/20170422123405/http://www.fuse.tv/2016/05/bts-kcon-2016-la-lineup-headliner
# #cite_ref-78
# http://www.billboard.com/articles/columns/k-town/7370335/bts-twitter-custom-k-pop-emoji-biggest-fans
# /wiki/Billboard_(magazine)
# https://web.archive.org/web/20160616095342/http://www.billboard.com/articles/columns/k-town/7370335/bts-twitter-custom-k-pop-emoji-biggest-fans
# #cite_ref-INU_Japanese_79-0
# http://news.kstyle.com/article.ksn?articleNo=2032731
# http://news.kstyle.com/article.ksn?articleNo=2038872
# https://web.archive.org/web/20160311005240/http://news.kstyle.com/article.ksn?articleNo=2038872
# #cite_ref-80
# https://web.archive.org/web/20160908010233/http://www.oricon.co.jp/rank/ja/d/2016-09-06/
# http://www.oricon.co.jp/rank/ja/d/2016-09-06/
# #cite_ref-500k_presale_81-0
# http://kpopherald.koreaherald.com/view.php?ud=201610071627260331797_2
# https://web.archive.org/web/20161008182855/http://kpopherald.koreaherald.com/view.php?ud=201610071627260331797_2
# #cite_ref-Review10_82-0
# #cite_ref-Review10_82-1
# #cite_ref-Review10_82-2
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9788925565828
# #cite_ref-83
# https://www.rollingstone.com/music/lists/10-new-artists-you-need-to-know-july-2017-w491865
# #cite_ref-84
# http://www.fuse.tv/2016/12/best-albums-of-the-year-2016#8
# /wiki/Fuse_(TV_channel)
# #cite_ref-85
# http://english.yonhapnews.co.kr/search1/2603000000.html?cid=AEN20161011003400315
# /wiki/Yonhap
# https://web.archive.org/web/20161013231510/http://english.yonhapnews.co.kr/search1/2603000000.html?cid=AEN20161011003400315
# #cite_ref-86
# http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=42&hitYear=2016&termGbn=week
# https://web.archive.org/web/20161220062629/http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL&targetTime=42&hitYear=2016&termGbn=week
# #cite_ref-BST_Youtube_Records_87-0
# http://en.yibada.com/articles/169424/20161024/bts-blood-sweat-and-tears-kpop-wings.htm
# https://web.archive.org/web/20161025234810/http://en.yibada.com/articles/169424/20161024/bts-blood-sweat-and-tears-kpop-wings.htm
# #cite_ref-88
# http://www.billboard.com/articles/columns/k-town/7542131/bts-wings-highest-charting-best-selling-kpop-album-billboard-200
# https://web.archive.org/web/20161019095818/http://www.billboard.com/articles/columns/k-town/7542131/bts-wings-highest-charting-best-selling-kpop-album-billboard-200
# #cite_ref-89
# http://www.billboard.com/charts/social-50
# /wiki/Billboard_(magazine)
# https://web.archive.org/web/20161023070027/http://www.billboard.com/charts/social-50
# #cite_ref-90
# http://english.yonhapnews.co.kr/search1/2603000000.html?cid=AEN20170309012000315
# https://web.archive.org/web/20170422141319/http://english.yonhapnews.co.kr/search1/2603000000.html?cid=AEN20170309012000315
# #cite_ref-91
# http://mwave.interest.me/en/kpop-news/article/109989/bts-wings-becomes-highest-selling-album-on-goan-chart-all-kpop-news
# https://web.archive.org/web/20161122073955/http://mwave.interest.me/en/kpop-news/article/109989/bts-wings-becomes-highest-selling-album-on-goan-chart-all-kpop-news
# #cite_ref-92
# http://english.yonhapnews.co.kr/search1/2603000000.html?cid=AEN20161203000400315
# ...
# /wiki/Shin_Seung-hun
# /wiki/Kim_Gun-mo
# /wiki/Kim_Gun-mo
# /wiki/Kim_Gun-mo
# /wiki/H.O.T
# /wiki/Kim_Jong-hwan_(singer)
# /wiki/Jo_Sung-mo
# /wiki/Jo_Sung-mo
# /wiki/Chapter_4_(g.o.d_album)
# /wiki/G.o.d
# /wiki/Cool_(South_Korean_band)
# /wiki/Jo_Sung-mo
# /wiki/The_Colors_of_My_Life
# /wiki/Lee_Soo-young
# /wiki/Saldaga
# /wiki/SG_Wannabe
# /wiki/%22O%22-Jung.Ban.Hap.
# /wiki/TVXQ
# /wiki/The_Sentimental_Chord
# /wiki/SG_Wannabe
# /wiki/Mirotic
# /wiki/TVXQ
# /wiki/Sorry,_Sorry
# /wiki/Super_Junior
# /wiki/Oh!_(Girls%27_Generation_album)
# /wiki/Girls%27_Generation
# /wiki/Mr._Simple
# /wiki/Super_Junior
# /wiki/Sexy,_Free_%26_Single
# /wiki/Super_Junior
# /wiki/XOXO_(album)
# /wiki/Exo_(band)
# /wiki/Overdose_(EP)
# /wiki/Exo_(band)
# /wiki/Exodus_(Exo_album)
# /wiki/Exo_(band)
# /wiki/Ex%27Act
# /wiki/Exo_(band)
# /wiki/Love_Yourself:_Her
# /wiki/Love_Yourself:_Answer
# /wiki/Map_of_the_Soul:_Persona
# /wiki/Ivy_(South_Korean_singer)
# /wiki/SG_Wannabe
# /wiki/Jewelry_(band)
# /wiki/Gee_(Girls%27_Generation_song)
# /wiki/Girls%27_Generation
# /wiki/Can%27t_Let_You_Go_Even_If_I_Die
# /wiki/2AM_(band)
# /wiki/The_Boys_(Girls%27_Generation_song)
# /wiki/Girls%27_Generation
# /wiki/Gangnam_Style
# /wiki/PSY
# /wiki/Gentleman_(Psy_song)
# /wiki/PSY
# /wiki/Eyes,_Nose,_Lips
# /wiki/Taeyang
# /wiki/Loser_(Big_Bang_song)
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Cheer_Up_(song)
# /wiki/Twice_(band)
# /wiki/Through_the_Night_(IU_song)
# /wiki/IU_(singer)
# /wiki/Love_Scenario
# /wiki/IKon
# /wiki/Boy_with_Luv
# /wiki/Template:Seoul_Music_Awards_Grand_Prize_Winners
# /wiki/Template_talk:Seoul_Music_Awards_Grand_Prize_Winners
# https://en.wikipedia.org/w/index.php?title=Template:Seoul_Music_Awards_Grand_Prize_Winners&action=edit
# /wiki/Seoul_Music_Awards#Daesang_Award_.28Grand_Prize.29
# /wiki/Byun_Jin-sub
# /wiki/Tae_Jin-ah
# /wiki/Seo_Taiji_and_Boys
# /wiki/Kim_Gun-mo
# /wiki/Roo%27ra
# /wiki/Clon_(duo)
# /wiki/H.O.T._(band)
# /wiki/Sechs_Kies
# /wiki/Jo_Sung-mo
# /wiki/Fin.K.L
# /wiki/Jo_Sung-mo
# /wiki/Kim_Gun-mo
# /wiki/BoA
# /wiki/Lee_Hyori
# /wiki/Shinhwa
# /wiki/TVXQ
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Wonder_Girls
# /wiki/Girls%27_Generation
# /wiki/Super_Junior
# /wiki/Psy
# /wiki/Exo_(band)
# /wiki/Map_of_the_Soul:_Persona
# /wiki/Four_Seasons_(song)
# /wiki/Taeyeon
# /wiki/Template:Forbes_Korea_Power_Celebrity
# /wiki/Template_talk:Forbes_Korea_Power_Celebrity
# https://en.wikipedia.org/w/index.php?title=Template:Forbes_Korea_Power_Celebrity&action=edit
# /wiki/Forbes_Korea_Power_Celebrity
# /wiki/Yuna_Kim
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Wonder_Girls
# /wiki/Lee_Hyori
# /wiki/Girls%27_Generation
# /wiki/Park_Ji-sung
# /wiki/Lee_Seung-yuop
# /wiki/Rain_(entertainer)
# /wiki/Yoo_Jae-suk
# /wiki/Kim_Tae-hee
# /wiki/Yuna_Kim
# /wiki/Girls%27_Generation
# /wiki/Park_Ji-sung
# /wiki/Lee_Byung-hun
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Go_Hyun-jung
# /wiki/Lee_Seung-gi
# /wiki/Lee_Hyori
# /wiki/Yoo_Jae-suk
# /wiki/Kang_Ho-dong
# /wiki/Girls%27_Generation
# /wiki/Park_Ji-sung
# /wiki/Yuna_Kim
# /wiki/Lee_Seung-gi
# /wiki/2PM
# /wiki/Yoo_Jae-suk
# /wiki/Lee_Chung-yong
# /wiki/2AM_(band)
# /wiki/Shin-Soo_Choo
# /wiki/Kang_Ho-dong
# /wiki/Girls%27_Generation
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/IU_(singer)
# /wiki/Kara_(South_Korean_band)
# /wiki/Yuna_Kim
# /wiki/Lee_Seung-gi
# /wiki/Park_Ji-sung
# /wiki/Kim_Tae-hee
# /wiki/Beast_(South_Korean_band)
# /wiki/Park_Tae-hwan
# /wiki/Psy
# /wiki/Girls%27_Generation
# /wiki/Son_Yeon-jae
# /wiki/Kim_Soo-hyun
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Park_Tae-hwan
# /wiki/Song_Joong-ki
# /wiki/IU_(singer)
# /wiki/Yuna_Kim
# /wiki/Super_Junior
# /wiki/Girls%27_Generation
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Bae_Suzy
# /wiki/Hyun-jin_Ryu
# /wiki/Exo_(band)
# /wiki/Shin-Soo_Choo
# /wiki/TVXQ
# /wiki/Shinee
# /wiki/Yuna_Kim
# /wiki/IU_(singer)
# /wiki/Exo_(band)
# /wiki/Kim_Soo-hyun
# /wiki/Yuna_Kim
# /wiki/Jun_Ji-hyun
# /wiki/Son_Yeon-jae
# /wiki/Lee_Seung-gi
# /wiki/Hyun-jin_Ryu
# /wiki/Son_Heung-min
# /wiki/Girls%27_Generation
# /wiki/Sistar
# /wiki/Exo_(band)
# /wiki/Yoo_Ah-in
# /wiki/Lee_Hye-ri
# /wiki/Girls%27_Generation
# /wiki/Kim_Soo-hyun
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Inbee_Park
# /wiki/Jun_Ji-hyun
# /wiki/IU_(singer)
# /wiki/Jung-ho_Kang
# /wiki/Park_Bo-gum
# /wiki/Song_Joong-ki
# /wiki/Twice_(band)
# /wiki/Exo_(band)
# /wiki/Bae_Suzy
# /wiki/Song_Hye-kyo
# /wiki/Kim_Yoo-jung
# /wiki/Jo_Jung-suk
# /wiki/Seung-hwan_Oh
# /wiki/Wanna_One
# /wiki/Twice_(band)
# /wiki/Exo_(band)
# /wiki/IU_(singer)
# /wiki/Song_Hye-kyo
# /wiki/Song_Joong-ki
# /wiki/Park_Bo-gum
# /wiki/Yuna_Kim
# /wiki/Hyun-jin_Ryu
# /wiki/Blackpink
# /wiki/Wanna_One
# /wiki/Kang_Daniel
# /wiki/Red_Velvet_(group)
# /wiki/Park_Na-rae_(comedian)
# /wiki/Hong_Jin-young
# /wiki/Han_Ji-min
# /wiki/Son_Heung-min
# /wiki/Exo_(band)
# /wiki/Template:Mnet_Asian_Music_Award_for_Album_of_the_Year
# /w/index.php?title=Template_talk:Mnet_Asian_Music_Award_for_Album_of_the_Year&action=edit&redlink=1
# https://en.wikipedia.org/w/index.php?title=Template:Mnet_Asian_Music_Award_for_Album_of_the_Year&action=edit
# /wiki/Mnet_Asian_Music_Award_for_Album_of_the_Year
# /wiki/The_3rd_Masterpiece
# /wiki/SG_Wannabe
# /wiki/Remapping_the_Human_Soul
# /wiki/Epik_High
# /wiki/Mirotic
# /wiki/TVXQ
# /wiki/Heartbreaker_(G-Dragon_album)
# /wiki/G-Dragon
# /wiki/To_Anyone
# /wiki/2NE1
# /wiki/Mr._Simple
# /wiki/Super_Junior
# /wiki/Sexy,_Free_%26_Single
# /wiki/Super_Junior
# /wiki/XOXO_(album)
# /wiki/Exo_(band)
# /wiki/Overdose_(EP)
# /wiki/Exo_(band)
# /wiki/Exodus_(Exo_album)
# /wiki/Exo_(band)
# /wiki/Ex%27Act
# /wiki/Exo_(band)
# /wiki/The_War_(album)
# /wiki/Exo_(band)
# /wiki/Love_Yourself:_Tear
# /wiki/Map_of_the_Soul:_Persona
# /wiki/Template:Mnet_Asian_Music_Award_for_Artist_of_the_Year
# /wiki/Template_talk:Mnet_Asian_Music_Award_for_Artist_of_the_Year
# https://en.wikipedia.org/w/index.php?title=Template:Mnet_Asian_Music_Award_for_Artist_of_the_Year&action=edit
# /wiki/Mnet_Asian_Music_Award_for_Artist_of_the_Year
# /wiki/TVXQ
# /wiki/Super_Junior
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/2PM
# /wiki/2NE1
# /wiki/Girls%27_Generation
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/G-Dragon
# /wiki/Exo_(band)
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Template:Mnet_Asian_Music_Award_for_Song_of_the_Year
# /w/index.php?title=Template_talk:Mnet_Asian_Music_Award_for_Song_of_the_Year&action=edit&redlink=1
# https://en.wikipedia.org/w/index.php?title=Template:Mnet_Asian_Music_Award_for_Song_of_the_Year&action=edit
# /wiki/Mnet_Asian_Music_Award_for_Song_of_the_Year
# /wiki/SG_Wannabe
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Lies_(Big_Bang_song)
# /wiki/Wonder_Girls
# /wiki/Nobody_(Wonder_Girls_song)
# /wiki/2NE1
# /wiki/I_Don%27t_Care_(2NE1_song)
# /wiki/Miss_A
# /wiki/Bad_Girl_Good_Girl
# /wiki/2NE1
# /wiki/I_Am_the_Best
# /wiki/Psy
# /wiki/Gangnam_Style
# /wiki/Cho_Yong-pil
# /wiki/Taeyang
# /wiki/Eyes,_Nose,_Lips
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Bang_Bang_Bang_(Big_Bang_song)
# /wiki/Twice_(band)
# /wiki/Cheer_Up_(song)
# /wiki/Twice_(band)
# /wiki/Signal_(Twice_song)
# /wiki/Twice_(band)
# /wiki/What_Is_Love%3F_(Twice_song)
# /wiki/Boy_with_Luv
# /wiki/Template:Big_Hit_Entertainment
# /wiki/Template_talk:Big_Hit_Entertainment
# https://en.wikipedia.org/w/index.php?title=Template:Big_Hit_Entertainment&action=edit
# /wiki/Big_Hit_Entertainment
# /wiki/Big_Hit_Entertainment_Discography
# /wiki/Bang_Si-hyuk
# /wiki/Suga_(entertainer)
# /wiki/J-Hope
# /wiki/Lee_Hyun
# /wiki/RM_(rapper)
# /wiki/8Eight
# /wiki/TXT_(band)
# /wiki/2AM_(band)
# /wiki/Glam_(band)
# /wiki/Lim_Jeong-hee
# /wiki/Homme_(band)
# /wiki/Lee_Chang-min_(singer)
# /wiki/Source_Music
# /wiki/GFriend
# /wiki/Signal_Entertainment_Group
# /wiki/Kakao_M
# /wiki/Iriver_Inc
# /wiki/K-pop
# /wiki/Category:South_Korean_record_labels
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q13580495
# /wiki/Integrated_Authority_File
# https://d-nb.info/gnd/1174925353
# /wiki/International_Standard_Name_Identifier
# http://isni.org/isni/0000000460095849
# /wiki/Library_of_Congress_Control_Number
# https://id.loc.gov/authorities/names/no2017138930
# /wiki/MusicBrainz
# https://musicbrainz.org/artist/0d79fe8e-ba27-4859-bb8c-2f255f346853
# /wiki/National_Library_of_Korea
# https://nl.go.kr/authorities/resource/KAB201500318
# /wiki/RERO_(Library_Network_of_Western_Switzerland)
# http://data.rero.ch/02-A027673501
# /wiki/Virtual_International_Authority_File
# https://viaf.org/viaf/916150943133426760004
# /wiki/WorldCat_Identities
# https://www.worldcat.org/identities/lccn-no2017138930
# https://en.wikipedia.org/w/index.php?title=BTS&oldid=946469879
# /wiki/Help:Category
# /wiki/Category:BTS_(band)
# /wiki/Category:2013_establishments_in_South_Korea
# /wiki/Category:K-pop_music_groups
# /wiki/Category:Melon_Music_Award_winners
# /wiki/Category:Mnet_Asian_Music_Award_winners
# /wiki/Category:Musical_groups_established_in_2013
# /wiki/Category:Musical_groups_from_Seoul
# /wiki/Category:South_Korean_boy_bands
# /wiki/Category:South_Korean_dance_music_groups
# /wiki/Category:South_Korean_hip_hop_groups
# /wiki/Category:Columbia_Records_artists
# /wiki/Category:Recipients_of_the_Order_of_Cultural_Merit_(Korea)
# /wiki/Category:MTV_EMA_winners
# /wiki/Category:CS1_Korean-language_sources_(ko)
# /wiki/Category:CS1_Japanese-language_sources_(ja)
# /wiki/Category:CS1_uses_Japanese-language_script_(ja)
# /wiki/Category:CS1_uses_Korean-language_script_(ko)
# /wiki/Category:CS1_Indonesian-language_sources_(id)
# /wiki/Category:CS1_Italian-language_sources_(it)
# /wiki/Category:CS1_uses_Chinese-language_script_(zh)
# /wiki/Category:CS1_Chinese-language_sources_(zh)
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Use_mdy_dates_from_January_2020
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Use_American_English_from_July_2018
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Articles_containing_Korean-language_text
# /wiki/Category:Articles_containing_Japanese-language_text
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2019
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Articles_containing_potentially_dated_statements_from_June_2019
# /wiki/Category:Commons_category_link_is_on_Wikidata
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers
# /wiki/Category:Wikipedia_articles_with_NLK_identifiers
# /wiki/Category:Wikipedia_articles_with_RERO_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Category:Wikipedia_articles_with_WorldCat_identifiers
# /wiki/Category:Articles_containing_video_clips
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=BTS
# /w/index.php?title=Special:UserLogin&returnto=BTS
# /wiki/BTS
# /wiki/Talk:BTS
# /wiki/BTS
# /w/index.php?title=BTS&action=edit
# /w/index.php?title=BTS&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Wikipedia:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/BTS
# /wiki/Special:RecentChangesLinked/BTS
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=BTS&oldid=946469879
# /w/index.php?title=BTS&action=info
# https://www.wikidata.org/wiki/Special:EntityPage/Q13580495
# /w/index.php?title=Special:CiteThisPage&page=BTS&id=946469879&wpFormIdentifier=titleform
# https://commons.wikimedia.org/wiki/Category:BTS_(musical_group)
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=BTS
# /w/index.php?title=Special:ElectronPdf&page=BTS&action=show-download-screen
# /w/index.php?title=BTS&printable=yes
# https://ar.wikipedia.org/wiki/%D8%A8%D9%8A_%D8%AA%D9%8A_%D8%A3%D8%B3
# https://ast.wikipedia.org/wiki/BTS_(grupu_musical)
# https://az.wikipedia.org/wiki/BTS_(musiqi_qrupu)
# https://azb.wikipedia.org/wiki/%D8%A8%DB%8C%E2%80%8C%D8%AA%DB%8C%D8%A7%D8%B3_(%D9%85%D9%88%D8%B3%DB%8C%D9%82%DB%8C_%D9%82%D8%B1%D9%88%D9%BE%D9%88)
# https://ban.wikipedia.org/wiki/BTS
# https://zh-min-nan.wikipedia.org/wiki/BTS
# https://bg.wikipedia.org/wiki/%D0%91%D0%B8_%D0%A2%D0%B8_%D0%95%D1%81
# https://ca.wikipedia.org/wiki/BTS_(grup_de_m%C3%BAsica)
# https://cs.wikipedia.org/wiki/BTS_(hudebn%C3%AD_skupina)
# https://cy.wikipedia.org/wiki/BTS
# https://da.wikipedia.org/wiki/BTS_(musikgruppe)
# https://de.wikipedia.org/wiki/BTS_(Band)
# https://et.wikipedia.org/wiki/BTS
# https://el.wikipedia.org/wiki/BTS_(%CF%83%CF%85%CE%B3%CE%BA%CF%81%CF%8C%CF%84%CE%B7%CE%BC%CE%B1)
# https://es.wikipedia.org/wiki/BTS_(banda)
# https://eu.wikipedia.org/wiki/BTS
# https://fa.wikipedia.org/wiki/%D8%A8%DB%8C%E2%80%8C%D8%AA%DB%8C%E2%80%8C%D8%A7%D8%B3_(%DA%AF%D8%B1%D9%88%D9%87_%D9%85%D9%88%D8%B3%DB%8C%D9%82%DB%8C)
# https://fr.wikipedia.org/wiki/BTS_(groupe)
# https://gl.wikipedia.org/wiki/BTS_(grupo_musical)
# https://hak.wikipedia.org/wiki/BTS
# https://ko.wikipedia.org/wiki/%EB%B0%A9%ED%83%84%EC%86%8C%EB%85%84%EB%8B%A8
# https://hy.wikipedia.org/wiki/BTS
# https://hi.wikipedia.org/wiki/%E0%A4%AC%E0%A5%80%E0%A4%9F%E0%A5%80%E0%A4%8F%E0%A4%B8_(%E0%A4%AC%E0%A5%88%E0%A4%A8%E0%A5%8D%E0%A4%A1)
# https://hr.wikipedia.org/wiki/BTS
# https://id.wikipedia.org/wiki/BTS_(grup_musik)
# https://it.wikipedia.org/wiki/BTS_(gruppo_musicale)
# https://he.wikipedia.org/wiki/BTS
# https://pam.wikipedia.org/wiki/Bangtan_Boys
# https://ka.wikipedia.org/wiki/BTS_(%E1%83%AF%E1%83%92%E1%83%A3%E1%83%A4%E1%83%98)
# https://kk.wikipedia.org/wiki/BTS
# https://la.wikipedia.org/wiki/BTS
# https://lv.wikipedia.org/wiki/BTS
# https://lt.wikipedia.org/wiki/BTS
# https://hu.wikipedia.org/wiki/BTS_(egy%C3%BCttes)
# https://ms.wikipedia.org/wiki/BTS_(kumpulan_muzik)
# https://mn.wikipedia.org/wiki/Bangtan_Boys
# https://my.wikipedia.org/wiki/%E1%80%98%E1%80%AE%E1%80%90%E1%80%AE%E1%80%A1%E1%80%80%E1%80%BA%E1%80%85%E1%80%BA
# https://nl.wikipedia.org/wiki/BTS_(band)
# https://ja.wikipedia.org/wiki/%E9%98%B2%E5%BC%BE%E5%B0%91%E5%B9%B4%E5%9B%A3
# https://no.wikipedia.org/wiki/BTS_(band)
# https://km.wikipedia.org/wiki/BTS_(band)
# https://pl.wikipedia.org/wiki/BTS_(zesp%C3%B3%C5%82_muzyczny)
# https://pt.wikipedia.org/wiki/BTS
# https://ro.wikipedia.org/wiki/BTS_(forma%C8%9Bie)
# https://ru.wikipedia.org/wiki/BTS
# https://sco.wikipedia.org/wiki/BTS_(baund)
# https://sq.wikipedia.org/wiki/Bangtan_Boys
# https://simple.wikipedia.org/wiki/BTS_(band)
# https://sk.wikipedia.org/wiki/BTS_(skupina)
# https://sl.wikipedia.org/wiki/BTS_(glasbena_skupina)
# https://sr.wikipedia.org/wiki/%D0%91%D0%A2%D0%A1_(%D0%B1%D0%B5%D0%BD%D0%B4)
# https://fi.wikipedia.org/wiki/BTS_(yhtye)
# https://sv.wikipedia.org/wiki/BTS_(musikgrupp)
# https://tl.wikipedia.org/wiki/BTS
# https://th.wikipedia.org/wiki/%E0%B8%9A%E0%B8%B5%E0%B8%97%E0%B8%B5%E0%B9%80%E0%B8%AD%E0%B8%AA_(%E0%B8%81%E0%B8%A5%E0%B8%B8%E0%B9%88%E0%B8%A1%E0%B8%99%E0%B8%B1%E0%B8%81%E0%B8%A3%E0%B9%89%E0%B8%AD%E0%B8%87)
# https://tr.wikipedia.org/wiki/BTS
# https://uk.wikipedia.org/wiki/BTS
# https://vep.wikipedia.org/wiki/BTS
# https://vi.wikipedia.org/wiki/BTS_(nh%C3%B3m_nh%E1%BA%A1c)
# https://fiu-vro.wikipedia.org/wiki/BTS
# https://zh-classical.wikipedia.org/wiki/%E9%98%B2%E5%BD%88%E5%B0%91%E5%B9%B4%E5%9C%98
# https://war.wikipedia.org/wiki/BTS
# https://zh-yue.wikipedia.org/wiki/%E9%98%B2%E5%BD%88%E5%B0%91%E5%B9%B4%E5%9C%98
# https://zh.wikipedia.org/wiki/%E9%98%B2%E5%BD%88%E5%B0%91%E5%B9%B4%E5%9C%98
# https://www.wikidata.org/wiki/Special:EntityPage/Q13580495#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=BTS&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
# 정규표현식을 사용해 원하는 위키 항목 페이지들을 찾음.

# id가 bodyContent인 div 영역 하나 찾고,
# 정규표현식을 이용해 하이퍼링크 찾는다.

import re

for link in bts_page.find('div', {'id' : 'bodyContent'})\
                     .findAll('a', {'href' : re.compile("^(/wiki/)((?!:).)*$")}):
    if 'href' in link.attrs:
        print(link['href'])
# Out:
# /wiki/BTS_(disambiguation)
# /wiki/LG_Electronics
# /wiki/V_(singer)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Kim_Seok-jin
# /wiki/Jimin_(singer,_born_1995)
# /wiki/Jungkook
# /wiki/Suga_(rapper)
# /wiki/Seoul
# /wiki/K-pop
# /wiki/Hip_hop_music
# /wiki/Contemporary_R%26B
# /wiki/Electronic_dance_music
# /wiki/Big_Hit_Entertainment
# /wiki/Pony_Canyon
# /wiki/Def_Jam_Recordings
# /wiki/Columbia_Records
# /wiki/Kim_Seok-jin
# /wiki/Suga_(rapper)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Jimin_(singer,_born_1995)
# /wiki/V_(singer)
# /wiki/Jungkook
# /wiki/Hangul
# /wiki/Hanja
# /wiki/Revised_Romanization_of_Korean
# /wiki/McCune%E2%80%93Reischauer
# /wiki/Kanji
# /wiki/Hiragana
# /wiki/Hepburn_romanization
# /wiki/Kunrei-shiki_romanization
# /wiki/Korean_language
# /wiki/Revised_Romanization_of_Korean
# /wiki/Boy_band
# /wiki/Seoul
# /wiki/Hip_hop_music
# /wiki/Parallel_universes_in_fiction
# /wiki/Big_Hit_Entertainment
# /wiki/2_Cool_4_Skool
# /wiki/Billboard_200
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_2
# /wiki/Wings_(BTS_album)
# /wiki/Korean_Wave
# /wiki/Recording_Industry_Association_of_America
# /wiki/Mic_Drop_(song)
# /wiki/The_Beatles
# /wiki/Gaon_Album_Chart
# /wiki/Gaon_Music_Chart
# /wiki/List_of_best-selling_albums_in_South_Korea
# /wiki/IFPI
# /wiki/Billboard_Music_Award_for_Top_Social_Artist
# /wiki/Billboard_Music_Award_for_Top_Duo/Group
# /wiki/2019_Billboard_Music_Awards
# /wiki/Time_(magazine)
# /wiki/Time_100
# /wiki/Honorific_nicknames_in_popular_music
# /wiki/Forbes_Korea_Power_Celebrity
# /wiki/Forbes_Celebrity_100
# /wiki/Billboard_(magazine)
# /wiki/Love_Yourself_World_Tour
# /wiki/Wembley_Stadium
# /wiki/Rose_Bowl_(stadium)
# /wiki/Love_Myself_(campaign)
# /wiki/UNICEF
# /wiki/United_Nations
# /wiki/United_Nations_General_Assembly
# /wiki/Order_of_Cultural_Merit_(Korea)
# /wiki/President_of_South_Korea
# /wiki/Korean_language
# /wiki/Hanja
# /wiki/J-Hope
# /wiki/Incheon
# /wiki/Bang_Si-hyuk
# /wiki/RM_(rapper)
# /wiki/Hip-hop
# /wiki/1TYM
# /wiki/2AM_(band)
# /wiki/Lee_Seung-gi
# /wiki/Kim_Seok-jin
# /wiki/Suga_(rapper)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Jimin_(singer,_born_1995)
# /wiki/V_(singer)
# /wiki/Jungkook_(singer)
# /wiki/YouTube
# /wiki/SoundCloud
# /wiki/Suga_(rapper)
# /wiki/Single_(music)#In_South_Korea
# /wiki/2_Cool_4_Skool
# /wiki/Extended_play
# /wiki/O!RUL8,2%3F
# /wiki/SBS_MTV
# /wiki/MasterChef_Korea
# /wiki/Melon_Music_Awards
# /wiki/Golden_Disc_Awards
# /wiki/Seoul_Music_Awards
# /wiki/Troubadour_(West_Hollywood,_California)
# /wiki/United_States
# /wiki/Skool_Luv_Affair
# /wiki/Gaon_Album_Chart
# /wiki/Billboard_(magazine)
# /wiki/Seoul
# /wiki/West_Hollywood,_California
# /wiki/KCON_(music_festival)
# /wiki/Los_Angeles
# /wiki/Dark_%26_Wild
# /wiki/Rock_music
# /wiki/Rhythm_and_blues
# /wiki/Concert_tour
# /wiki/The_Red_Bullet_Tour
# /wiki/Kobe
# /wiki/Tokyo
# /wiki/Manila
# /wiki/Singapore
# /wiki/Bangkok
# /wiki/Wake_Up_(BTS_album)
# /wiki/Oricon_Albums_Chart
# /wiki/Wake_Up_(BTS_album)#Promotion
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_1
# /wiki/Fuse_(TV_channel)
# /wiki/I_Need_U_(BTS_song)
# /wiki/SBS_MTV
# /wiki/The_Show_(South_Korean_TV_series)
# /wiki/YouTube
# /wiki/Oricon_Albums_Chart
# /wiki/Summer_Sonic_Festival
# /wiki/The_Most_Beautiful_Moment_in_Life_On_Stage_Tour
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_2
# /wiki/Billboard_(magazine)
# /wiki/World_Albums
# /wiki/Billboard_200_chart
# /wiki/Mnet_Asian_Music_Awards_in_the_Special_Awards_Category
# /wiki/2015_Mnet_Asian_Music_Awards
# /wiki/KCON_(music_festival)
# /wiki/Fire_(BTS_song)
# /wiki/Save_Me_(BTS_song)
# /wiki/List_of_Gaon_Album_Chart_number_ones_of_2016#Weekly_charts
# /wiki/Billboard_200
# /wiki/Melon_Music_Awards
# /wiki/The_Most_Beautiful_Moment_in_Life_On_Stage_Tour#Epilogue_extension
# /wiki/Olympic_Gymnastics_Arena
# /wiki/Seoul
# /wiki/KCON_(music_festival)
# /wiki/Newark,_New_Jersey
# /wiki/Youth_(BTS_album)
# /wiki/Japan
# /wiki/Wings_(BTS_album)
# /wiki/Rolling_Stone
# /wiki/Fuse_(TV_channel)
# /wiki/List_of_Billboard_Social_50_number-one_artists
# /wiki/Gaon_Album_Chart
# /wiki/S.M._Entertainment
# /wiki/YG_Entertainment
# /wiki/JYP_Entertainment
# /wiki/Mnet_Asian_Music_Awards
# /wiki/Wings_(BTS_album)#You_Never_Walk_Alone
# /wiki/Spring_Day_(song)
# /wiki/Dazed_Digital
# /wiki/Melon_(online_music_service)
# /wiki/Bubbling_Under_Hot_100
# /wiki/Melon_Music_Awards#Song_of_the_Year
# /wiki/Billboard_Music_Award
# /wiki/Billboard_Music_Award_for_Top_Social_Artist
# /wiki/Seo_Taiji
# /wiki/Come_Back_Home_(Seo_Taiji_and_Boys_song)
# /wiki/Seoul_Olympic_Stadium
# /wiki/Kish%C5%8Dtenketsu
# /wiki/The_Chainsmokers
# /wiki/DNA_(BTS_song)
# /wiki/Steve_Aoki
# /wiki/Mic_Drop_(song)
# /wiki/Desiigner
# /wiki/G.o.d
# /wiki/Chapter_4_(g.o.d_album)
# /wiki/YouTube
# /wiki/Billboard_Hot_100
# /wiki/Wonder_Girls
# /wiki/Mic_Drop_(song)
# /wiki/Recording_Industry_Association_of_America
# /wiki/American_Music_Awards
# /wiki/Guinness_World_Records
# /wiki/Dick_Clark%27s_New_Year%27s_Rockin%27_Eve
# /wiki/TV_Asahi
# /wiki/Music_Station#Super_Live
# /wiki/Mnet_Asian_Music_Award_for_Artist_of_the_Year
# /wiki/2017_Mnet_Asian_Music_Awards
# /wiki/Golden_Disc_Awards
# /wiki/Seoul_Music_Awards
# /wiki/YouTube_Premium
# /wiki/Face_Yourself
# /wiki/Billboard_200
# /wiki/2018_Billboard_Music_Awards
# /wiki/Fake_Love_(BTS_song)
# /wiki/Billboard_Music_Award_for_Top_Social_Artist
# /wiki/Billboard_(magazine)
# /wiki/Pitchfork_(website)
# /wiki/Album-equivalent_unit
# /wiki/United_Kingdom
# /wiki/UK_Albums_Chart
# /wiki/Compilation_album
# /wiki/Idol_(BTS_song)
# /wiki/Nicki_Minaj
# /wiki/Magnum_opus
# /wiki/Gaon_Album_Chart
# /wiki/Pop_music
# /wiki/One_Direction
# /wiki/Midnight_Memories
# /wiki/Four_(One_Direction_album)
# /wiki/Canadian_Albums_Chart
# /wiki/Billboard_Hot_100
# /wiki/Canadian_Singles_Chart
# /wiki/Taylor_Swift
# /wiki/Look_What_You_Made_Me_Do
# /wiki/Citi_Field
# /wiki/Seoul_Olympic_Stadium
# /wiki/Steve_Aoki
# /wiki/Waste_It_On_Me
# /wiki/Citi_Field
# /wiki/Koreatown,_Long_Island
# /wiki/StubHub
# /wiki/Ed_Sheeran
# /wiki/Vivid_Seats
# /wiki/Uproxx
# /wiki/Staples_Center
# /wiki/MTV
# /wiki/Simon_Wiesenthal_Center
# /wiki/Nazism
# /wiki/2018_Mnet_Asian_Music_Awards
# /wiki/Drake_(musician)
# /wiki/Taylor_Swift
# /wiki/Imagine_Dragons
# /wiki/50_Most_Influential_(Bloomberg_Markets_ranking)
# /wiki/61st_Grammy_Awards
# /wiki/Grammy_Museum_at_L.A._Live
# /wiki/Spotify
# /wiki/Time_(magazine)
# /wiki/Time_100
# /wiki/Boy_With_Luv
# /wiki/Halsey_(singer)
# /wiki/Saturday_Night_Live
# /wiki/The_Beatles
# /wiki/The_Monkees
# /wiki/List_of_best-selling_albums_in_South_Korea
# /wiki/Australia
# /wiki/Recording_Industry_Association_of_America
# /wiki/British_Phonographic_Industry
# /wiki/Pasadena,_California
# /wiki/Rose_Bowl_(stadium)
# /wiki/2019_Billboard_Music_Awards
# /wiki/Billboard_Music_Award_for_Top_Duo/Group
# /wiki/Wembley_Stadium
# /wiki/Stade_de_France
# /wiki/MetLife_Stadium
# /wiki/Rose_Bowl_(stadium)
# /wiki/Soldier_Field
# /wiki/Taylor_Swift
# /wiki/U2
# /wiki/The_Late_Show_with_Stephen_Colbert
# /wiki/Good_Morning_America
# /wiki/Central_Park
# /wiki/Koreatown,_Manhattan
# /wiki/The_Voice_(U.S._TV_series)
# /wiki/Britain%27s_Got_Talent
# /wiki/BTS_World
# /wiki/Dream_Glow
# /wiki/Charli_XCX
# /wiki/A_Brand_New_Day_(BTS_and_Zara_Larsson_song)
# /wiki/Zara_Larsson
# /wiki/All_Night_(BTS_and_Juice_Wrld_song)
# /wiki/Juice_Wrld
# /wiki/Heartbeat_(BTS_song)
# /wiki/Gaon_Music_Chart
# /wiki/Netmarble
# /wiki/IOS
# /wiki/Android_(operating_system)
# /wiki/Lights_(BTS_song)
# /wiki/Celine_Dion
# /wiki/To_Love_You_More
# /wiki/RIAJ
# /wiki/King_Fahd_International_Stadium
# /wiki/Love_Yourself_World_Tour
# /wiki/Ed_Sheeran
# /wiki/Pink_(singer)
# /wiki/Rolling_Stones
# /wiki/Metallica
# /wiki/Kiss_(band)
# /wiki/Backstreet_Boys
# /wiki/Make_It_Right_(BTS_song)
# /wiki/Lauv
# /wiki/American_Music_Awards_of_2019
# /wiki/2019_Melon_Music_Awards
# /wiki/2019_Mnet_Asian_Music_Awards
# /wiki/Jonas_Brothers
# /wiki/Variety_(magazine)
# /wiki/New_York_City
# /wiki/Times_Square
# /wiki/American_Broadcasting_Company
# /wiki/Dick_Clark%27s_New_Year%27s_Rockin%27_Eve
# /wiki/34th_Golden_Disc_Awards
# /wiki/Nielsen_SoundScan
# /wiki/Taylor_Swift
# /wiki/Lover_(album)
# /wiki/Billboard_(magazine)
# /wiki/Queen_(band)
# /wiki/Imagine_Dragons
# /wiki/The_Beatles
# /wiki/International_Federation_of_the_Phonographic_Industry
# /wiki/Arashi
# /wiki/5x20_All_the_Best!!_1999%E2%80%932019
# /wiki/International_Federation_of_the_Phonographic_Industry
# /wiki/Black_Swan_(BTS_song)
# /wiki/Iriver_Inc
# /wiki/Lil_Nas_X
# /wiki/Billy_Ray_Cyrus
# /wiki/Diplo
# /wiki/62nd_Annual_Grammy_Awards
# /wiki/On_(song)
# /wiki/Sia_(musician)
# /wiki/Billboard_200
# /wiki/Album-equivalent_unit
# /wiki/The_Beatles
# /wiki/Billboard_Hot_100
# /wiki/List_of_best-selling_albums_in_South_Korea
# /wiki/Map_of_the_Soul_Tour
# /wiki/2019%E2%80%9320_coronavirus_outbreak
# /wiki/Freddie_Mercury
# /wiki/Wembley_Stadium
# /wiki/Seo_Taiji_and_Boys
# /wiki/Nas
# /wiki/Eminem
# /wiki/Kanye_West
# /wiki/Drake_(musician)
# /wiki/Post_Malone
# /wiki/Charlie_Puth
# /wiki/Danger_(musician)
# /wiki/Queen_(band)
# /wiki/Live_Aid
# /wiki/Freddie_Mercury
# /wiki/Hermann_Hesse
# /wiki/Demian
# /wiki/Blood_Sweat_%26_Tears_(song)
# /wiki/Friedrich_Nietzsche
# /wiki/Thus_Spoke_Zarathustra
# /wiki/Herbert_James_Draper
# /wiki/The_Lament_for_Icarus
# /wiki/Pieter_Bruegel_the_Elder
# /wiki/Landscape_with_the_Fall_of_Icarus
# /wiki/The_Fall_of_the_Rebel_Angels_(Bruegel)
# /wiki/Ursula_K._Le_Guin
# /wiki/The_Ones_Who_Walk_Away_from_Omelas
# /wiki/Erich_Fromm
# /wiki/The_Art_of_Loving
# /wiki/James_Doty_(physician)
# /wiki/Hip_hop
# /wiki/Old-school_hip_hop
# /wiki/Rhythm_and_blues
# /wiki/Rock_music
# /wiki/Electronic_dance_music
# /wiki/Moombahton
# /wiki/Neo_soul
# /wiki/Gospel_music
# /wiki/Future_bass
# /wiki/Latin_pop
# /wiki/Jazz_rap
# /wiki/Emo_rap
# /wiki/Rap_rock
# /wiki/Afro_pop
# /wiki/Nu-disco
# /wiki/Funk
# /wiki/Trap_music
# /wiki/Pop_rap
# /wiki/Social_commentary
# /wiki/No_More_Dream
# /wiki/N.O_(BTS_song)
# /wiki/Dope_(BTS_song)
# /wiki/Silver_Spoon_(BTS_song)
# /wiki/Millennials
# /wiki/Am_I_Wrong_(BTS_song)
# /wiki/Wings_(BTS_album)
# /wiki/Ministry_of_Education_(South_Korea)
# /wiki/Caste
# /wiki/2016_South_Korean_political_scandal
# /wiki/Park_Geun-hye
# /wiki/Skool_Luv_Affair
# /wiki/The_Most_Beautiful_Moment_in_Life,_Pt._1
# /wiki/Forever_Rain
# /wiki/Not_Today_(BTS_song)
# /wiki/Anti-establishment
# /wiki/Spring_Day_(song)
# /wiki/Sinking_of_MV_Sewol
# /wiki/Wings_(BTS_album)
# /wiki/RM_(rapper)
# /wiki/Suga_(rapper)
# /wiki/Fuse_(magazine)
# /wiki/Moon_Jae-in
# /wiki/Time_(magazine)
# /wiki/Billboard_charts
# /wiki/The_Beatles
# /wiki/The_Monkees
# /wiki/Nielsen_Holdings
# /wiki/Global_Recording_Artist_of_the_Year
# /wiki/Drake_(musician)
# /wiki/International_Federation_of_the_Phonographic_Industry
# /wiki/Billboard_(magazine)
# /wiki/Honorific_nicknames_in_popular_music
# /wiki/Time_(magazine)
# /wiki/Time_100
# /wiki/CNN
# /wiki/Parasite_(2019_film)
# /wiki/Bong_Joon-ho
# /wiki/Bloomberg_Markets
# /wiki/50_Most_Influential_(Bloomberg_Markets_ranking)
# /wiki/Forbes_Korea_Power_Celebrity
# /wiki/Forbes
# /wiki/Forbes_Celebrity_100
# /wiki/SDG
# /wiki/United_Nations
# /wiki/Malala_Yousafzai
# /wiki/Bill_Gates
# /wiki/California
# /wiki/United_Nations
# /wiki/United_Nations_General_Assembly
# /wiki/Moon_Jae-in
# /wiki/Moon_Hee-sang
# /wiki/Moon_Jae-in
# /wiki/Ministry_of_Culture,_Sports_and_Tourism
# /wiki/Gallup_(company)
# /wiki/Korean_Culture_and_Information_Service
# /wiki/Order_of_Cultural_Merit_(Korea)
# /wiki/President_of_South_Korea
# /wiki/Korean_Wave
# /wiki/Korea_Customs_Service
# /wiki/Korea_Foundation
# /wiki/China%E2%80%93South_Korea_relations#Deployment_of_THAAD_in_South_Korea
# /wiki/Korea_Creative_Content_Agency
# /wiki/KB_Financial_Group_Inc
# /wiki/Billboard_200
# /wiki/Netmarble
# /wiki/Soribada
# /wiki/Mattel
# /wiki/Mattel
# /wiki/Hyundai_Motor_Company
# /wiki/Balance_of_payments
# /wiki/Seoul_Metropolitan_Government
# /wiki/China%E2%80%93South_Korea_relations#Deployment_of_THAAD_in_South_Korea
# /wiki/Seoul
# /wiki/Busan
# /wiki/Gross_domestic_product
# /wiki/Love_Yourself_World_Tour
# /wiki/Korean_Air
# /wiki/Interpark
# /wiki/Seoul_Olympic_Stadium
# /wiki/Wembley_Stadium
# /wiki/London
# /wiki/Malta_(island)
# /wiki/Ariana_Grande
# /wiki/Drake_(musician)
# /wiki/(G)I-dle
# /wiki/D-Crunch
# /wiki/The_Boyz_(South_Korean_band)
# /wiki/SF9_(band)
# /wiki/Euna_Kim
# /wiki/Golden_Child_(band)
# /wiki/Wanna_One
# /wiki/In2It
# /wiki/Park_Ji-hoon
# /wiki/Kim_Dong-han
# /wiki/Seven_O%27Clock_(band)
# /wiki/Hyeongseop_X_Euiwoong
# /wiki/Noir_(band)
# /wiki/Victon
# /wiki/Loona_(group)
# /wiki/Idol_(BTS_song)
# /wiki/National_Gugak_Center
# /wiki/RM_(rapper)
# /wiki/United_Nations
# /wiki/List_of_awards_and_nominations_received_by_BTS
# /wiki/Mnet_Asian_Music_Awards
# /wiki/Melon_Music_Awards
# /wiki/Golden_Disc_Awards
# /wiki/Seoul_Music_Awards
# /wiki/Gaon_Chart_Music_Awards
# /wiki/Billboard_Music_Award
# /wiki/Korean_Music_Awards
# /wiki/American_Music_Awards
# /wiki/MTV_Video_Music_Awards
# /wiki/Gaon_Music_Chart#Certification
# /wiki/Gaon_Music_Chart#Certification
# /wiki/Recording_Industry_Association_of_America
# /wiki/Music_recording_certification
# /wiki/Platinum_Single
# /wiki/Gold_single
# /wiki/Gold_album
# /wiki/Recording_Industry_Association_of_Japan
# /wiki/Recording_Industry_Association_of_Japan
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# /wiki/Recording_Industry_Association_of_Japan#RIAJ_Certification
# /wiki/British_Phonographic_Industry
# /wiki/British_Phonographic_Industry
# /wiki/Guinness_World_Records
# /wiki/Order_of_Cultural_Merit_(Korea)
# /wiki/President_of_South_Korea
# /wiki/Recording_Academy
# /wiki/Grammy_Award
# /wiki/Puma_(brand)
# /wiki/Dior
# /wiki/Kim_Jones_(designer)
# /wiki/Stade_de_France
# /wiki/Business_of_Fashion
# /wiki/Fila_(company)
# /wiki/LG_Electronics
# /wiki/LG_G7_ThinQ
# /wiki/Hyundai_Motor_Company
# /wiki/LA_Auto_Show
# /wiki/Hyundai_Palisade
# /wiki/Lotte_Corporation
# /wiki/Seoul_Metropolitan_Government
# /wiki/Line_(software)
# /wiki/Line_Friends
# /wiki/Line_Friends#BT21
# /wiki/Line_Friends#BT21
# /wiki/Line_Friends
# /wiki/Mapo_District
# /wiki/Seoul
# /wiki/Webtoon
# /wiki/Save_Me_(webtoon)
# /wiki/Line_Webtoon
# /wiki/Mattel
# /wiki/Idol_(BTS_song)
# /wiki/Kubrick_(toy)
# /wiki/Funko
# /wiki/Nexon
# /wiki/Role-playing_game
# /wiki/Elsword
# /wiki/Netmarble_Games
# /wiki/BTS_World
# /wiki/Casetify
# /wiki/KB_Kookmin_Bank
# /wiki/The_Coca-Cola_Company
# /wiki/2018_FIFA_World_Cup
# /wiki/Plum_Blossom
# /wiki/Tokopedia
# /wiki/Formula_E
# /wiki/Formula_E
# /wiki/Hyundai_Motors
# /wiki/Hydrogen_vehicle
# /wiki/Fuel_cell_vehicle
# /wiki/Sport_utility_vehicle
# /wiki/Hyundai_Nexo
# /wiki/Samsung_Electronics
# /wiki/Love_Myself_(campaign)
# /wiki/Apgujeong-dong
# /wiki/Love_Myself_(campaign)
# /wiki/Sinking_of_MV_Sewol
# /wiki/Love_Myself_(campaign)
# /wiki/UNICEF
# /wiki/Stevie_Wonder
# /wiki/Martin_Luther_King_Jr.
# /wiki/Amyotrophic_lateral_sclerosis
# /wiki/United_Nations
# /wiki/United_Nations_General_Assembly
# /wiki/Starbucks_Corporation
# /wiki/Grammy_Award
# /wiki/Love_Yourself_World_Tour
# /wiki/MusiCares
# /wiki/Music_community
# /wiki/Parallel_universes_in_fiction
# /wiki/Big_Hit_Entertainment
# /wiki/Webtoon
# /wiki/Save_Me_(webtoon)
# /wiki/I_Need_U_(BTS_song)
# /wiki/Picture_book
# /wiki/Korean_drama
# /wiki/Chorokbaem_Media
# /wiki/Billboard_(magazine)
# /wiki/The_Ones_Who_Walk_Away_from_Omelas
# /wiki/London
# /wiki/Berlin
# /wiki/Buenos_Aires
# /wiki/Seoul
# /wiki/New_York_City
# /wiki/Serpentine_Galleries
# /wiki/Brooklyn_Bridge
# /wiki/Antony_Gormley
# /wiki/BBC
# /wiki/Tom%C3%A1s_Saraceno
# /wiki/Dongdaemun_Design_Plaza
# /wiki/Ann_Veronica_Janssens
# /wiki/Martin-Gropius-Bau
# /wiki/Kim_Seok-jin
# /wiki/Suga_(rapper)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Jimin_(singer,_born_1995)
# /wiki/V_(singer)
# /wiki/Jungkook
# /wiki/BTS_albums_discography
# /wiki/BTS_singles_discography
# /wiki/Dark_%26_Wild
# /wiki/Wings_(BTS_album)
# /wiki/Wake_Up_(BTS_album)
# /wiki/Youth_(BTS_album)
# /wiki/Face_Yourself
# /wiki/List_of_BTS_live_performances
# /wiki/The_Red_Bullet_Tour
# /wiki/Wake_Up_(BTS_album)#Promotion
# /wiki/The_Most_Beautiful_Moment_in_Life_On_Stage_Tour
# /wiki/The_Wings_Tour
# /wiki/Love_Yourself_World_Tour
# /wiki/Map_of_the_Soul_Tour
# /wiki/BTS_videography
# /wiki/Love_Yourself_in_Seoul
# /wiki/SBS_MTV
# /wiki/YinYueTai
# /wiki/Mnet_(TV_channel)
# /wiki/Run_BTS!
# /wiki/Mnet_(TV_channel)
# /wiki/JTBC
# /wiki/V_Live_(website)
# /wiki/Run_BTS!
# /wiki/YouTube_Premium
# /wiki/Love_Yourself_World_Tour
# /wiki/Universal_Music_Group
# /wiki/Roger_Friedman
# /wiki/Showbiz411
# /wiki/Behance
# /wiki/International_Standard_Book_Number
# /wiki/Vox_(website)
# /wiki/Time_(magazine)
# /wiki/International_Standard_Book_Number
# /wiki/International_Standard_Book_Number
# /wiki/Melon_(online_music_service)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/International_Standard_Book_Number
# /wiki/International_Standard_Book_Number
# /wiki/Oricon
# /wiki/Oricon
# /wiki/ITunes
# /wiki/International_Standard_Book_Number
# /wiki/Fuse_(TV_channel)
# /wiki/Billboard_(magazine)
# /wiki/Oricon
# /wiki/International_Standard_Book_Number
# /wiki/Billboard_(magazine)
# /wiki/Gaon_Chart
# /wiki/Gaon_Chart
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/International_Standard_Book_Number
# /wiki/Fuse_(TV_channel)
# /wiki/Yonhap
# /wiki/Billboard_(magazine)
# /wiki/Fuse_(magazine)
# /wiki/CNN
# /wiki/Billboard_(magazine)
# /wiki/International_Standard_Book_Number
# /wiki/Recording_Industry_Association_of_America
# /wiki/MTV_(UK_and_Ireland)
# /wiki/Billboard_(magazine)
# /wiki/Oricon
# /wiki/Naver_(corporation)
# /wiki/Recording_Industry_Association_of_Japan
# /wiki/Naver_(corporation)
# /wiki/Quartz_(publication)
# /wiki/Naver_(corporation)
# /wiki/Naver_(corporation)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/International_Standard_Book_Number
# /wiki/Forbes
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/Osen
# /wiki/The_Philippine_Star
# /wiki/Huffington_Post
# /wiki/International_Standard_Book_Number
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/The_Chosun_Ilbo
# /wiki/MSN
# /wiki/USA_Today
# /wiki/The_New_York_Times
# /wiki/Simon_Wiesenthal_Center
# /wiki/USA_Today
# /wiki/Naver
# /wiki/Bloomberg_Markets
# /wiki/Naver
# /wiki/Variety_(magazine)
# /wiki/Variety_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Entertainment_Tonight
# /wiki/Yahoo!_News
# /wiki/Billboard_(magazine)
# /wiki/Halsey_(singer)
# /wiki/Time_(magazine)
# /wiki/Teen_Vogue
# /wiki/Vanity_Fair_(magazine)
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/Forbes
# /wiki/Naver_(corporation)
# /wiki/Billboard_(magazine)
# /wiki/Forbes
# /wiki/Forbes
# /wiki/Forbes
# /wiki/British_Phonographic_Industry
# /wiki/Syndicat_National_de_l%27%C3%89dition_Phonographique
# /wiki/Billboard_(magazine)
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/Good_Morning_America
# /wiki/Billboard_(magazine)
# /wiki/People_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/CNN
# /wiki/E!_Online
# /wiki/Naver_(corporation)
# /wiki/Gaon_Music_Chart
# /wiki/Gaon_Music_Chart
# /wiki/Gaon_Music_Chart
# /wiki/Gaon_Music_Chart
# /wiki/British_Phonographic_Industry
# /wiki/British_Phonographic_Industry
# /wiki/British_Phonographic_Industry
# /wiki/BBC_News
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Variety_(magazine)
# /wiki/CBS_News
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/International_Federation_of_the_Phonographic_Industry
# /wiki/Naver
# /wiki/Hankook_Ilbo
# /wiki/Naver
# /wiki/Forbes
# /wiki/Naver
# /wiki/Hankook_Ilbo
# /wiki/Naver
# /wiki/Pitchfork_(website)
# /wiki/Rolling_Stone
# /wiki/Herald_Corporation
# /wiki/Yonhap_News_Agency
# /wiki/Time_(magazine)
# /wiki/Metacritic
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Forbes
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/Vox_(magazine)
# /wiki/Forbes
# /wiki/Naver
# /wiki/Forbes
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/Entertainment_Tonight
# /wiki/BBC
# /wiki/Korean_Broadcasting_System
# /wiki/Amazon_Standard_Identification_Number
# /wiki/Theguardian.com
# /wiki/Rolling_Stone
# /wiki/Stereogum
# /wiki/The_Independent
# /wiki/Entertainment_Weekly
# /wiki/Forbes
# /wiki/International_Standard_Serial_Number
# /wiki/Naver_(corporation)
# /wiki/Yonhap_News_Agency
# /wiki/The_Korea_Herald
# /wiki/Twitter
# /wiki/International_Federation_of_the_Phonographic_Industry
# /wiki/Forbes
# /wiki/Billboard_(magazine)
# /wiki/CNN
# /wiki/New_York_(magazine)
# /wiki/The_Guardian
# /wiki/Pitchfork_(website)
# /wiki/The_Times
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Time_(magazine)
# /wiki/Time_(magazine)
# /wiki/Time_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Time_(magazine)
# /wiki/CNN
# /wiki/Bloomberg_Markets
# /wiki/JoongAng_Ilbo
# /wiki/Forbes
# /wiki/Vogue_(magazine)
# /wiki/Rolling_Stone
# /wiki/Billboard_(magazine)
# /wiki/Herald_Corporation
# /wiki/The_Korea_Herald
# /wiki/The_Chosun_Ilbo
# /wiki/Forbes
# /wiki/PBS
# /wiki/The_Economic_Times
# /wiki/South_China_Morning_Post
# /wiki/Billboard_(magazine)
# /wiki/South_China_Morning_Post
# /wiki/Korea_Economic_Daily
# /wiki/Naver_(corporation)
# /wiki/BBC
# /wiki/Billboard_(magazine)
# /wiki/The_Korea_Herald
# /wiki/Naver_(corporation)
# /wiki/IMBC
# /wiki/V_Live_(website)
# /wiki/Naver_(corporation)
# /wiki/Seoul_Shinmun
# /wiki/Naver_(corporation)
# /wiki/Seoul_Shinmun
# /wiki/Seoul_Broadcasting_System
# /wiki/Maeil_Broadcasting_Network
# /wiki/The_Korea_Herald
# /wiki/YTN
# /wiki/Naver_(corporation)
# /wiki/Korean_Broadcasting_System
# /wiki/Naver_(corporation)
# /wiki/Gaon_Music_Chart
# /wiki/Gaon_Music_Chart
# /wiki/Recording_Industry_Association_of_America
# /wiki/Billboard_(magazine)
# /wiki/The_Korea_Herald
# /wiki/Reuters
# /wiki/Naver_(corporation)
# /wiki/Huffington_Post
# /wiki/Billboard_(magazine)
# /wiki/Yonhap_News_Agency
# /wiki/JoongAng_Ilbo
# /wiki/Yonhap_News_Agency
# /wiki/The_Korea_Herald
# /wiki/Yonhap_News_Agency
# /wiki/The_Korea_Herald
# /wiki/Billboard_(magazine)
# /wiki/The_Korea_Herald
# /wiki/Chosun_Ilbo
# /wiki/The_China_Post
# /wiki/GameSpot
# /wiki/Naver_(corporation)
# /wiki/Yonhap_News_Agency
# /wiki/The_Korea_Herald
# /wiki/Billboard_JAPAN
# /wiki/Billboard_(magazine)
# /wiki/Herald_Corporation
# /wiki/The_Korea_Herald
# /wiki/The_Korea_Herald
# /wiki/V_Live_(website)
# /wiki/Naver
# /wiki/Entertainment_Tonight
# /wiki/UNICEF
# /wiki/Naver
# /wiki/ABC_News
# /wiki/Billboard_(magazine)
# /wiki/Rolling_Stone
# /wiki/CBS_News
# /wiki/Vogue_(magazine)
# /wiki/UNICEF
# /wiki/Naver
# /wiki/Yonhap_News_Agency
# /wiki/Newsarama
# /wiki/MTV
# /wiki/Mumbrella
# /wiki/South_China_Morning_Post
# /wiki/YouTube
# /wiki/Big_Hit_Entertainment
# /wiki/Teen_Vogue
# /wiki/Billboard_(magazine)
# /wiki/Teen_Vogue
# /wiki/International_Business_Times
# /wiki/CNN
# /wiki/Billboard_(magazine)
# /wiki/The_New_York_Times
# /wiki/BBC
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Billboard_(magazine)
# /wiki/Naver_(corporation)
# /wiki/AXS_(company)
# /wiki/Billboard_(magazine)
# /wiki/Naver_(corporation)
# /wiki/Variety_(magazine)
# /wiki/CNBC
# /wiki/Mnet_(TV_channel)
# /wiki/The_Korea_Herald
# /wiki/El_Comercio_(Peru)
# /wiki/Billboard_(magazine)
# /wiki/Naver_(corporation)
# /wiki/Kim_Seok-jin
# /wiki/Suga_(rapper)
# /wiki/J-Hope
# /wiki/RM_(rapper)
# /wiki/Jimin_(singer,_born_1995)
# /wiki/V_(singer)
# /wiki/Jungkook
# /wiki/Dark_%26_Wild
# /wiki/Wings_(BTS_album)
# /wiki/Wake_Up_(BTS_album)
# /wiki/Youth_(BTS_album)
# /wiki/Face_Yourself
# /wiki/O!RUL8,2%3F
# /wiki/Skool_Luv_Affair
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_1
# /wiki/The_Most_Beautiful_Moment_in_Life,_Part_2
# /wiki/2_Cool_4_Skool
# /wiki/I_Need_U_(BTS_song)
# /wiki/Run_(BTS_song)
# /wiki/Fire_(BTS_song)
# /wiki/Save_Me_(BTS_song)
# /wiki/Blood_Sweat_%26_Tears_(song)
# /wiki/Spring_Day_(song)
# /wiki/Not_Today_(BTS_song)
# /wiki/DNA_(BTS_song)
# /wiki/Mic_Drop_(song)
# /wiki/Don%27t_Leave_Me_(BTS_song)
# /wiki/Fake_Love_(BTS_song)
# /wiki/Idol_(BTS_song)
# /wiki/Airplane_Pt._2
# /wiki/Boy_with_Luv
# /wiki/Make_It_Right_(BTS_song)
# /wiki/Lights_(BTS_song)
# /wiki/Black_Swan_(song)
# /wiki/On_(song)
# /wiki/Waste_It_on_Me
# /wiki/Serendipity_(BTS_song)
# /wiki/Euphoria_(BTS_song)
# /wiki/Singularity_(song)
# /wiki/Epiphany_(BTS_song)
# /wiki/Persona_(song)
# /wiki/Home_(BTS_song)
# /wiki/Dionysus_(song)
# /wiki/Dream_Glow
# /wiki/A_Brand_New_Day_(BTS_and_Zara_Larsson_song)
# /wiki/All_Night_(BTS_and_Juice_Wrld_song)
# /wiki/Heartbeat_(BTS_song)
# /wiki/List_of_BTS_concert_tours
# /wiki/The_Red_Bullet_Tour
# /wiki/The_Most_Beautiful_Moment_in_Life_On_Stage_Tour
# /wiki/The_Wings_Tour
# /wiki/Love_Yourself_World_Tour
# /wiki/Map_of_the_Soul_Tour
# /wiki/Love_Myself_(campaign)
# /wiki/Run_BTS
# /wiki/Love_Yourself_in_Seoul
# /wiki/BTS_albums_discography
# /wiki/BTS_singles_discography
# /wiki/List_of_awards_and_nominations_received_by_BTS
# /wiki/BTS_videography
# /wiki/BTS_World
# /wiki/Save_Me_(webtoon)
# /wiki/List_of_awards_and_nominations_received_by_BTS
# /wiki/Golden_Disc_Award#Newcomer_Winners.2F_New_Artist_of_the_Year
# /wiki/Kim_Wan-sun
# /wiki/Byun_Jin-sub
# /wiki/Lee_Tzsche
# /wiki/Yoon_Sang
# /wiki/Two_Two
# /wiki/H.O.T._(band)
# /wiki/Yangpa
# /wiki/Jinusean
# /wiki/S.E.S._(band)
# /wiki/Fin.K.L
# /wiki/Lee_Jung-hyun
# /wiki/1TYM
# /wiki/Chakra_(band)
# /wiki/Park_Hyo-shin
# /wiki/Choi_Jin-young
# /wiki/Sung_Si-kyung
# /wiki/Jang_Na-ra
# /wiki/Rain_(entertainer)
# /wiki/Wheesung
# /wiki/Seven_(Korean_singer)
# /wiki/Big_Mama_(band)
# /wiki/SG_Wannabe
# /wiki/Tei_(singer)
# /wiki/Eru_(singer)
# /wiki/Ivy_(South_Korean_singer)
# /wiki/Lim_Jeong-hee
# /wiki/Super_Junior
# /wiki/SeeYa
# /wiki/Gavy_NJ
# /wiki/F.T._Island
# /wiki/Wonder_Girls
# /wiki/Girls%27_Generation
# /wiki/Younha
# /wiki/SHINee
# /wiki/Davichi
# /wiki/4Minute
# /wiki/T-ara
# /wiki/Beast_(South_Korean_band)
# /wiki/Miss_A
# /wiki/Secret_(Korean_band)
# /wiki/Apink
# /wiki/B1A4
# /wiki/Dal_Shabet
# /wiki/Boyfriend_(band)
# /wiki/Huh_Gak
# /wiki/Exo_(band)
# /wiki/Juniel
# /wiki/B.A.P_(band)
# /wiki/Ailee
# /wiki/Lee_Hi
# /wiki/Roy_Kim
# /wiki/Lim_Kim
# /wiki/Crayon_Pop
# /wiki/Got7
# /wiki/Winner_(band)
# /wiki/Red_Velvet_(group)
# /wiki/GFriend
# /wiki/IKon
# /wiki/Seventeen_(South_Korean_band)
# /wiki/Twice_(group)
# /wiki/Blackpink
# /wiki/Bolbbalgan4
# /wiki/NCT_127
# /wiki/I.O.I
# /wiki/Wanna_One
# /wiki/(G)I-dle
# /wiki/Iz*One
# /wiki/Stray_Kids
# /wiki/Golden_Disc_Awards
# /wiki/Cho_Yong-pil
# /wiki/Lee_Moon-sae
# /wiki/Joo_Hyun-mi
# /wiki/Byun_Jin-sub
# /wiki/Byun_Jin-sub
# /wiki/Kim_Hyun-sik
# /wiki/Shin_Seung-hun
# /wiki/Shin_Seung-hun
# /wiki/Kim_Gun-mo
# /wiki/Kim_Gun-mo
# /wiki/Kim_Gun-mo
# /wiki/H.O.T
# /wiki/Kim_Jong-hwan_(singer)
# /wiki/Jo_Sung-mo
# /wiki/Jo_Sung-mo
# /wiki/Chapter_4_(g.o.d_album)
# /wiki/G.o.d
# /wiki/Cool_(South_Korean_band)
# /wiki/Jo_Sung-mo
# /wiki/The_Colors_of_My_Life
# /wiki/Lee_Soo-young
# /wiki/Saldaga
# /wiki/SG_Wannabe
# /wiki/%22O%22-Jung.Ban.Hap.
# /wiki/TVXQ
# /wiki/The_Sentimental_Chord
# /wiki/SG_Wannabe
# /wiki/Mirotic
# /wiki/TVXQ
# /wiki/Sorry,_Sorry
# /wiki/Super_Junior
# /wiki/Oh!_(Girls%27_Generation_album)
# /wiki/Girls%27_Generation
# /wiki/Mr._Simple
# /wiki/Super_Junior
# /wiki/Sexy,_Free_%26_Single
# /wiki/Super_Junior
# /wiki/XOXO_(album)
# /wiki/Exo_(band)
# /wiki/Overdose_(EP)
# /wiki/Exo_(band)
# /wiki/Exodus_(Exo_album)
# /wiki/Exo_(band)
# /wiki/Ex%27Act
# /wiki/Exo_(band)
# /wiki/Ivy_(South_Korean_singer)
# /wiki/SG_Wannabe
# /wiki/Jewelry_(band)
# /wiki/Gee_(Girls%27_Generation_song)
# /wiki/Girls%27_Generation
# /wiki/Can%27t_Let_You_Go_Even_If_I_Die
# /wiki/2AM_(band)
# /wiki/The_Boys_(Girls%27_Generation_song)
# /wiki/Girls%27_Generation
# /wiki/Gangnam_Style
# /wiki/PSY
# /wiki/Gentleman_(Psy_song)
# /wiki/PSY
# /wiki/Eyes,_Nose,_Lips
# /wiki/Taeyang
# /wiki/Loser_(Big_Bang_song)
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Cheer_Up_(song)
# /wiki/Twice_(band)
# /wiki/Through_the_Night_(IU_song)
# /wiki/IU_(singer)
# /wiki/Love_Scenario
# /wiki/IKon
# /wiki/Boy_with_Luv
# /wiki/Seoul_Music_Awards#Daesang_Award_.28Grand_Prize.29
# /wiki/Byun_Jin-sub
# /wiki/Tae_Jin-ah
# /wiki/Seo_Taiji_and_Boys
# /wiki/Kim_Gun-mo
# /wiki/Roo%27ra
# /wiki/Clon_(duo)
# /wiki/H.O.T._(band)
# /wiki/Sechs_Kies
# /wiki/Jo_Sung-mo
# /wiki/Fin.K.L
# /wiki/Jo_Sung-mo
# /wiki/Kim_Gun-mo
# /wiki/BoA
# /wiki/Lee_Hyori
# /wiki/Shinhwa
# /wiki/TVXQ
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Wonder_Girls
# /wiki/Girls%27_Generation
# /wiki/Super_Junior
# /wiki/Psy
# /wiki/Exo_(band)
# /wiki/Four_Seasons_(song)
# /wiki/Taeyeon
# /wiki/Forbes_Korea_Power_Celebrity
# /wiki/Yuna_Kim
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Wonder_Girls
# /wiki/Lee_Hyori
# /wiki/Girls%27_Generation
# /wiki/Park_Ji-sung
# /wiki/Lee_Seung-yuop
# /wiki/Rain_(entertainer)
# /wiki/Yoo_Jae-suk
# /wiki/Kim_Tae-hee
# /wiki/Yuna_Kim
# /wiki/Girls%27_Generation
# /wiki/Park_Ji-sung
# /wiki/Lee_Byung-hun
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Go_Hyun-jung
# /wiki/Lee_Seung-gi
# /wiki/Lee_Hyori
# /wiki/Yoo_Jae-suk
# /wiki/Kang_Ho-dong
# /wiki/Girls%27_Generation
# /wiki/Park_Ji-sung
# /wiki/Yuna_Kim
# /wiki/Lee_Seung-gi
# /wiki/2PM
# /wiki/Yoo_Jae-suk
# /wiki/Lee_Chung-yong
# /wiki/2AM_(band)
# /wiki/Shin-Soo_Choo
# /wiki/Kang_Ho-dong
# /wiki/Girls%27_Generation
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/IU_(singer)
# /wiki/Kara_(South_Korean_band)
# /wiki/Yuna_Kim
# /wiki/Lee_Seung-gi
# /wiki/Park_Ji-sung
# /wiki/Kim_Tae-hee
# /wiki/Beast_(South_Korean_band)
# /wiki/Park_Tae-hwan
# /wiki/Psy
# /wiki/Girls%27_Generation
# /wiki/Son_Yeon-jae
# /wiki/Kim_Soo-hyun
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Park_Tae-hwan
# /wiki/Song_Joong-ki
# /wiki/IU_(singer)
# /wiki/Yuna_Kim
# /wiki/Super_Junior
# /wiki/Girls%27_Generation
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Bae_Suzy
# /wiki/Hyun-jin_Ryu
# /wiki/Exo_(band)
# /wiki/Shin-Soo_Choo
# /wiki/TVXQ
# /wiki/Shinee
# /wiki/Yuna_Kim
# /wiki/IU_(singer)
# /wiki/Exo_(band)
# /wiki/Kim_Soo-hyun
# /wiki/Yuna_Kim
# /wiki/Jun_Ji-hyun
# /wiki/Son_Yeon-jae
# /wiki/Lee_Seung-gi
# /wiki/Hyun-jin_Ryu
# /wiki/Son_Heung-min
# /wiki/Girls%27_Generation
# /wiki/Sistar
# /wiki/Exo_(band)
# /wiki/Yoo_Ah-in
# /wiki/Lee_Hye-ri
# /wiki/Girls%27_Generation
# /wiki/Kim_Soo-hyun
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Inbee_Park
# /wiki/Jun_Ji-hyun
# /wiki/IU_(singer)
# /wiki/Jung-ho_Kang
# /wiki/Park_Bo-gum
# /wiki/Song_Joong-ki
# /wiki/Twice_(band)
# /wiki/Exo_(band)
# /wiki/Bae_Suzy
# /wiki/Song_Hye-kyo
# /wiki/Kim_Yoo-jung
# /wiki/Jo_Jung-suk
# /wiki/Seung-hwan_Oh
# /wiki/Wanna_One
# /wiki/Twice_(band)
# /wiki/Exo_(band)
# /wiki/IU_(singer)
# /wiki/Song_Hye-kyo
# /wiki/Song_Joong-ki
# /wiki/Park_Bo-gum
# /wiki/Yuna_Kim
# /wiki/Hyun-jin_Ryu
# /wiki/Blackpink
# /wiki/Wanna_One
# /wiki/Kang_Daniel
# /wiki/Red_Velvet_(group)
# /wiki/Park_Na-rae_(comedian)
# /wiki/Hong_Jin-young
# /wiki/Han_Ji-min
# /wiki/Son_Heung-min
# /wiki/Exo_(band)
# /wiki/Mnet_Asian_Music_Award_for_Album_of_the_Year
# /wiki/The_3rd_Masterpiece
# /wiki/SG_Wannabe
# /wiki/Remapping_the_Human_Soul
# /wiki/Epik_High
# /wiki/Mirotic
# /wiki/TVXQ
# /wiki/Heartbreaker_(G-Dragon_album)
# /wiki/G-Dragon
# /wiki/To_Anyone
# /wiki/2NE1
# /wiki/Mr._Simple
# /wiki/Super_Junior
# /wiki/Sexy,_Free_%26_Single
# /wiki/Super_Junior
# /wiki/XOXO_(album)
# /wiki/Exo_(band)
# /wiki/Overdose_(EP)
# /wiki/Exo_(band)
# /wiki/Exodus_(Exo_album)
# /wiki/Exo_(band)
# /wiki/Ex%27Act
# /wiki/Exo_(band)
# /wiki/The_War_(album)
# /wiki/Exo_(band)
# /wiki/Mnet_Asian_Music_Award_for_Artist_of_the_Year
# /wiki/TVXQ
# /wiki/Super_Junior
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/2PM
# /wiki/2NE1
# /wiki/Girls%27_Generation
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/G-Dragon
# /wiki/Exo_(band)
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Mnet_Asian_Music_Award_for_Song_of_the_Year
# /wiki/SG_Wannabe
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Lies_(Big_Bang_song)
# /wiki/Wonder_Girls
# /wiki/Nobody_(Wonder_Girls_song)
# /wiki/2NE1
# /wiki/I_Don%27t_Care_(2NE1_song)
# /wiki/Miss_A
# /wiki/Bad_Girl_Good_Girl
# /wiki/2NE1
# /wiki/I_Am_the_Best
# /wiki/Psy
# /wiki/Gangnam_Style
# /wiki/Cho_Yong-pil
# /wiki/Taeyang
# /wiki/Eyes,_Nose,_Lips
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Bang_Bang_Bang_(Big_Bang_song)
# /wiki/Twice_(band)
# /wiki/Cheer_Up_(song)
# /wiki/Twice_(band)
# /wiki/Signal_(Twice_song)
# /wiki/Twice_(band)
# /wiki/What_Is_Love%3F_(Twice_song)
# /wiki/Boy_with_Luv
# /wiki/Big_Hit_Entertainment
# /wiki/Big_Hit_Entertainment_Discography
# /wiki/Bang_Si-hyuk
# /wiki/Suga_(entertainer)
# /wiki/J-Hope
# /wiki/Lee_Hyun
# /wiki/RM_(rapper)
# /wiki/8Eight
# /wiki/TXT_(band)
# /wiki/2AM_(band)
# /wiki/Glam_(band)
# /wiki/Lim_Jeong-hee
# /wiki/Homme_(band)
# /wiki/Lee_Chang-min_(singer)
# /wiki/Source_Music
# /wiki/GFriend
# /wiki/Signal_Entertainment_Group
# /wiki/Kakao_M
# /wiki/Iriver_Inc
# /wiki/K-pop
# /wiki/Integrated_Authority_File
# /wiki/International_Standard_Name_Identifier
# /wiki/Library_of_Congress_Control_Number
# /wiki/MusicBrainz
# /wiki/National_Library_of_Korea
# /wiki/RERO_(Library_Network_of_Western_Switzerland)
# /wiki/Virtual_International_Authority_File
# /wiki/WorldCat_Identities

# %% [markdown]
# ### 함수화_ver0
# 위의 과정을 함수화한다. 그러나, ver0에서는 계속 실행하면 재귀 호출 횟수 제한으로 인해 `RecursionError` 발생한다.
#
#
#
# 1. **`getLinks`** 함수
#     * 페이지를 읽어 와서 그 페이지의 BeautifulSoup 객체를 반환.
#     * 에러가 발생할 때, `None` 반환.
#     * 읽어온 페이지에서 모든 항목 링크를 반환.
#
#
# 2. **메인 함수**
#     * 시작 항목에서 getLinks를 호출해 항목 링크를 반환하고, 그 항목 링크를 무작위로 선택하여 getLinks를 다시 호출.
#     * 프로그램이 끝나거나, 새 페이지에 항목 링크가 없을 때까지 위의 작업을 반복.
#
#
# #### 작동 원리
#     * 현재 시스템 시간으로 난수 시드 설정 : 프로그램을 실행할 때마다 새로운 무작위 경로 탐색.
#     * "/wiki/"로 시작하는 URL을 받고, 그 앞에 위키백과 도메인 "http://en.wikipedia.org"을 붙인다. 이를 시작점으로 하여, 해당 위치의 HTML에서 BeautifulSoup 객체를 가져온다.
#     * 위 페이지에서 모든 항목 링크 태그를 반환한다.
#     * 메인 함수에서 루프를 실행하며 항목 링크를 무작위로 선택한다.
#     * 새롭게 선택한 링크에서 `href` 속성을 추출한다.
#     * 다시 URL을 받는 단계로 돌아가 페이지를 출력하고, URL에서 새 링크 목록을 가져온다.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import datetime
import random

random.seed(datetime.datetime.now())

def getLinks(articleUrl):
    try:
        html = urlopen("http://en.wikipedia.org{}".format(articleUrl))
    except HTTPError as e:
        print("접속에 실패하였습니다. {}".format(e))
        return None
    try:
        bs = BeautifulSoup(html, 'html5lib')
        print("{} 페이지를 읽어 왔습니다.".format(bs.h1.get_text()))
    except AttributeError as e:
        print("error! no such tag!")
        return None
    return bs.find('div', {'id' : 'bodyContent'})\
              .findAll('a', {'href' : re.compile("^(/wiki/)((?!:).)*$")})


cnt = 0 # 링크 몇 번 탔는지 횟수 세기

links = getLinks('/wiki/BTS') # 시작점

while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    cnt += 1 # 새로운 기사 찾으면 일단 더하고
    if 'TXT_(band)' in newArticle: # 찾는 문서 나오면 멈추고
        break
    else: # 아니면 다시 진행
        links = getLinks(newArticle)

print(cnt)
# Out:
# BTS 페이지를 읽어 왔습니다.
# /wiki/Shinee
# Shinee 페이지를 읽어 왔습니다.
# /wiki/Luhan_(entertainer)
# Lu Han 페이지를 읽어 왔습니다.
# /wiki/Exo-CBX
# Exo-CBX 페이지를 읽어 왔습니다.
# /wiki/Blooming_Days
# Blooming Days 페이지를 읽어 왔습니다.
# /wiki/Magic_(Exo-CBX_album)
# Magic (Exo-CBX album) 페이지를 읽어 왔습니다.
# /wiki/Ballad
# Ballad 페이지를 읽어 왔습니다.
# /wiki/Walter_Scott
# Walter Scott 페이지를 읽어 왔습니다.
# /wiki/Edvard_Grieg
# Edvard Grieg 페이지를 읽어 왔습니다.
# /wiki/Finland
# Finland 페이지를 읽어 왔습니다.
# /wiki/Mauritz_Stiller
# Mauritz Stiller 페이지를 읽어 왔습니다.
# /wiki/Helsinki
# Helsinki 페이지를 읽어 왔습니다.
# /wiki/Stockholm
# Stockholm 페이지를 읽어 왔습니다.
# /wiki/Leith
# Leith 페이지를 읽어 왔습니다.
# /wiki/Firth_of_Forth
# Firth of Forth 페이지를 읽어 왔습니다.
# /wiki/Charlestown,_Fife
# Charlestown, Fife 페이지를 읽어 왔습니다.
# /wiki/Gazetteer_for_Scotland
# Gazetteer for Scotland 페이지를 읽어 왔습니다.
# /wiki/Gazetteer
# Gazetteer 페이지를 읽어 왔습니다.
# /wiki/Composite_Gazetteer_of_Antarctica
# Composite Gazetteer of Antarctica 페이지를 읽어 왔습니다.
# /wiki/United_Kingdom
# United Kingdom 페이지를 읽어 왔습니다.
# /wiki/Government_of_Ireland
# Government of Ireland 페이지를 읽어 왔습니다.
# /wiki/Oireachtas
# Oireachtas 페이지를 읽어 왔습니다.
# /wiki/Parliament_of_Guernsey
# States of Guernsey 페이지를 읽어 왔습니다.
# /wiki/Parliament_of_Gibraltar
# Gibraltar Parliament 페이지를 읽어 왔습니다.
# /wiki/Education_in_Gibraltar
# Education in Gibraltar 페이지를 읽어 왔습니다.
# /wiki/Coat_of_arms_of_Gibraltar
# Coat of arms of Gibraltar 페이지를 읽어 왔습니다.
# /wiki/Communications_in_Gibraltar
# Communications in Gibraltar 페이지를 읽어 왔습니다.
# /wiki/Gibraltar_Constitution_Order_1969
# Gibraltar Constitution Order 1969 페이지를 읽어 왔습니다.
# /wiki/Vanguard_Cave
# Vanguard Cave 페이지를 읽어 왔습니다.
# /wiki/Cueva_de_los_Casares
# Cueva de los Casares 페이지를 읽어 왔습니다.
# /wiki/La_Chaire_a_Calvin
# La Chaire a Calvin 페이지를 읽어 왔습니다.
# /wiki/Sirgenstein_Cave
# Sirgenstein Cave 페이지를 읽어 왔습니다.
# /wiki/Ng%C6%B0%E1%BB%9Dm
# Ngườm 페이지를 읽어 왔습니다.
# /wiki/Malta
# Malta 페이지를 읽어 왔습니다.
# /wiki/Belgium
# Belgium 페이지를 읽어 왔습니다.
# /wiki/Mauritius
# Mauritius 페이지를 읽어 왔습니다.
# /wiki/Coat_of_arms_of_Mauritius
# Coat of arms of Mauritius 페이지를 읽어 왔습니다.
# /wiki/Coat_of_arms_of_Gabon
# Coat of arms of Gabon 페이지를 읽어 왔습니다.
# /wiki/Coat_of_arms_of_Cape_Verde
# National emblem of Cape Verde 페이지를 읽어 왔습니다.
# /wiki/List_of_islands_of_Cape_Verde
# List of islands of Cape Verde 페이지를 읽어 왔습니다.
# /wiki/Transport_in_Cape_Verde
# Transport in Cape Verde 페이지를 읽어 왔습니다.
# /wiki/LGBT_rights_in_Cape_Verde
# LGBT rights in Cape Verde 페이지를 읽어 왔습니다.
# /wiki/LGBT_rights_in_Seychelles
# LGBT rights in Seychelles 페이지를 읽어 왔습니다.
# /wiki/Sexual_orientation_and_military_service
# Sexual orientation and gender identity in military service 페이지를 읽어 왔습니다.
# /wiki/Alcohol_abuse
# Alcohol abuse 페이지를 읽어 왔습니다.
# /wiki/Spins
# Spins 페이지를 읽어 왔습니다.
# /wiki/Alcohol_and_health
# Alcohol and health 페이지를 읽어 왔습니다.
# /wiki/Tonic_water
# Tonic water 페이지를 읽어 왔습니다.
# /wiki/%C3%81gua_de_Inglaterra
# Água de Inglaterra 페이지를 읽어 왔습니다.
# /wiki/Guadiana
# Guadiana 페이지를 읽어 왔습니다.
# /wiki/Pliny_the_Elder
# Pliny the Elder 페이지를 읽어 왔습니다.
# /wiki/Gens
# Gens 페이지를 읽어 왔습니다.
# /wiki/Michael_Grant_(author)
# Michael Grant (classicist) 페이지를 읽어 왔습니다.
# /wiki/International_Standard_Name_Identifier
# International Standard Name Identifier 페이지를 읽어 왔습니다.
# /wiki/Biblioth%C3%A8que_nationale_de_Luxembourg
# National Library of Luxembourg 페이지를 읽어 왔습니다.
# /wiki/National_Library_of_Serbia
# National Library of Serbia 페이지를 읽어 왔습니다.
# /wiki/Map
# Map 페이지를 읽어 왔습니다.
# /wiki/Automatic_label_placement
# Automatic label placement 페이지를 읽어 왔습니다.
# /wiki/Genetic_algorithm
# Genetic algorithm 페이지를 읽어 왔습니다.
# /wiki/Evolutionary_algorithms
# Evolutionary algorithm 페이지를 읽어 왔습니다.
# /wiki/Differential_evolution
# Differential evolution 페이지를 읽어 왔습니다.
# /wiki/Cellular_evolutionary_algorithm
# Cellular evolutionary algorithm 페이지를 읽어 왔습니다.
# /wiki/Interactive_evolutionary_computation
# Interactive evolutionary computation 페이지를 읽어 왔습니다.
# /wiki/Artificial_life
# Artificial life 페이지를 읽어 왔습니다.
# /wiki/Evolutionary_art
# Evolutionary art 페이지를 읽어 왔습니다.
# /wiki/Computational_aesthetics
# Aesthetics 페이지를 읽어 왔습니다.
# /wiki/Czech_philosophy
# Czech philosophy 페이지를 읽어 왔습니다.
# /wiki/Energy_in_the_Czech_Republic
# Energy in the Czech Republic 페이지를 읽어 왔습니다.
# /wiki/Energy_in_Belgium
# Energy in Belgium 페이지를 읽어 왔습니다.
# /wiki/Kyoto_Protocol
# Kyoto Protocol 페이지를 읽어 왔습니다.
# /wiki/Carbon_emission_trading
# Carbon emission trading 페이지를 읽어 왔습니다.
# /wiki/Pollution_haven_hypothesis
# Pollution haven hypothesis 페이지를 읽어 왔습니다.
# /wiki/Political_globalization
# Political globalization 페이지를 읽어 왔습니다.
# /wiki/ETH_Zurich
# ETH Zurich 페이지를 읽어 왔습니다.
# /wiki/Vrije_Universiteit_Brussel
# Vrije Universiteit Brussel 페이지를 읽어 왔습니다.
# /wiki/Julia_Gillard
# Julia Gillard 페이지를 읽어 왔습니다.
# /wiki/Preselection
# Preselection 페이지를 읽어 왔습니다.
# /wiki/Political_system
# Political system 페이지를 읽어 왔습니다.
# /wiki/Separation_of_powers
# Separation of powers 페이지를 읽어 왔습니다.
# /wiki/Mary_Wollstonecraft
# Mary Wollstonecraft 페이지를 읽어 왔습니다.
# /wiki/Luis_Firm%C3%ADn_de_Carvajal,_Conde_de_la_Uni%C3%B3n
# Luis Firmín de Carvajal, Conde de la Unión 페이지를 읽어 왔습니다.
# /wiki/First_French_Republic
# French First Republic 페이지를 읽어 왔습니다.
# /wiki/Jean_Victor_Marie_Moreau
# Jean Victor Marie Moreau 페이지를 읽어 왔습니다.
# /wiki/Constitution_of_the_Year_III
# Constitution of the Year III 페이지를 읽어 왔습니다.
# /wiki/Battle_of_Rivoli
# Battle of Rivoli 페이지를 읽어 왔습니다.
# /wiki/International_Standard_Book_Number
# International Standard Book Number 페이지를 읽어 왔습니다.
# /wiki/ISO/IEC_17025
# ISO/IEC 17025 페이지를 읽어 왔습니다.
# /wiki/ISO/IEC_11404
# ISO/IEC 11404 페이지를 읽어 왔습니다.
# /wiki/ISO/IEC_5218
# ISO/IEC 5218 페이지를 읽어 왔습니다.
# /wiki/Film_speed
# Film speed 페이지를 읽어 왔습니다.
# /wiki/Logarithmic_scale
# Logarithmic scale 페이지를 읽어 왔습니다.
# /wiki/Neper
# Neper 페이지를 읽어 왔습니다.
# /wiki/Metre
# Metre 페이지를 읽어 왔습니다.
# /wiki/Giovanni_Domenico_Cassini
# Giovanni Domenico Cassini 페이지를 읽어 왔습니다.
# /wiki/Parallax
# Parallax 페이지를 읽어 왔습니다.
# /wiki/Aristarchus_On_the_Sizes_and_Distances
# On the Sizes and Distances (Aristarchus) 페이지를 읽어 왔습니다.
# /wiki/Hypatia
# Hypatia 페이지를 읽어 왔습니다.
# /wiki/Wilbur_Knorr
# Wilbur Knorr 페이지를 읽어 왔습니다.
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# Système universitaire de documentation 페이지를 읽어 왔습니다.
# /wiki/Terminologia_Histologica
# Terminologia Histologica 페이지를 읽어 왔습니다.
# /wiki/Gallbladder
# Gallbladder 페이지를 읽어 왔습니다.
# /wiki/Serosa
# Serous membrane 페이지를 읽어 왔습니다.
# /wiki/Pleura
# Pulmonary pleurae 페이지를 읽어 왔습니다.
# /wiki/Latin
# Latin 페이지를 읽어 왔습니다.
# /wiki/List_of_Latin_phrases
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1253         """Send a complete request to the server."""
# -> 1254         self._send_request(method, url, body, headers, encode_chunked)
#    1255
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             body = _encode(body, 'body')
# -> 1300         self.endheaders(body, encode_chunked=encode_chunked)
#    1301
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1248             raise CannotSendHeader()
# -> 1249         self._send_output(message_body, encode_chunked=encode_chunked)
#    1250
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in connect(self)
#     945         self.sock = self._create_connection(
# --> 946             (self.host,self.port), self.timeout, self.source_address)
#     947         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\Anaconda3\envs\cpu_env\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# ~\Anaconda3\envs\cpu_env\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-24-ce45c2288495> in <module>
#      35         break
#      36     else: # 아니면 다시 진행
# ---> 37         links = getLinks(newArticle)
#      38
#      39 print(cnt)
#
# <ipython-input-24-ce45c2288495> in getLinks(articleUrl)
#      10 def getLinks(articleUrl):
#      11     try:
# ---> 12         html = urlopen("http://en.wikipedia.org{}".format(articleUrl))
#      13     except HTTPError as e:
#      14         print("접속에 실패하였습니다. {}".format(e))
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다>

# %% [markdown]
# ### 함수화_ver1
#
#  보통 많은 웹사이트에서 내부 링크는 중복이다. 따라서 새로운 링크만 탐색하고, 그 안에서 다른 링크를 검색하도록 **set**을 사용한다.
#
# 1. 빈 URL넘겨 getLinks 호출.
# 2. getLinks 함수 내부에서 빈 URL과 위키피디아 도메인을 합쳐 위키피디아 첫 페이지로 간다.
# 3. 첫 페이지에서 각 항목 링크를 돌며 `pages`에 저장되어 있는지 검사.
# 4. 들어 있지 않은 링크라면 리스트에 출력하고, 화면에 출력한 다음, `getLinks` 함수 재귀적으로 호출.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import datetime
import random

random.seed(datetime.datetime.now())

pages = set()
cnt = 0

def getLinks(pageUrl, targetWord):
    global pages
    global cnt
    
    try:
        html = urlopen("http://en.wikipedia.org{}".format(pageUrl))
    except HTTPError as e:
        print("접속에 실패하였습니다. {}".format(3))
        return None
    try:
        bs = BeautifulSoup(html, 'lxml')
        print("{} 페이지를 읽어 왔습니다.".format(bs.h1.get_text()))
    except AttributeError as e:
        print("{}! no such tag!".format(e))
        return None
    
    for link in bs.findAll('a', {'href':re.compile("^(/wiki/)((?!:).)*$")}):
        # 첫 페이지에서 시작하므로, bodyContent 조건 완화.
        
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages: # 이전에 발견하지 못한 페이지
                newPage = link.attrs['href']
                cnt += 1
                if cnt <= 30:
                    print(newPage)
                else:
                    print("...")
                    
                if targetWord in newPage: # 책 코드 수정
                    return cnt
                
                pages.add(newPage)
                getLinks(newPage, 'BTS')
        
getLinks('', 'BTS')
# Out:
# Main Page 페이지를 읽어 왔습니다.
# /wiki/Wikipedia
# Wikipedia 페이지를 읽어 왔습니다.
# /wiki/English_Wikipedia
# English Wikipedia 페이지를 읽어 왔습니다.
# /wiki/Internet_encyclopedia
# Online encyclopedia 페이지를 읽어 왔습니다.
# /wiki/CD-ROM_encyclopedia
# CD-ROM encyclopedia 페이지를 읽어 왔습니다.
# /wiki/Encyclopedia
# Encyclopedia 페이지를 읽어 왔습니다.
# /wiki/Encyclopedia_(disambiguation)
# Encyclopedia (disambiguation) 페이지를 읽어 왔습니다.
# /wiki/Encyclopedia_(album)
# Encyclopedia (album) 페이지를 읽어 왔습니다.
# /wiki/Album
# Album 페이지를 읽어 왔습니다.
# /wiki/Album_(disambiguation)
# Album (disambiguation) 페이지를 읽어 왔습니다.
# /wiki/Album_%E2%80%93_Generic_Flipper
# Album – Generic Flipper 페이지를 읽어 왔습니다.
# /wiki/Flipper_(band)
# Flipper (band) 페이지를 읽어 왔습니다.
# /wiki/San_Francisco,_California
# San Francisco 페이지를 읽어 왔습니다.
# /wiki/San_Francisco_(disambiguation)
# San Francisco (disambiguation) 페이지를 읽어 왔습니다.
# /wiki/San_Francisco
# San Francisco 페이지를 읽어 왔습니다.
# /wiki/Consolidated_city-county
# Consolidated city-county 페이지를 읽어 왔습니다.
# /wiki/Political_divisions_of_the_United_States
# Political divisions of the United States 페이지를 읽어 왔습니다.
# /wiki/U.S._state
# U.S. state 페이지를 읽어 왔습니다.
# /wiki/Commonwealth_(U.S._state)
# Commonwealth (U.S. state) 페이지를 읽어 왔습니다.
# /wiki/Commonwealth_(U.S._insular_area)
# Commonwealth (U.S. insular area) 페이지를 읽어 왔습니다.
# /wiki/Commonwealth_(disambiguation)
# Commonwealth (disambiguation) 페이지를 읽어 왔습니다.
# /wiki/Commonwealth
# Commonwealth 페이지를 읽어 왔습니다.
# /wiki/Commonwealth_of_Nations
# Commonwealth of Nations 페이지를 읽어 왔습니다.
# /wiki/Commonwealth_of_Independent_States
# Commonwealth of Independent States 페이지를 읽어 왔습니다.
# /wiki/Russian_language
# Russian language 페이지를 읽어 왔습니다.
# /wiki/Rusyn_language
# Rusyn language 페이지를 읽어 왔습니다.
# /wiki/Ruthenian_language
# Ruthenian language 페이지를 읽어 왔습니다.
# /wiki/Classical_Belarusian
# Taraškievica 페이지를 읽어 왔습니다.
# /wiki/Branis%C5%82a%C5%AD_Tara%C5%A1kievi%C4%8D
# Branislaw Tarashkyevich 페이지를 읽어 왔습니다.
# /wiki/Ma%C4%8Diuli%C5%A1k%C4%97s
# Mačiuliškės 페이지를 읽어 왔습니다.
# /wiki/Geographic_coordinate_system
# Geographic coordinate system 페이지를 읽어 왔습니다.
# ...
# Geodesy 페이지를 읽어 왔습니다.
# ...
# Ostend 페이지를 읽어 왔습니다.
# ...
# Ostend (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Ostend, Essex 페이지를 읽어 왔습니다.
# ...
# Essex 페이지를 읽어 왔습니다.
# ...
# Essex (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Kingdom of Essex 페이지를 읽어 왔습니다.
# ...
# Old English 페이지를 읽어 왔습니다.
# ...
# Old English (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Old English 페이지를 읽어 왔습니다.
# ...
# Beowulf 페이지를 읽어 왔습니다.
# ...
# Beowulf (hero) 페이지를 읽어 왔습니다.
# ...
# Monarch 페이지를 읽어 왔습니다.
# ...
# Monarch (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Monarchy 페이지를 읽어 왔습니다.
# ...
# Monarch (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Danaus (butterfly) 페이지를 읽어 왔습니다.
# ...
# Danaus chrysippus 페이지를 읽어 왔습니다.
# ...
# Kerala 페이지를 읽어 왔습니다.
# ...
# Kerala (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Kerala Kingdom 페이지를 읽어 왔습니다.
# ...
# Epic poetry 페이지를 읽어 왔습니다.
# ...
# Epic 페이지를 읽어 왔습니다.
# ...
# Epic film 페이지를 읽어 왔습니다.
# ...
# Cabiria 페이지를 읽어 왔습니다.
# ...
# Giovanni Pastrone 페이지를 읽어 왔습니다.
# ...
# Montechiaro d'Asti 페이지를 읽어 왔습니다.
# ...
# Comune 페이지를 읽어 왔습니다.
# ...
# Comunes Collective 페이지를 읽어 왔습니다.
# ...
# Nonprofit organization 페이지를 읽어 왔습니다.
# ...
# Economic surplus 페이지를 읽어 왔습니다.
# ...
# Surplus 페이지를 읽어 왔습니다.
# ...
# Excess supply 페이지를 읽어 왔습니다.
# ...
# Economics 페이지를 읽어 왔습니다.
# ...
# Economics (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Economics (textbook) 페이지를 읽어 왔습니다.
# ...
# Paul Samuelson 페이지를 읽어 왔습니다.
# ...
# Gary, Indiana 페이지를 읽어 왔습니다.
# ...
# City 페이지를 읽어 왔습니다.
# ...
# City (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Altstadt (Zürich) 페이지를 읽어 왔습니다.
# ...
# Cantons of Switzerland 페이지를 읽어 왔습니다.
# ...
# German language 페이지를 읽어 왔습니다.
# ...
# Deutsch 페이지를 읽어 왔습니다.
# ...
# Germans 페이지를 읽어 왔습니다.
# ...
# Demographics of Germany 페이지를 읽어 왔습니다.
# ...
# West Germany 페이지를 읽어 왔습니다.
# ...
# Germany 페이지를 읽어 왔습니다.
# ...
# Germany (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Germany (European Parliament constituency) 페이지를 읽어 왔습니다.
# ...
# European Parliament constituency 페이지를 읽어 왔습니다.
# ...
# European Union 페이지를 읽어 왔습니다.
# ...
# EU (disambiguation) 페이지를 읽어 왔습니다.
# ...
# .eu 페이지를 읽어 왔습니다.
# ...
# Top-level domain 페이지를 읽어 왔습니다.
# ...
# Mobile Station Roaming Number 페이지를 읽어 왔습니다.
# ...
# E.164 페이지를 읽어 왔습니다.
# ...
# ITU-T 페이지를 읽어 왔습니다.
# ...
# International Telecommunication Union 페이지를 읽어 왔습니다.
# ...
# ITU (disambiguation) 페이지를 읽어 왔습니다.
# ...
# International Telecommunication Union 페이지를 읽어 왔습니다.
# ...
# List of specialized agencies of the United Nations 페이지를 읽어 왔습니다.
# ...
# United Nations 페이지를 읽어 왔습니다.
# ...
# United Nations (disambiguation) 페이지를 읽어 왔습니다.
# ...
# United Nations (band) 페이지를 읽어 왔습니다.
# ...
# New York City 페이지를 읽어 왔습니다.
# ...
# New York City (disambiguation) 페이지를 읽어 왔습니다.
# ...
# City of New York (1885 ship) 페이지를 읽어 왔습니다.
# ...
# Norway 페이지를 읽어 왔습니다.
# ...
# Norway (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Upper Beaches 페이지를 읽어 왔습니다.
# ...
# Canada 페이지를 읽어 왔습니다.
# ...
# Canada (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Canada Dock 페이지를 읽어 왔습니다.
# ...
# Kirkdale, Liverpool 페이지를 읽어 왔습니다.
# ...
# Merseyside 페이지를 읽어 왔습니다.
# ...
# Metropolitan county 페이지를 읽어 왔습니다.
# ...
# Metropolitan and non-metropolitan counties of England 페이지를 읽어 왔습니다.
# ...
# Regions of England 페이지를 읽어 왔습니다.
# ...
# NUTS 1 statistical regions of England 페이지를 읽어 왔습니다.
# ...
# England 페이지를 읽어 왔습니다.
# ...
# England (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Kingdom of England 페이지를 읽어 왔습니다.
# ...
# United Kingdom 페이지를 읽어 왔습니다.
# ...
# Great Britain 페이지를 읽어 왔습니다.
# ...
# Kingdom of Great Britain 페이지를 읽어 왔습니다.
# ...
# Scots language 페이지를 읽어 왔습니다.
# ...
# SCO 페이지를 읽어 왔습니다.
# ...
# Santa Cruz Operation 페이지를 읽어 왔습니다.
# ...
# SCO Group 페이지를 읽어 왔습니다.
# ...
# List of legal entity types by country 페이지를 읽어 왔습니다.
# ...
# Company (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Company 페이지를 읽어 왔습니다.
# ...
# Münster 페이지를 읽어 왔습니다.
# ...
# Munster, Lower Saxony 페이지를 읽어 왔습니다.
# ...
# North Rhine-Westphalia 페이지를 읽어 왔습니다.
# ...
# NRW (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Natural Resources Wales 페이지를 읽어 왔습니다.
# ...
# Welsh Government sponsored bodies 페이지를 읽어 왔습니다.
# ...
# Welsh language 페이지를 읽어 왔습니다.
# ...
# Chubut Province 페이지를 읽어 왔습니다.
# ...
# Spanish language 페이지를 읽어 왔습니다.
# ...
# Spain 페이지를 읽어 왔습니다.
# ...
# Spain (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Spain (European Parliament constituency) 페이지를 읽어 왔습니다.
# ...
# Member state of the European Union 페이지를 읽어 왔습니다.
# ...
# Parliamentary system 페이지를 읽어 왔습니다.
# ...
# Republic 페이지를 읽어 왔습니다.
# ...
# Republicanism 페이지를 읽어 왔습니다.
# ...
# Republican 페이지를 읽어 왔습니다.
# ...
# Monarchism 페이지를 읽어 왔습니다.
# ...
# Monarchianism 페이지를 읽어 왔습니다.
# ...
# Christian theology 페이지를 읽어 왔습니다.
# ...
# G. L. Christian and Associates v. United States 페이지를 읽어 왔습니다.
# ...
# John Marvin Jones 페이지를 읽어 왔습니다.
# ...
# Senior status 페이지를 읽어 왔습니다.
# ...
# Retirement 페이지를 읽어 왔습니다.
# ...
# Retirement (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Retirement (Beanie Baby) 페이지를 읽어 왔습니다.
# ...
# Beanie Babies 페이지를 읽어 왔습니다.
# ...
# Stuffed toy 페이지를 읽어 왔습니다.
# ...
# Taxidermy 페이지를 읽어 왔습니다.
# ...
# Taxonomy (biology) 페이지를 읽어 왔습니다.
# ...
# Taxonomy 페이지를 읽어 왔습니다.
# ...
# Taxonomy (general) 페이지를 읽어 왔습니다.
# ...
# Count noun 페이지를 읽어 왔습니다.
# ...
# Grammatical category 페이지를 읽어 왔습니다.
# ...
# Animacy 페이지를 읽어 왔습니다.
# ...
# Grammatical case 페이지를 읽어 왔습니다.
# ...
# Dative construction 페이지를 읽어 왔습니다.
# ...
# Dative shift 페이지를 읽어 왔습니다.
# ...
# Quirky subject 페이지를 읽어 왔습니다.
# ...
# Classifier (linguistics) 페이지를 읽어 왔습니다.
# ...
# Radical (Chinese characters) 페이지를 읽어 왔습니다.
# ...
# Musashi Province 페이지를 읽어 왔습니다.
# ...
# Provinces of Japan 페이지를 읽어 왔습니다.
# ...
# Administrative division 페이지를 읽어 왔습니다.
# ...
# Division (business) 페이지를 읽어 왔습니다.
# ...
# Business 페이지를 읽어 왔습니다.
# ...
# Business (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Goods and services 페이지를 읽어 왔습니다.
# ...
# Capitalism 페이지를 읽어 왔습니다.
# ...
# Capitalism (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Economic liberalism 페이지를 읽어 왔습니다.
# ...
# Industrial Revolution 페이지를 읽어 왔습니다.
# ...
# Roberts Loom 페이지를 읽어 왔습니다.
# ...
# Power loom 페이지를 읽어 왔습니다.
# ...
# Lancashire 페이지를 읽어 왔습니다.
# ...
# Lancashire (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Lancashire, Delaware 페이지를 읽어 왔습니다.
# ...
# Unincorporated area 페이지를 읽어 왔습니다.
# ...
# Main road town 페이지를 읽어 왔습니다.
# ...
# Town 페이지를 읽어 왔습니다.
# ...
# Town (disambiguation) 페이지를 읽어 왔습니다.
# ...
# A. Hays Town 페이지를 읽어 왔습니다.
# ...
# Crowley, Louisiana 페이지를 읽어 왔습니다.
# ...
# List of municipalities in Louisiana 페이지를 읽어 왔습니다.
# ...
# Louisiana 페이지를 읽어 왔습니다.
# ...
# Louisiana (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Louisiana (New France) 페이지를 읽어 왔습니다.
# ...
# New France 페이지를 읽어 왔습니다.
# ...
# Kingdom of Araucanía and Patagonia 페이지를 읽어 왔습니다.
# ...
# List of states with limited recognition 페이지를 읽어 왔습니다.
# ...
# List of territorial disputes 페이지를 읽어 왔습니다.
# ...
# Territorial dispute 페이지를 읽어 왔습니다.
# ...
# Possession (law) 페이지를 읽어 왔습니다.
# ...
# Property law 페이지를 읽어 왔습니다.
# ...
# Common law 페이지를 읽어 왔습니다.
# ...
# Jus commune 페이지를 읽어 왔습니다.
# ...
# Canon law of the Catholic Church 페이지를 읽어 왔습니다.
# ...
# 1983 Code of Canon Law 페이지를 읽어 왔습니다.
# ...
# Code of Canons of the Eastern Churches 페이지를 읽어 왔습니다.
# ...
# Omnium in mentem 페이지를 읽어 왔습니다.
# ...
# Magnum principium 페이지를 읽어 왔습니다.
# ...
# Ad tuendam fidem 페이지를 읽어 왔습니다.
# ...
# Ex Corde Ecclesiae 페이지를 읽어 왔습니다.
# ...
# Indulgentiarum Doctrina 페이지를 읽어 왔습니다.
# ...
# Pastor bonus 페이지를 읽어 왔습니다.
# ...
# Roman Curia 페이지를 읽어 왔습니다.
# ...
# Curia (Catholic Church) 페이지를 읽어 왔습니다.
# ...
# Pontificalis Domus 페이지를 읽어 왔습니다.
# ...
# Veritatis gaudium 페이지를 읽어 왔습니다.
# ...
# Custom (canon law) 페이지를 읽어 왔습니다.
# ...
# Matrimonial nullity trial reforms of Pope Francis 페이지를 읽어 왔습니다.
# ...
# Second Vatican Council 페이지를 읽어 왔습니다.
# ...
# Latin 페이지를 읽어 왔습니다.
# ...
# Latin (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Latin 페이지를 읽어 왔습니다.
# ...
# Colosseum 페이지를 읽어 왔습니다.
# ...
# Colosseum (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Colosseum, Queensland 페이지를 읽어 왔습니다.
# ...
# Queensland 페이지를 읽어 왔습니다.
# ...
# Queensland (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Queensland, Calgary 페이지를 읽어 왔습니다.
# ...
# Calgary 페이지를 읽어 왔습니다.
# ...
# Calgary, Mull 페이지를 읽어 왔습니다.
# ...
# Scottish Gaelic 페이지를 읽어 왔습니다.
# ...
# Goidelic languages 페이지를 읽어 왔습니다.
# ...
# Scottish Gaelic 페이지를 읽어 왔습니다.
# ...
# Irish language 페이지를 읽어 왔습니다.
# ...
# Irish language (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Hiberno-English 페이지를 읽어 왔습니다.
# ...
# Ireland 페이지를 읽어 왔습니다.
# ...
# Republic of Ireland 페이지를 읽어 왔습니다.
# ...
# Ireland (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Northern Ireland 페이지를 읽어 왔습니다.
# ...
# Northern Ireland (European Parliament constituency) 페이지를 읽어 왔습니다.
# ...
# 1979 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 1984 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 1989 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 1994 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 1999 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 2004 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 2009 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 2014 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# 2019 European Parliament election in the United Kingdom 페이지를 읽어 왔습니다.
# ...
# List of members of the European Parliament for the United Kingdom, 2014–19 페이지를 읽어 왔습니다.
# ...
# Member of the European Parliament 페이지를 읽어 왔습니다.
# ...
# MEP 페이지를 읽어 왔습니다.
# ...
# Mahajana Eksath Peramuna 페이지를 읽어 왔습니다.
# ...
# Philip Gunawardena 페이지를 읽어 왔습니다.
# ...
# The Honourable 페이지를 읽어 왔습니다.
# ...
# Honour 페이지를 읽어 왔습니다.
# ...
# Honor (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Honor (given name) 페이지를 읽어 왔습니다.
# ...
# Grammatical gender 페이지를 읽어 왔습니다.
# ...
# Language and gender 페이지를 읽어 왔습니다.
# ...
# Grammatical gender 페이지를 읽어 왔습니다.
# ...
# Gender-neutral language 페이지를 읽어 왔습니다.
# ...
# Gender fair language 페이지를 읽어 왔습니다.
# ...
# Sexism 페이지를 읽어 왔습니다.
# ...
# Sexual orientation discrimination 페이지를 읽어 왔습니다.
# ...
# Sexism 페이지를 읽어 왔습니다.
# ...
# Anti-sex 페이지를 읽어 왔습니다.
# ...
# Pro-feminism 페이지를 읽어 왔습니다.
# ...
# Feminism 페이지를 읽어 왔습니다.
# ...
# Feminists (disambiguation) 페이지를 읽어 왔습니다.
# ...
# List of feminists 페이지를 읽어 왔습니다.
# ...
# Feminist history 페이지를 읽어 왔습니다.
# ...
# History of feminism 페이지를 읽어 왔습니다.
# ...
# Women-only space 페이지를 읽어 왔습니다.
# ...
# Women's history 페이지를 읽어 왔습니다.
# ...
# Legal rights of women in history 페이지를 읽어 왔습니다.
# ...
# Middle Ages 페이지를 읽어 왔습니다.
# ...
# Post-classical history 페이지를 읽어 왔습니다.
# ...
# Post-classical editing 페이지를 읽어 왔습니다.
# ...
# Zach Staenberg 페이지를 읽어 왔습니다.
# ...
# United States 페이지를 읽어 왔습니다.
# ...
# Americas 페이지를 읽어 왔습니다.
# ...
# The Americas (journal) 페이지를 읽어 왔습니다.
# ...
# America (disambiguation) 페이지를 읽어 왔습니다.
# ...
# United States 페이지를 읽어 왔습니다.
# ...
# US (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Us (Peter Gabriel album) 페이지를 읽어 왔습니다.
# ...
# Peter Gabriel 페이지를 읽어 왔습니다.
# ...
# Peter Gabriel (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Peter Gabriel (1977 album) 페이지를 읽어 왔습니다.
# ...
# Toronto 페이지를 읽어 왔습니다.
# ...
# Toronto (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Greater Toronto Area 페이지를 읽어 왔습니다.
# ...
# Metropolitan Toronto 페이지를 읽어 왔습니다.
# ...
# Metro Hall 페이지를 읽어 왔습니다.
# ...
# Louisville Metro Hall 페이지를 읽어 왔습니다.
# ...
# National Register of Historic Places 페이지를 읽어 왔습니다.
# ...
# Canadian Register of Historic Places 페이지를 읽어 왔습니다.
# ...
# Comprehensive Rural Health Project 페이지를 읽어 왔습니다.
# ...
# Jamkhed 페이지를 읽어 왔습니다.
# ...
# Ahmednagar district 페이지를 읽어 왔습니다.
# ...
# Nashik 페이지를 읽어 왔습니다.
# ...
# Nazok 페이지를 읽어 왔습니다.
# ...
# Persian language 페이지를 읽어 왔습니다.
# ...
# Farsi (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Persians 페이지를 읽어 왔습니다.
# ...
# Persian cat 페이지를 읽어 왔습니다.
# ...
# Iran 페이지를 읽어 왔습니다.
# ...
# Iran (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Pahlavi dynasty 페이지를 읽어 왔습니다.
# ...
# Flag of Iran 페이지를 읽어 왔습니다.
# ...
# List of flag names 페이지를 읽어 왔습니다.
# ...
# Nickname 페이지를 읽어 왔습니다.
# ...
# Short and long titles 페이지를 읽어 왔습니다.
# ...
# Primary and secondary legislation 페이지를 읽어 왔습니다.
# ...
# Presidential system 페이지를 읽어 왔습니다.
# ...
# Semi-presidential system 페이지를 읽어 왔습니다.
# ...
# Parliamentary republic 페이지를 읽어 왔습니다.
# ...
# Parliamentary Republic 페이지를 읽어 왔습니다.
# ...
# History of Chile during the Parliamentary Era (1891–1925) 페이지를 읽어 왔습니다.
# ...
# Flag of Chile 페이지를 읽어 왔습니다.
# ...
# List of Chilean flags 페이지를 읽어 왔습니다.
# ...
# Chile 페이지를 읽어 왔습니다.
# ...
# Chile (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Chili pepper 페이지를 읽어 왔습니다.
# ...
# Red Chillies (film) 페이지를 읽어 왔습니다.
# ...
# Shaji Kailas 페이지를 읽어 왔습니다.
# ...
# Thiruvananthapuram 페이지를 읽어 왔습니다.
# ...
# Thiruvananthapuram district 페이지를 읽어 왔습니다.
# ...
# Thiruvananthapuram (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Thiruvananthapuram district 페이지를 읽어 왔습니다.
# ...
# List of districts of Kerala 페이지를 읽어 왔습니다.
# ...
# South India 페이지를 읽어 왔습니다.
# ...
# States and union territories of India 페이지를 읽어 왔습니다.
# ...
# Administrative divisions of India 페이지를 읽어 왔습니다.
# ...
# List of ecoregions in India 페이지를 읽어 왔습니다.
# ...
# Himalayas 페이지를 읽어 왔습니다.
# ...
# Imaus (moth) 페이지를 읽어 왔습니다.
# ...
# Animal 페이지를 읽어 왔습니다.
# ...
# Animal (disambiguation) 페이지를 읽어 왔습니다.
# ...
# The Animal (nickname) 페이지를 읽어 왔습니다.
# ...
# Joseph Barboza 페이지를 읽어 왔습니다.
# ...
# New Bedford, Massachusetts 페이지를 읽어 왔습니다.
# ...
# New Bedford (disambiguation) 페이지를 읽어 왔습니다.
# ...
# New Bedford, Massachusetts 페이지를 읽어 왔습니다.
# ...
# Bedford, Massachusetts 페이지를 읽어 왔습니다.
# ...
# New England town 페이지를 읽어 왔습니다.
# ...
# Municipal corporation 페이지를 읽어 왔습니다.
# ...
# Local government 페이지를 읽어 왔습니다.
# ...
# List of forms of government 페이지를 읽어 왔습니다.
# ...
# Separatism 페이지를 읽어 왔습니다.
# ...
# Separatist (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Separatism 페이지를 읽어 왔습니다.
# ...
# Associated state 페이지를 읽어 왔습니다.
# ...
# Chiefdom 페이지를 읽어 왔습니다.
# ...
# Political anthropology 페이지를 읽어 왔습니다.
# ...
# Legal anthropology 페이지를 읽어 왔습니다.
# ...
# Ascribed status 페이지를 읽어 왔습니다.
# ...
# Achieved status 페이지를 읽어 왔습니다.
# ...
# Social status 페이지를 읽어 왔습니다.
# ...
# Sociology 페이지를 읽어 왔습니다.
# ...
# Sociology (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Sociology (journal) 페이지를 읽어 왔습니다.
# ...
# Outline of academic disciplines 페이지를 읽어 왔습니다.
# ...
# Discipline (academia) 페이지를 읽어 왔습니다.
# ...
# School discipline 페이지를 읽어 왔습니다.
# ...
# English-speaking world 페이지를 읽어 왔습니다.
# ...
# De facto 페이지를 읽어 왔습니다.
# ...
# De facto (disambiguation) 페이지를 읽어 왔습니다.
# ...
# De Facto (band) 페이지를 읽어 왔습니다.
# ...
# El Paso, Texas 페이지를 읽어 왔습니다.
# ...
# El Paso (disambiguation) 페이지를 읽어 왔습니다.
# ...
# El Paso, Arkansas 페이지를 읽어 왔습니다.
# ...
# White County, Arkansas 페이지를 읽어 왔습니다.
# ...
# White County 페이지를 읽어 왔습니다.
# ...
# White County, New South Wales 페이지를 읽어 왔습니다.
# ...
# New South Wales 페이지를 읽어 왔습니다.
# ...
# New Britain (Canada) 페이지를 읽어 왔습니다.
# ...
# Nunavik 페이지를 읽어 왔습니다.
# ...
# Nunavik (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Nunavik Peninsula 페이지를 읽어 왔습니다.
# ...
# Baffin Bay 페이지를 읽어 왔습니다.
# ...
# Baffin Bay (Texas) 페이지를 읽어 왔습니다.
# ...
# Kenedy County, Texas 페이지를 읽어 왔습니다.
# ...
# Kenedy, Texas 페이지를 읽어 왔습니다.
# ...
# List of sovereign states 페이지를 읽어 왔습니다.
# ...
# Lists of countries and territories 페이지를 읽어 왔습니다.
# ...
# Lists by country 페이지를 읽어 왔습니다.
# ...
# Sovereign state 페이지를 읽어 왔습니다.
# ...
# International law 페이지를 읽어 왔습니다.
# ...
# The Law of Nations 페이지를 읽어 왔습니다.
# ...
# Emer de Vattel 페이지를 읽어 왔습니다.
# ...
# Couvet 페이지를 읽어 왔습니다.
# ...
# List of former municipalities of Switzerland 페이지를 읽어 왔습니다.
# ...
# Municipalities of Switzerland 페이지를 읽어 왔습니다.
# ...
# Districts of Switzerland 페이지를 읽어 왔습니다.
# ...
# Switzerland 페이지를 읽어 왔습니다.
# ...
# Switzerland (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Switzerland, Florida 페이지를 읽어 왔습니다.
# ...
# St. Johns County, Florida 페이지를 읽어 왔습니다.
# ...
# County (United States) 페이지를 읽어 왔습니다.
# ...
# Parish (administrative division) 페이지를 읽어 왔습니다.
# ...
# Parish 페이지를 읽어 왔습니다.
# ...
# Parish (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Parish in the Catholic Church 페이지를 읽어 왔습니다.
# ...
# Christus Dominus 페이지를 읽어 왔습니다.
# ...
# Bishop 페이지를 읽어 왔습니다.
# ...
# Bishop (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Bishop in the Catholic Church 페이지를 읽어 왔습니다.
# ...
# Hierarchy of the Catholic Church 페이지를 읽어 왔습니다.
# ...
# Catholic-Hierarchy.org 페이지를 읽어 왔습니다.
# ...
# Alexa Internet 페이지를 읽어 왔습니다.
# ...
# Amazon Alexa 페이지를 읽어 왔습니다.
# ...
# Programmer 페이지를 읽어 왔습니다.
# ...
# Program 페이지를 읽어 왔습니다.
# ...
# Program management 페이지를 읽어 왔습니다.
# ...
# Program Manager 페이지를 읽어 왔습니다.
# ...
# Windows 3.1x 페이지를 읽어 왔습니다.
# ...
# Windows NT 3.1 페이지를 읽어 왔습니다.
# ...
# Windows NT 페이지를 읽어 왔습니다.
# ...
# Microsoft 페이지를 읽어 왔습니다.
# ...
# Microsoft Redmond campus 페이지를 읽어 왔습니다.
# ...
# Redmond, Washington 페이지를 읽어 왔습니다.
# ...
# Redmond, Western Australia 페이지를 읽어 왔습니다.
# ...
# Western Australia 페이지를 읽어 왔습니다.
# ...
# Flag of Western Australia 페이지를 읽어 왔습니다.
# ...
# Glossary of vexillology 페이지를 읽어 왔습니다.
# ...
# Nomenclature 페이지를 읽어 왔습니다.
# ...
# Nomenklatura 페이지를 읽어 왔습니다.
# ...
# Soviet Union 페이지를 읽어 왔습니다.
# ...
# USSR (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Soviet Union 페이지를 읽어 왔습니다.
# ...
# CCCP (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Soviet Union 페이지를 읽어 왔습니다.
# ...
# Soviet (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Romanization of Russian 페이지를 읽어 왔습니다.
# ...
# Transliteration 페이지를 읽어 왔습니다.
# ...
# Translation 페이지를 읽어 왔습니다.
# ...
# Translation (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Translation studies 페이지를 읽어 왔습니다.
# ...
# Translation Studies (journal) 페이지를 읽어 왔습니다.
# ...
# Editor-in-chief 페이지를 읽어 왔습니다.
# ...
# Managing editor 페이지를 읽어 왔습니다.
# ...
# Publication 페이지를 읽어 왔습니다.
# ...
# Publishing 페이지를 읽어 왔습니다.
# ...
# Publisher (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Publishing 페이지를 읽어 왔습니다.
# ...
# Printing press 페이지를 읽어 왔습니다.
# ...
# Printing 페이지를 읽어 왔습니다.
# ...
# Block letters 페이지를 읽어 왔습니다.
# ...
# Block letters (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Business letter 페이지를 읽어 왔습니다.
# ...
# Salutation 페이지를 읽어 왔습니다.
# ...
# Salutation (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Salutation (ballet) 페이지를 읽어 왔습니다.
# ...
# Martha Graham 페이지를 읽어 왔습니다.
# ...
# Yousuf Karsh 페이지를 읽어 왔습니다.
# ...
# Mardin 페이지를 읽어 왔습니다.
# ...
# Mardin (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Mardin (surname) 페이지를 읽어 왔습니다.
# ...
# Arif Mardin 페이지를 읽어 왔습니다.
# ...
# Istanbul 페이지를 읽어 왔습니다.
# ...
# Istanbul (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Istanbul (film) 페이지를 읽어 왔습니다.
# ...
# Film poster 페이지를 읽어 왔습니다.
# ...
# This Gun for Hire 페이지를 읽어 왔습니다.
# ...
# This Gun for Hire (album) 페이지를 읽어 왔습니다.
# ...
# The Toasters 페이지를 읽어 왔습니다.
# ...
# New York (state) 페이지를 읽어 왔습니다.
# ...
# Coat of arms of New York 페이지를 읽어 왔습니다.
# ...
# Flags of New York City 페이지를 읽어 왔습니다.
# ...
# Seal of New York City 페이지를 읽어 왔습니다.
# ...
# Armiger 페이지를 읽어 왔습니다.
# ...
# Armiger (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Katie Armiger 페이지를 읽어 왔습니다.
# ...
# Sugar Land, Texas 페이지를 읽어 왔습니다.
# ...
# Sugarland (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Sugarland 페이지를 읽어 왔습니다.
# ...
# Sugarland (disambiguation) 페이지를 읽어 왔습니다.
# ...
# The Sugarlands 페이지를 읽어 왔습니다.
# ...
# Great Smoky Mountains 페이지를 읽어 왔습니다.
# ...
# Smoky Mountains (Moon) 페이지를 읽어 왔습니다.
# ...
# List of mountain lists 페이지를 읽어 왔습니다.
# ...
# Peak bagging 페이지를 읽어 왔습니다.
# ...
# Ojos del Salado 페이지를 읽어 왔습니다.
# ...
# Summit 페이지를 읽어 왔습니다.
# ...
# Summit (meeting) 페이지를 읽어 왔습니다.
# ...
# Head of state 페이지를 읽어 왔습니다.
# ...
# Head of government 페이지를 읽어 왔습니다.
# ...
# Mikhail Mishustin 페이지를 읽어 왔습니다.
# ...
# Eastern Slavic naming customs 페이지를 읽어 왔습니다.
# ...
# Russia 페이지를 읽어 왔습니다.
# ...
# Russia (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Central Federal District 페이지를 읽어 왔습니다.
# ...
# Central Russia 페이지를 읽어 왔습니다.
# ...
# Lake Vivi 페이지를 읽어 왔습니다.
# ...
# Krasnoyarsk Krai 페이지를 읽어 왔습니다.
# ...
# Krasnodar Krai 페이지를 읽어 왔습니다.
# ...
# Krais of Russia 페이지를 읽어 왔습니다.
# ...
# Altai Krai 페이지를 읽어 왔습니다.
# ...
# Altai Republic 페이지를 읽어 왔습니다.
# ...
# Altay 페이지를 읽어 왔습니다.
# ...
# Altai Mountains 페이지를 읽어 왔습니다.
# ...
# Altay 페이지를 읽어 왔습니다.
# ...
# Altay Prefecture 페이지를 읽어 왔습니다.
# ...
# Prefectures of China 페이지를 읽어 왔습니다.
# ...
# Simplified Chinese characters 페이지를 읽어 왔습니다.
# ...
# Logogram 페이지를 읽어 왔습니다.
# ...
# The Times 페이지를 읽어 왔습니다.
# ...
# The Times (disambiguation) 페이지를 읽어 왔습니다.
# ...
# The Times 페이지를 읽어 왔습니다.
# ...
# Compact (newspaper) 페이지를 읽어 왔습니다.
# ...
# Broadsheet 페이지를 읽어 왔습니다.
# ...
# Newspaper format 페이지를 읽어 왔습니다.
# ...
# Paper size 페이지를 읽어 왔습니다.
# ...
# Sizing 페이지를 읽어 왔습니다.
# ...
# Size (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Wikisource 페이지를 읽어 왔습니다.
# ...
# Digital library 페이지를 읽어 왔습니다.
# ...
# Digital media 페이지를 읽어 왔습니다.
# ...
# Hard disk drive 페이지를 읽어 왔습니다.
# ...
# Hard drive (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Hard disk drive 페이지를 읽어 왔습니다.
# ...
# IBM 페이지를 읽어 왔습니다.
# ...
# IBM (disambiguation) 페이지를 읽어 왔습니다.
# ...
# IBM (atoms) 페이지를 읽어 왔습니다.
# ...
# Xenon 페이지를 읽어 왔습니다.
# ...
# Xenon (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Xenon (processor) 페이지를 읽어 왔습니다.
# ...
# Xenos (graphics chip) 페이지를 읽어 왔습니다.
# ...
# Graphics processing unit 페이지를 읽어 왔습니다.
# ...
# Video card 페이지를 읽어 왔습니다.
# ...
# Expansion card 페이지를 읽어 왔습니다.
# ...
# Computing 페이지를 읽어 왔습니다.
# ...
# Computing (magazine) 페이지를 읽어 왔습니다.
# ...
# Computing (Urdu magazine) 페이지를 읽어 왔습니다.
# ...
# Computer magazine 페이지를 읽어 왔습니다.
# ...
# Computer (magazine) 페이지를 읽어 왔습니다.
# ...
# Academic publishing 페이지를 읽어 왔습니다.
# ...
# Scholarly communication 페이지를 읽어 왔습니다.
# ...
# Science communication 페이지를 읽어 왔습니다.
# ...
# Scientific literature 페이지를 읽어 왔습니다.
# ...
# Academic publishing 페이지를 읽어 왔습니다.
# ...
# Academic journal 페이지를 읽어 왔습니다.
# ...
# Periodical literature 페이지를 읽어 왔습니다.
# ...
# Periodicity 페이지를 읽어 왔습니다.
# ...
# Bott periodicity theorem 페이지를 읽어 왔습니다.
# ...
# Mathematics 페이지를 읽어 왔습니다.
# ...
# Mathematics (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Mathematics (album) 페이지를 읽어 왔습니다.
# ...
# Melissa Manchester 페이지를 읽어 왔습니다.
# ...
# Melissa Manchester (album) 페이지를 읽어 왔습니다.
# ...
# Atlanta 페이지를 읽어 왔습니다.
# ...
# Atlanta (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Atlanta, Arkansas 페이지를 읽어 왔습니다.
# ...
# Arkansas 페이지를 읽어 왔습니다.
# ...
# Arkansas Territory 페이지를 읽어 왔습니다.
# ...
# Organized incorporated territories of the United States 페이지를 읽어 왔습니다.
# ...
# United States territorial acquisitions 페이지를 읽어 왔습니다.
# ...
# Territories of the United States 페이지를 읽어 왔습니다.
# ...
# U.S. territory 페이지를 읽어 왔습니다.
# ...
# Sovereignty 페이지를 읽어 왔습니다.
# ...
# Thomas Hobbes 페이지를 읽어 왔습니다.
# ...
# Hobbes (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Fredric Hobbs 페이지를 읽어 왔습니다.
# ...
# Philadelphia 페이지를 읽어 왔습니다.
# ...
# Philly (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Philadelphia 페이지를 읽어 왔습니다.
# ...
# Philadelphia (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Philadelphia County, Pennsylvania 페이지를 읽어 왔습니다.
# ...
# Old City Hall (Philadelphia) 페이지를 읽어 왔습니다.
# ...
# Historic districts in the United States 페이지를 읽어 왔습니다.
# ...
# Sycamore Historic District 페이지를 읽어 왔습니다.
# ...
# Sycamore, Illinois 페이지를 읽어 왔습니다.
# ...
# List of municipalities in Illinois 페이지를 읽어 왔습니다.
# ...
# List of unincorporated communities in Illinois 페이지를 읽어 왔습니다.
# ...
# List of municipalities in Illinois 페이지를 읽어 왔습니다.
# ...
# List of census-designated places in Illinois 페이지를 읽어 왔습니다.
# ...
# List of Illinois townships 페이지를 읽어 왔습니다.
# ...
# Illinois 페이지를 읽어 왔습니다.
# ...
# Illinois (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Illinois Confederation 페이지를 읽어 왔습니다.
# ...
# Chief Illiniwek 페이지를 읽어 왔습니다.
# ...
# Mascot 페이지를 읽어 왔습니다.
# ...
# Mascot (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Mascot, New South Wales 페이지를 읽어 왔습니다.
# ...
# Sydney 페이지를 읽어 왔습니다.
# ...
# City of Sydney 페이지를 읽어 왔습니다.
# ...
# Local government in Australia 페이지를 읽어 왔습니다.
# ...
# Australia 페이지를 읽어 왔습니다.
# ...
# Australia (continent) 페이지를 읽어 왔습니다.
# ...
# Australia (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Name of Australia 페이지를 읽어 왔습니다.
# ...
# Abraham Ortelius 페이지를 읽어 왔습니다.
# ...
# Peter Paul Rubens 페이지를 읽어 왔습니다.
# ...
# Rubens (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Rubens family 페이지를 읽어 왔습니다.
# ...
# Spanish Netherlands 페이지를 읽어 왔습니다.
# ...
# Plus ultra 페이지를 읽어 왔습니다.
# ...
# Plus Ultra (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Plus ultra 페이지를 읽어 왔습니다.
# ...
# Coat of arms of Spain 페이지를 읽어 왔습니다.
# ...
# Felipe VI of Spain 페이지를 읽어 왔습니다.
# ...
# Monarchy of Spain 페이지를 읽어 왔습니다.
# ...
# King of Spain (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Monarchy of Spain 페이지를 읽어 왔습니다.
# ...
# Coat of arms of the King of Spain 페이지를 읽어 왔습니다.
# ...
# Felipe VI of Spain 페이지를 읽어 왔습니다.
# ...
# List of titles and honours of the Spanish Crown 페이지를 읽어 왔습니다.
# ...
# Coat of arms of the King of Spain 페이지를 읽어 왔습니다.
# ...
# Crest (heraldry) 페이지를 읽어 왔습니다.
# ...
# Coat of arms 페이지를 읽어 왔습니다.
# ...
# Achievement (heraldry) 페이지를 읽어 왔습니다.
# ...
# Heraldry 페이지를 읽어 왔습니다.
# ...
# Hyghalmen Roll 페이지를 읽어 왔습니다.
# ...
# Roll of arms 페이지를 읽어 왔습니다.
# ...
# Early modern period 페이지를 읽어 왔습니다.
# ...
# History of the world 페이지를 읽어 왔습니다.
# ...
# History of Earth 페이지를 읽어 왔습니다.
# ...
# Planet 페이지를 읽어 왔습니다.
# ...
# Planet (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Dwarf planet 페이지를 읽어 왔습니다.
# ...
# Minor planet 페이지를 읽어 왔습니다.
# ...
# Planetoid (comics) 페이지를 읽어 왔습니다.
# ...
# Image Comics 페이지를 읽어 왔습니다.
# ...
# Erik Larsen 페이지를 읽어 왔습니다.
# ...
# Erik Larsen (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Erik Larsen (rower) 페이지를 읽어 왔습니다.
# ...
# Herfølge 페이지를 읽어 왔습니다.
# ...
# Køge 페이지를 읽어 왔습니다.
# ...
# Frederick VII of Denmark 페이지를 읽어 왔습니다.
# ...
# August Schiøtt 페이지를 읽어 왔습니다.
# ...
# Reventlow 페이지를 읽어 왔습니다.
# ...
# Holstein 페이지를 읽어 왔습니다.
# ...
# Holstein (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Schleswig-Holstein 페이지를 읽어 왔습니다.
# ...
# Province of Schleswig-Holstein 페이지를 읽어 왔습니다.
# ...
# Prussia 페이지를 읽어 왔습니다.
# ...
# Prussia (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Preußen 페이지를 읽어 왔습니다.
# ...
# Preussen (ship) 페이지를 읽어 왔습니다.
# ...
# German Empire 페이지를 읽어 왔습니다.
# ...
# German Empire (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Holy Roman Empire 페이지를 읽어 왔습니다.
# ...
# Roman Empire 페이지를 읽어 왔습니다.
# ...
# Roman Empire (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Autocracy 페이지를 읽어 왔습니다.
# ...
# Dominion 페이지를 읽어 왔습니다.
# ...
# Dominion (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Dominion, Nova Scotia 페이지를 읽어 왔습니다.
# ...
# List of sovereign states 페이지를 읽어 왔습니다.
# ...
# Dependent territory 페이지를 읽어 왔습니다.
# ...
# Territory 페이지를 읽어 왔습니다.
# ...
# Territory (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Box office territory 페이지를 읽어 왔습니다.
# ...
# Film industry 페이지를 읽어 왔습니다.
# ...
# Film crew 페이지를 읽어 왔습니다.
# ...
# The Film Crew 페이지를 읽어 왔습니다.
# ...
# Walk the Angry Beach 페이지를 읽어 왔습니다.
# ...
# Five Minutes to Love 페이지를 읽어 왔습니다.
# ...
# John Hayes (director) 페이지를 읽어 왔습니다.
# ...
# Burbank, California 페이지를 읽어 왔습니다.
# ...
# Burbank, Santa Clara County, California 페이지를 읽어 왔습니다.
# ...
# Burbank 페이지를 읽어 왔습니다.
# ...
# Burbank, Queensland 페이지를 읽어 왔습니다.
# ...
# Brisbane 페이지를 읽어 왔습니다.
# ...
# Brisbane (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Brisbane, California 페이지를 읽어 왔습니다.
# ...
# List of cities and towns in California 페이지를 읽어 왔습니다.
# ...
# Los Angeles 페이지를 읽어 왔습니다.
# ...
# Los Angeles County, California 페이지를 읽어 왔습니다.
# ...
# List of parishes in Louisiana 페이지를 읽어 왔습니다.
# ...
# List of United States counties and county equivalents 페이지를 읽어 왔습니다.
# ...
# County (United States) 페이지를 읽어 왔습니다.
# ...
# Borough (United States) 페이지를 읽어 왔습니다.
# ...
# Municipality 페이지를 읽어 왔습니다.
# ...
# Ponce City Hall 페이지를 읽어 왔습니다.
# ...
# Federico Degetau 페이지를 읽어 왔습니다.
# ...
# Resident Commissioner of Puerto Rico 페이지를 읽어 왔습니다.
# ...
# Jenniffer González 페이지를 읽어 왔습니다.
# ...
# Spanish naming customs 페이지를 읽어 왔습니다.
# ...
# Naming customs of Hispanic America 페이지를 읽어 왔습니다.
# ...
# Hispanic America 페이지를 읽어 왔습니다.
# ...
# Spanish colonization of the Americas 페이지를 읽어 왔습니다.
# ...
# Conquista (disambiguation) 페이지를 읽어 왔습니다.
# ...
# La Conquista (opera) 페이지를 읽어 왔습니다.
# ...
# Lorenzo Ferrero 페이지를 읽어 왔습니다.
# ...
# Contemporary classical music 페이지를 읽어 왔습니다.
# ...
# Popular music 페이지를 읽어 왔습니다.
# ...
# Pop music 페이지를 읽어 왔습니다.
# ...
# Pop music (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Pop Muzik 페이지를 읽어 왔습니다.
# ...
# Poppy.Computer 페이지를 읽어 왔습니다.
# ...
# Poppy (entertainer) 페이지를 읽어 왔습니다.
# ...
# Boston 페이지를 읽어 왔습니다.
# ...
# Boston, Lincolnshire 페이지를 읽어 왔습니다.
# ...
# Boston (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Boston Bar, British Columbia 페이지를 읽어 왔습니다.
# ...
# Provinces and territories of Canada 페이지를 읽어 왔습니다.
# ...
# Circumboreal Region 페이지를 읽어 왔습니다.
# ...
# Chamaenerion angustifolium 페이지를 읽어 왔습니다.
# ...
# Fireweed (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Chamaenerion angustifolium 페이지를 읽어 왔습니다.
# ...
# Plant 페이지를 읽어 왔습니다.
# ...
# Plant (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Chantelle Nicholson 페이지를 읽어 왔습니다.
# ...
# University of Otago 페이지를 읽어 왔습니다.
# ...
# Māori language 페이지를 읽어 왔습니다.
# ...
# Te Reo (TV channel) 페이지를 읽어 왔습니다.
# ...
# Government of New Zealand 페이지를 읽어 왔습니다.
# ...
# Politics of New Zealand 페이지를 읽어 왔습니다.
# ...
# New Zealand 페이지를 읽어 왔습니다.
# ...
# NZ (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Novaya Zemlya 페이지를 읽어 왔습니다.
# ...
# Terra Nova (2008 film) 페이지를 읽어 왔습니다.
# ...
# Nova Zembla (film) 페이지를 읽어 왔습니다.
# ...
# Terra Nova (2008 film) 페이지를 읽어 왔습니다.
# ...
# Konstantin Lavronenko 페이지를 읽어 왔습니다.
# ...
# Rostov-on-Don 페이지를 읽어 왔습니다.
# ...
# Rostov 페이지를 읽어 왔습니다.
# ...
# Rostov (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Rostov Oblast 페이지를 읽어 왔습니다.
# ...
# Oblasts of Russia 페이지를 읽어 왔습니다.
# ...
# Federated state 페이지를 읽어 왔습니다.
# ...
# Federation 페이지를 읽어 왔습니다.
# ...
# Federation (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Federalism 페이지를 읽어 왔습니다.
# ...
# Federalism (disambiguation) 페이지를 읽어 왔습니다.
# ...
# World Federalist Movement 페이지를 읽어 왔습니다.
# ...
# Civil Society Movement 페이지를 읽어 왔습니다.
# ...
# List of political ideologies 페이지를 읽어 왔습니다.
# ...
# Political party 페이지를 읽어 왔습니다.
# ...
# Party Politics 페이지를 읽어 왔습니다.
# ...
# Party Politics (horse) 페이지를 읽어 왔습니다.
# ...
# Right Royal 페이지를 읽어 왔습니다.
# ...
# Owen Tudor (horse) 페이지를 읽어 왔습니다.
# ...
# Hyperion (horse) 페이지를 읽어 왔습니다.
# ...
# Gainsborough (horse) 페이지를 읽어 왔습니다.
# ...
# Bayardo (horse) 페이지를 읽어 왔습니다.
# ...
# Bay Ronald 페이지를 읽어 왔습니다.
# ...
# Hampton (horse) 페이지를 읽어 왔습니다.
# ...
# Lord Clifden 페이지를 읽어 왔습니다.
# ...
# Viscount Clifden 페이지를 읽어 왔습니다.
# ...
# George III of the United Kingdom 페이지를 읽어 왔습니다.
# ...
# George III (disambiguation) 페이지를 읽어 왔습니다.
# ...
# George III of the United Kingdom 페이지를 읽어 왔습니다.
# ...
# Allan Ramsay (artist) 페이지를 읽어 왔습니다.
# ...
# Allan Ramsay 페이지를 읽어 왔습니다.
# ...
# Allan M. Ramsay 페이지를 읽어 왔습니다.
# ...
# Syntax 페이지를 읽어 왔습니다.
# ...
# Syntax (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Grammar 페이지를 읽어 왔습니다.
# ...
# English grammar 페이지를 읽어 왔습니다.
# ...
# Morphology (linguistics) 페이지를 읽어 왔습니다.
# ...
# Morphological typology 페이지를 읽어 왔습니다.
# ...
# Linguistic typology 페이지를 읽어 왔습니다.
# ...
# Analytic language 페이지를 읽어 왔습니다.
# ...
# Isolating language 페이지를 읽어 왔습니다.
# ...
# Language isolate 페이지를 읽어 왔습니다.
# ...
# Natural language 페이지를 읽어 왔습니다.
# ...
# Natural language processing 페이지를 읽어 왔습니다.
# ...
# Nonlinear programming 페이지를 읽어 왔습니다.
# ...
# Optimization problem 페이지를 읽어 왔습니다.
# ...
# Mathematical optimization 페이지를 읽어 왔습니다.
# ...
# Mathematical Programming 페이지를 읽어 왔습니다.
# ...
# Computer science 페이지를 읽어 왔습니다.
# ...
# Computer Sciences Corporation 페이지를 읽어 왔습니다.
# ...
# CSC 페이지를 읽어 왔습니다.
# ...
# Conspicuous Service Cross 페이지를 읽어 왔습니다.
# ...
# Conspicuous Service Cross (Australia) 페이지를 읽어 왔습니다.
# ...
# Australian Defence Force 페이지를 읽어 왔습니다.
# ...
# Australian Army 페이지를 읽어 왔습니다.
# ...
# Elizabeth II 페이지를 읽어 왔습니다.
# ...
# Elizabeth II (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Elizabeth II 페이지를 읽어 왔습니다.
# ...
# Monarchy of the United Kingdom 페이지를 읽어 왔습니다.
# ...
# Sovereign (British coin) 페이지를 읽어 왔습니다.
# ...
# Pound sterling 페이지를 읽어 왔습니다.
# ...
# GBP (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Pound sterling 페이지를 읽어 왔습니다.
# ...
# ISO 4217 페이지를 읽어 왔습니다.
# ...
# Currency symbol 페이지를 읽어 왔습니다.
# ...
# Currency sign (typography) 페이지를 읽어 왔습니다.
# ...
# Currency symbol 페이지를 읽어 왔습니다.
# ...
# ISO 4217 페이지를 읽어 왔습니다.
# ...
# Airline ticket 페이지를 읽어 왔습니다.
# ...
# Austrian Airlines 페이지를 읽어 왔습니다.
# ...
# Airline codes 페이지를 읽어 왔습니다.
# ...
# International Air Transport Association 페이지를 읽어 왔습니다.
# ...
# IATA (disambiguation) 페이지를 읽어 왔습니다.
# ...
# IATA airport code 페이지를 읽어 왔습니다.
# ...
# ICAO airport code 페이지를 읽어 왔습니다.
# ...
# IATA airport code 페이지를 읽어 왔습니다.
# ...
# Oral Ak Zhol Airport 페이지를 읽어 왔습니다.
# ...
# Oral, Kazakhstan 페이지를 읽어 왔습니다.
# ...
# Aral, Kazakhstan 페이지를 읽어 왔습니다.
# ...
# Kazakhstan 페이지를 읽어 왔습니다.
# ...
# Qazaqstan (channel) 페이지를 읽어 왔습니다.
# ...
# Television in Kazakhstan 페이지를 읽어 왔습니다.
# ...
# Khabar Agency 페이지를 읽어 왔습니다.
# ...
# Joint-stock company 페이지를 읽어 왔습니다.
# ...
# Corporate law 페이지를 읽어 왔습니다.
# ...
# Anguillan company law 페이지를 읽어 왔습니다.
# ...
# Statute 페이지를 읽어 왔습니다.
# ...
# Statutory law 페이지를 읽어 왔습니다.
# ...
# Anglosphere 페이지를 읽어 왔습니다.
# ...
# List of territorial entities where English is an official language 페이지를 읽어 왔습니다.
# ...
# British Overseas Territories 페이지를 읽어 왔습니다.
# ...
# Bots 페이지를 읽어 왔습니다.
# ...
# Robot 페이지를 읽어 왔습니다.
# ...
# Bot 페이지를 읽어 왔습니다.
# ...
# Robot 페이지를 읽어 왔습니다.
# ...
# Robot (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Internet bot 페이지를 읽어 왔습니다.
# ...
# Software agent 페이지를 읽어 왔습니다.
# ...
# Authority 페이지를 읽어 왔습니다.
# ...
# Authority (disambiguation) 페이지를 읽어 왔습니다.
# ...
# Authority (album) 페이지를 읽어 왔습니다.
# ...
# Client (band) 페이지를 읽어 왔습니다.
# ...
# Krefeld 페이지를 읽어 왔습니다.
# ...
# States of Germany 페이지를 읽어 왔습니다.
# ...
# States of Germany (disambiguation) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (A) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (B) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (C) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (D) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (E) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (F) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (G) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (H) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (I) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (J) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (K) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (L) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (M) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (N) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (O) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (P) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (Q) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (R) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (S) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (T) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (U) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (V) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (W) 페이지를 읽어 왔습니다.
# ...
# List of states in the Holy Roman Empire (Z) 페이지를 읽어 왔습니다.
# ...
# List of free imperial cities 페이지를 읽어 왔습니다.
# ...
# Free imperial city 페이지를 읽어 왔습니다.
# ...
# Imperial City 페이지를 읽어 왔습니다.
# ...
# Free imperial city 페이지를 읽어 왔습니다.
# ...
# Reichstadt 페이지를 읽어 왔습니다.
# ...
# Reichstadt Agreement 페이지를 읽어 왔습니다.
# ...
# Zákupy 페이지를 읽어 왔습니다.
# ...
# Regions of the Czech Republic 페이지를 읽어 왔습니다.
# ...
# Czech lands 페이지를 읽어 왔습니다.
# ...
# Kraj 페이지를 읽어 왔습니다.
# ...
# Krai 페이지를 읽어 왔습니다.
# ...
# KRAI 페이지를 읽어 왔습니다.
# ...
# KRAI (AM) 페이지를 읽어 왔습니다.
# ...
# City of license 페이지를 읽어 왔습니다.
# ...
# Philippines 페이지를 읽어 왔습니다.
# ...
# Philippine, Netherlands 페이지를 읽어 왔습니다.
# ...
# Netherlands 페이지를 읽어 왔습니다.
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-0e479405c4ef> in <module>
#      47
#      48
# ---> 49 getLinks('', 'BTS')
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
# ...
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      43
#      44                 pages.add(newPage)
# ---> 45                 getLinks(newPage, 'BTS')
#      46
#      47
#
# <ipython-input-27-0e479405c4ef> in getLinks(pageUrl, targetWord)
#      21         return None
#      22     try:
# ---> 23         bs = BeautifulSoup(html, 'lxml')
#      24         print("{} 페이지를 읽어 왔습니다.".format(bs.h1.get_text()))
#      25     except AttributeError as e:
#
# ~\Anaconda3\envs\cpu_env\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     284
#     285         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 286             markup = markup.read()
#     287         elif len(markup) <= 256 and (
#     288                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in read(self, amt)
#     464
#     465             if self.chunked:
# --> 466                 return self._readall_chunked()
#     467
#     468             if self.length is None:
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in _readall_chunked(self)
#     574                 if chunk_left is None:
#     575                     break
# --> 576                 value.append(self._safe_read(chunk_left))
#     577                 self.chunk_left = 0
#     578             return b''.join(value)
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in _safe_read(self, amt)
#     620         s = []
#     621         while amt > 0:
# --> 622             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     623             if not chunk:
#     624                 raise IncompleteRead(b''.join(s), amt)
#
# ~\Anaconda3\envs\cpu_env\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\cpu_env\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~\Anaconda3\envs\cpu_env\lib\ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~\Anaconda3\envs\cpu_env\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. 이동하며 특정 정보를 스크레이핑하는 크롤러
# * 페이지 제목, 첫 번째 문단, 편집 페이지를 가리키는 링크(존재한다면)를 스크레이핑하며, 이동하는 크롤러를 제작한다.
# * 아직까지 수집한 데이터를 저장하지는 않고 출력만 한다. 저장하는 것은 *6장*에서 다루도록 한다.
# ---
#
# 1. 페이지 패턴 탐색
#     * 제목의 위치 : h1 태그 안.
#     * (교재와 다름) 첫 문단 : `div#mf-section-0`
#     * (교재와 다름) (if any) 편집 링크 : `a#ca-edit -> href`
#
#
# 2. 1의 ver1 기본 크롤링 코드를 수정해, 크롤링과 데이터 스크레이핑(출력 가능) 기능이 있는 프로그램 제작. -> 웹 페이지 태그 언제나 변경될 수 있으므로, 에러 확인하는 코드 필요하다.
#
# 3. 함수 설명
#     * 출력되는 컨텐츠를 명확히 구분하기 위해 대시 추가.
#     * 원하는 정보 모두가 페이지에 있다고 확신할 수 없으므로, 있을 확률이 높은 순서대로 정렬해서 출력.
#
# #### 편집 페이지 밑에서는 되는데 왜 여기서는 안 될까?

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import URLError, HTTPError
import re
import random
import datetime

pages = set()

random.seed(datetime.datetime.now())

def getLinks(pageUrl, targetWord):
    global pages
    
    try:
        html = urlopen("http://en.wikipedia.org"+pageUrl) # 1의 함수 수정.
    except HTTPError as e:
        print("접속에 실패하였습니다. {}".format(e))
        return None
    try:
        bs = BeautifulSoup(html, 'lxml')
        print("제목 : {}".format(bs.h1.get_text())) # 제목
        print("첫 문단 : {}".format(bs.find('div', {'class' : 'mw-parser-output'})\
                                      .findAll('p')[1].get_text())) # 첫 문단
        print("편집 페이지 : {}".format(bs.find('a', {'id' : "ca-edit"}).attrs['href'])) # 편집 페이지
    except AttributeError as e:
        print("없는 정보가 있습니다. No Worries Though!")
    except IndexError as e:
        print("페이지 구조가 다릅니다. No Worries Though!")    
    for link in bs.findAll('a', href = re.compile("^(/wiki/)")):
        # 제약 조건 완화. 항목 페이지 아니어도 되게 했다.
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newPage = link.attrs['href']
                print("-------------\n"+"새로 찾은 페이지:"+newPage)           
                pages.add(newPage)
                getLinks(newPage, targetWord)
            
getLinks('/wiki/Jungkook', 'BTS')
# Out:
# 제목 : Jungkook
# 첫 문단 : Jeon Jung-kook (Korean: 전정국; born September 1, 1997), better known mononymously as Jungkook (stylized as Jung Kook), is a South Korean singer, songwriter and record producer. He is a member and vocalist of the South Korean boy band BTS.[2]
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Protection_policy#semi
# 제목 : Wikipedia:Protection policy
# 첫 문단 :
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Requests_for_page_protection
# 제목 : Wikipedia:Requests for page protection
# 첫 문단 : After a page has been protected, the protection is listed in the page history and logs with a short description indicating why it was protected, and the article is listed on Special:Protectedpages. Further discussion should take place on the Talk page of the article. In the case of full protection due to edit warring, admins do not revert to specific versions of the page, except to get rid of obvious vandalism.
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Protection_policy#move
# 제목 : Wikipedia:Protection policy
# 첫 문단 :
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Lists_of_protected_pages
# 제목 : Wikipedia:Lists of protected pages
# 첫 문단 : This is a list of resources available that list pages that are protected, semi-protected or move protected.
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Protection_policy
# 제목 : Wikipedia:Protection policy
# 첫 문단 :
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Perennial_proposals
# 제목 : Wikipedia:Perennial proposals
# 첫 문단 : Note that extensive styling of nearly every aspect of one's watchlist is possible through CSS; see Wikipedia:Customizing watchlists.
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Reliable_sources/Perennial_sources
# 제목 : Wikipedia:Reliable sources/Perennial sources
# 첫 문단 : This is a non-exhaustive list of sources whose reliability and use on Wikipedia are frequently discussed. This list summarizes prior consensus and consolidates links to the most in-depth and recent discussions from the reliable sources noticeboard and elsewhere on Wikipedia.
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:Reliable_sources
# 제목 : Wikipedia:Reliable sources
# 첫 문단 : Wikipedia articles should be based on reliable, published sources, making sure that all majority and significant minority views that have appeared in those sources are covered (see Wikipedia:Neutral point of view).  If no reliable sources can be found on a topic, Wikipedia should not have an article on it.
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:WikiProject_Reliability
# 제목 : Wikipedia:WikiProject Reliability
# 첫 문단 : This WikiProject covers all articles on Wikipedia.
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Wikipedia:WRE
# 제목 : Wikipedia:WikiProject Resource Exchange
# 첫 문단 : Departments
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/File:People_icon.svg
# 제목 : File:People icon.svg
# 첫 문단 : http://creativecommons.org/publicdomain/zero/1.0/deed.enCC0Creative Commons Zero, Public Domain Dedicationfalsefalse
#
# 없는 정보가 있습니다. No Worries Though!
# -------------
# 새로 찾은 페이지:/wiki/Special:WhatLinksHere/File:People_icon.svg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-5e9c0ca1df7f> in <module>
#      42                 getLinks(newPage, targetWord)
#      43
# ---> 44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      40                     break
#      41                 pages.add(newPage)
# ---> 42                 getLinks(newPage, targetWord)
#      43
#      44 getLinks('/wiki/Jungkook', 'BTS')
#
# <ipython-input-82-5e9c0ca1df7f> in getLinks(pageUrl, targetWord)
#      16
#      17     try:
# ---> 18         html = urlopen("http://en.wikipedia.org"+pageUrl) # 1의 함수 수정.
#      19     except HTTPError as e:
#      20         print("접속에 실패하였습니다. {}".format(e))
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1252                 encode_chunked=False):
#    1253         """Send a complete request to the server."""
# -> 1254         self._send_request(method, url, body, headers, encode_chunked)
#    1255
#    1256     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1298             # default charset of iso-8859-1.
#    1299             body = _encode(body, 'body')
# -> 1300         self.endheaders(body, encode_chunked=encode_chunked)
#    1301
#    1302     def getresponse(self):
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1247         else:
#    1248             raise CannotSendHeader()
# -> 1249         self._send_output(message_body, encode_chunked=encode_chunked)
#    1250
#    1251     def request(self, method, url, body=None, headers={}, *,
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1034         msg = b"\r\n".join(self._buffer)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#    1038         if message_body is not None:
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in send(self, data)
#     972         if self.sock is None:
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#     976                 raise NotConnected()
#
# ~\Anaconda3\envs\cpu_env\lib\http\client.py in connect(self)
#    1413
#    1414             self.sock = self._context.wrap_socket(self.sock,
# -> 1415                                                   server_hostname=server_hostname)
#    1416             if not self._context.check_hostname and self._check_hostname:
#    1417                 try:
#
# ~\Anaconda3\envs\cpu_env\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# ~\Anaconda3\envs\cpu_env\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     815                         # non-blocking
#     816                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 817                     self.do_handshake()
#     818
#     819             except (OSError, ValueError):
#
# ~\Anaconda3\envs\cpu_env\lib\ssl.py in do_handshake(self, block)
#    1075             if timeout == 0.0 and block:
#    1076                 self.settimeout(None)
# -> 1077             self._sslobj.do_handshake()
#    1078         finally:
#    1079             self.settimeout(timeout)
#
# ~\Anaconda3\envs\cpu_env\lib\ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:

# %%
html = urlopen("https://en.m.wikipedia.org/wiki/TXT_(band)")
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('a', {'id' : "ca-edit"})['href'])
# Out:
# /w/index.php?title=TXT_(band)&action=edit&section=0

# %% [markdown]
# ## 3. 여러 도메인을 이동하며 특정 정보를 스크레이핑하는 크롤러
#
# 1. 페이지에서 발견된 내부 링크를 모두 목록으로 만듦.
#
# 2. 페이지에서 발견된 외부 링크를 모두 목록으로 만듦.
#     * 웹사이트의 첫 페이지에 항상 외부 링크가 있다는 보장이 없다.
#     * 따라서 외부 링크를 찾을 때까지 웹사이트를 재귀적으로 파고든다.
#     * 실무에서 이 코드를 실행한다면, 재귀 제한에 걸리게 되므로 **반드시** 예외를 처리하는 코드를 넣어야 한다.
#
# 3. 무작위로 외부 링크를 타고 이동.
#
# 4. 외부 링크를 검색하고, 각 링크마다 메모를 남김.
#     * 하나의 동작에서는 내부 링크를 수집한다.
#     * 또 다른 동작에서는 외부 링크를 수집한다.
#     * 두 동작이 연관되어 수행된다.

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from urllib.error import HTTPError, URLError
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
allExtLinks = set()
allIntLinks = set()
random.seed(datetime.datetime.now())

# 페이지에서 발견된 내부 링크 모두 목록으로 만든다.
def getInternalLinks(bs, includeUrl): # includeUrl : 현재 페이지 url
    includeUrl = "{}://{}".format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    # 현재 페이지에서 /로 시작하는 링크 찾기
    for link in bs.findAll('a', href = re.compile("^(/|.*" + includeUrl + ")")): # 콤마, 괄호는 그냥 중간에 변수 넣을라고 해준 것.
        print(link) # 질문 해결을 위한 확인 용도
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if link.attrs['href'].startswith('/'):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(links.attrs['href'])
    return internalLinks

def getExternalLinks(bs, excludeUrl):
    externalLinks = []
    # 현재 url을 포함하지 않으면서, http나 www로 시작하는 링크 찾기 : 외부 링크라는 의미이므로.
    for link in bs.findAll('a',
                          href = re.compile("^(http|www)((?!" + excludeUrl + ").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    try:
        html = urlopen(startingPage)
    except HTTPError as e:
        print("접속되지 않았습니다. 에러 내용 : {}".format(e))
    try:
        bs = BeautifulSoup(html, 'lxml')
        externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc) # 외부 링크 뽑아 온다.
    except AttributeError as e:
        print("Error! No such Tag!")
    else:
        if len(externalLinks) == 0:
            print("외부 링크가 없습니다. 다른 링크 찾기를 시도합니다.")
            domain = "{}://{}".format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
            internalLinks = getInternalLinks(bs, domain) # 내부 링크 랜덤으로 찾고, 거기서 randomExternal 함수 이용해서 랜덤으로 외부 링크로 간다.
            return getRandomExternalLink(internalLinks[random.randint(0, len(internalLinks))])
        else:
            return externalLinks[random.randint(0, len(externalLinks)-1)] # 외부링크 있으면 랜덤으로 가면 됨.

def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
    followExternalOnly(externalLink)

followExternalOnly("http://oreilly.com")
# Out:
# 랜덤으로 찾은 외부 링크 : https://oreilly.formulated.by/scme-miami-2020/
# 랜덤으로 찾은 외부 링크 : https://www.linkedin.com/in/julianicolewatson/
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-97-23b5341a3dca> in <module>
#      61     followExternalOnly(externalLink)
#      62
# ---> 63 followExternalOnly("http://oreilly.com")
#
# <ipython-input-97-23b5341a3dca> in followExternalOnly(startingSite)
#      59     externalLink = getRandomExternalLink(startingSite)
#      60     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
# ---> 61     followExternalOnly(externalLink)
#      62
#      63 followExternalOnly("http://oreilly.com")
#
# <ipython-input-97-23b5341a3dca> in followExternalOnly(startingSite)
#      59     externalLink = getRandomExternalLink(startingSite)
#      60     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
# ---> 61     followExternalOnly(externalLink)
#      62
#      63 followExternalOnly("http://oreilly.com")
#
# <ipython-input-97-23b5341a3dca> in followExternalOnly(startingSite)
#      57
#      58 def followExternalOnly(startingSite):
# ---> 59     externalLink = getRandomExternalLink(startingSite)
#      60     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
#      61     followExternalOnly(externalLink)
#
# <ipython-input-97-23b5341a3dca> in getRandomExternalLink(startingPage)
#      39 def getRandomExternalLink(startingPage):
#      40     try:
# ---> 41         html = urlopen(startingPage)
#      42 #     except HTTPError as e:
#      43 #         print("접속되지 않았습니다. 에러 내용 : {}".format(e))
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\envs\cpu_env\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 999: Request denied

# %%
followExternalOnly("https://www.naver.com")
# Out:
# 랜덤으로 찾은 외부 링크 : http://newsstand.naver.com/?list=ct8&pcode=387
# 랜덤으로 찾은 외부 링크 : http://www.kwnews.co.kr/
# 랜덤으로 찾은 외부 링크 : http://www.jjan.kr/
# 랜덤으로 찾은 외부 링크 : https://www.facebook.com/jeonbukilbo/
# 랜덤으로 찾은 외부 링크 : http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.jjan.kr%2Fnews%2FarticleView.html%3Fidxno%3D2079382&h=AT19vMabQ8F1V3AmV8g7PCgwrNFadjUn9nmK4Ndko4buoc3Pv9OB6MB_yFSFBgjtpjbC4xHUnVUG81d4yIMR2EmiTjSRKnjK_0WLhWa278sC9uN92HWPsEAVJOnhonJzNecTdbCimV-b6fkHzaUaKGTzD9oAUvnt4fdaVryP4jvs
# 외부 링크가 없습니다. 다른 링크 찾기를 시도합니다.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-38e710c614ab> in <module>
# ----> 1 followExternalOnly("https://www.naver.com")
#
# <ipython-input-85-1c7c755d5ec4> in followExternalOnly(startingSite)
#      57     externalLink = getRandomExternalLink(startingSite)
#      58     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
# ---> 59     followExternalOnly(externalLink)
#      60
#      61 followExternalOnly("http://oreilly.com")
#
# <ipython-input-85-1c7c755d5ec4> in followExternalOnly(startingSite)
#      57     externalLink = getRandomExternalLink(startingSite)
#      58     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
# ---> 59     followExternalOnly(externalLink)
#      60
#      61 followExternalOnly("http://oreilly.com")
#
# <ipython-input-85-1c7c755d5ec4> in followExternalOnly(startingSite)
#      57     externalLink = getRandomExternalLink(startingSite)
#      58     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
# ---> 59     followExternalOnly(externalLink)
#      60
#      61 followExternalOnly("http://oreilly.com")
#
# <ipython-input-85-1c7c755d5ec4> in followExternalOnly(startingSite)
#      57     externalLink = getRandomExternalLink(startingSite)
#      58     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
# ---> 59     followExternalOnly(externalLink)
#      60
#      61 followExternalOnly("http://oreilly.com")
#
# <ipython-input-85-1c7c755d5ec4> in followExternalOnly(startingSite)
#      57     externalLink = getRandomExternalLink(startingSite)
#      58     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
# ---> 59     followExternalOnly(externalLink)
#      60
#      61 followExternalOnly("http://oreilly.com")
#
# <ipython-input-85-1c7c755d5ec4> in followExternalOnly(startingSite)
#      55
#      56 def followExternalOnly(startingSite):
# ---> 57     externalLink = getRandomExternalLink(startingSite)
#      58     print("랜덤으로 찾은 외부 링크 : {}".format(externalLink))
#      59     followExternalOnly(externalLink)
#
# <ipython-input-85-1c7c755d5ec4> in getRandomExternalLink(startingPage)
#      50             domain = "{}://{}".format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
#      51             internalLinks = getInternalLinks(bs, domain) # 내부 링크 랜덤으로 찾고, 거기서 randomExternal 함수 이용해서 랜덤으로 외부 링크로 간다.
# ---> 52             return getRandomExternalLink(internalLinks[random.randint(0, len(internalLinks)-1)])
#      53         else:
#      54             return externalLinks[random.randint(0, len(externalLinks)-1)] # 외부링크 있으면 랜덤으로 가면 됨.
#
# ~\Anaconda3\envs\cpu_env\lib\random.py in randint(self, a, b)
#     219         """
#     220
# --> 221         return self.randrange(a, b+1)
#     222
#     223     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# ~\Anaconda3\envs\cpu_env\lib\random.py in randrange(self, start, stop, step, _int)
#     197             return istart + self._randbelow(width)
#     198         if step == 1:
# --> 199             raise ValueError("empty range for randrange() (%d,%d, %d)" % (istart, istop, width))
#     200
#     201         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (0,0, 0)
